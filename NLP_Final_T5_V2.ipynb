# %%
# !pip install transformers torch datasets
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Collecting datasets
#   Downloading datasets-2.19.0-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.2 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.7 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Collecting huggingface-hub<1.0,>=0.19.3 (from transformers)
#   Downloading huggingface_hub-0.22.2-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 41.1 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, huggingface-hub, nvidia-cusolver-cu12, datasets
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# Successfully installed datasets-2.19.0 dill-0.3.8 huggingface-hub-0.22.2 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 xxhash-3.4.1

# %%
# !pip install rouge_score sacrebleu
# Out:
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu
#   Downloading sacrebleu-2.4.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.25.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.2)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=60f25f1014cba0fc6fdf86bfa27672949d3bbe2f43420d856d96ceebae1fd200
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: portalocker, colorama, sacrebleu, rouge_score
# Successfully installed colorama-0.4.6 portalocker-2.8.2 rouge_score-0.1.2 sacrebleu-2.4.2

# %%
# !pip install accelerate -U
# Out:
# Collecting accelerate
#   Downloading accelerate-0.29.3-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.22.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.29.3

# %%
from datasets import load_dataset
from transformers import T5Tokenizer, T5ForConditionalGeneration, Trainer, TrainingArguments
from transformers import DataCollatorForSeq2Seq, EarlyStoppingCallback
import numpy as np
import torch

# %%
def load_and_prepare_data(model_name):
    dataset = load_dataset("neulab/tldr")
    train_test_split = dataset["train"].train_test_split(test_size=0.2)
    dataset["train"] = train_test_split["train"]
    dataset["validation"] = train_test_split["test"]

    tokenizer = T5Tokenizer.from_pretrained(model_name)
    def preprocess_function(examples):
        input_texts = ["translate English to Bash: " + inp for inp in examples['nl']]
        model_inputs = tokenizer(input_texts, max_length=30, truncation=True, padding="max_length")
        with tokenizer.as_target_tokenizer():
            labels = tokenizer(examples['cmd'], max_length=30, truncation=True, padding="max_length")
        model_inputs['labels'] = labels['input_ids']
        return model_inputs

    tokenized_datasets = dataset.map(preprocess_function, batched=True)
    return tokenized_datasets, tokenizer

# %%
model_name = "t5-small"  # Consider changing to an even smaller model if memory issues persist
tokenized_datasets, tokenizer = load_and_prepare_data(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1486: FutureWarning: The repository for neulab/tldr contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/neulab/tldr
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/4.92k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/2.97k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.76M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.28M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Map:   0%|          | 0/5131 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:3921: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map:   0%|          | 0/928 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1283 [00:00<?, ? examples/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
import os
from rouge_score import rouge_scorer, scoring
from sacrebleu.metrics import BLEU
from datasets import load_metric
import numpy as np

# Load metrics for evaluation
bleu_metric = load_metric('sacrebleu')
rouge_metric = load_metric('rouge')

def compute_metrics(eval_pred):
    logits, labels = eval_pred

    # Check if logits is a tuple and extract appropriately
    if isinstance(logits, tuple):
        logits = logits[0]

    # Convert to numpy arrays if they are tensors
    if isinstance(logits, torch.Tensor):
        logits = logits.detach().cpu().numpy()

    if isinstance(labels, torch.Tensor):
        labels = labels.detach().cpu().numpy()

    # Perform argmax to get predictions
    predictions = np.argmax(logits, axis=-1)

    # Decode the predictions and labels using the tokenizer
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Clean up tokens
    decoded_preds = [pred.strip() for pred in decoded_preds]
    decoded_labels = [[label.strip()] for label in decoded_labels]

    # Calculate metrics
    bleu_score = bleu_metric.compute(predictions=decoded_preds, references=decoded_labels)['score']
    rouge_result = rouge_metric.compute(predictions=decoded_preds, references=decoded_labels)
    rouge_l_score = rouge_result['rougeL'].mid.fmeasure

    # Calculate perplexity if possible
    # Directly compute perplexity from logits if losses are not separately provided
    if logits is not None:
        # Assume cross-entropy loss for perplexity calculation
        softmax_logits = torch.nn.functional.softmax(torch.tensor(logits), dim=-1)
        label_ids = torch.tensor(labels)
        # Use gather to pull probabilities of actual labels
        gathered_probs = softmax_logits.gather(dim=-1, index=label_ids.unsqueeze(-1)).squeeze(-1)
        mean_log_prob = gathered_probs.log().mean().item()
        perplexity = np.exp(-mean_log_prob)
    else:
        perplexity = float('nan')

    return {'bleu': bleu_score, 'rouge-l': rouge_l_score, 'perplexity': perplexity}
# Out:
# <ipython-input-8-cd5c73119686>:8: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   bleu_metric = load_metric('sacrebleu')
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for sacrebleu contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/sacrebleu/sacrebleu.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/2.85k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for rouge contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/rouge/rouge.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/2.17k [00:00<?, ?B/s]

# %%
from transformers import TrainingArguments, Trainer, DataCollatorForSeq2Seq, EarlyStoppingCallback
from transformers import T5Tokenizer, T5ForConditionalGeneration
from datasets import load_dataset

# Set up TrainingArguments
training_args = TrainingArguments(
    output_dir="./results",  # Make sure this is the directory you want to use
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    gradient_accumulation_steps=16,
    num_train_epochs=5,
    weight_decay=0.01,
    save_strategy="epoch",
    save_total_limit=3,  # Adjust this to manage disk space
    load_best_model_at_end=True,
    metric_for_best_model='bleu',  # This must match the key returned by compute_metrics
    report_to="none",
    fp16=True
)

# Trainer setup
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['validation'],
    data_collator=DataCollatorForSeq2Seq(tokenizer),
    compute_metrics=compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=3)]
)

# Start Training
trainer.train()
# Out:
#     <div>
#
#       <progress value='1600' max='1600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1600/1600 33:32, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#       <th>Rouge-l</th>
#       <th>Perplexity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>No log</td>
#       <td>1.914883</td>
#       <td>4.422776</td>
#       <td>0.094693</td>
#       <td>6.786120</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.952000</td>
#       <td>1.708897</td>
#       <td>9.320101</td>
#       <td>0.123349</td>
#       <td>5.522833</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.952000</td>
#       <td>1.652636</td>
#       <td>10.078784</td>
#       <td>0.140994</td>
#       <td>5.220721</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.828400</td>
#       <td>1.629758</td>
#       <td>10.121123</td>
#       <td>0.147907</td>
#       <td>5.102635</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.744700</td>
#       <td>1.623179</td>
#       <td>10.409788</td>
#       <td>0.150078</td>
#       <td>5.069162</td>
#     </tr>
#   </tbody>
# </table><p>
# There were missing keys in the checkpoint model loaded: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight', 'lm_head.weight'].
# TrainOutput(global_step=1600, training_loss=2.1474752616882324, metrics={'train_runtime': 2014.7959, 'train_samples_per_second': 12.733, 'train_steps_per_second': 0.794, 'total_flos': 203012702208000.0, 'train_loss': 2.1474752616882324, 'epoch': 4.989280841941142})

# %%
# Save the model to Google Drive (specific to Google Colab)
from google.colab import drive
drive.mount('/content/drive')
model.save_pretrained("/content/drive/My Drive/linux_command_translator_V2")
tokenizer.save_pretrained("/content/drive/My Drive/linux_command_translator_V2")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ('/content/drive/My Drive/linux_command_translator_V2/tokenizer_config.json',
#  '/content/drive/My Drive/linux_command_translator_V2/special_tokens_map.json',
#  '/content/drive/My Drive/linux_command_translator_V2/spiece.model',
#  '/content/drive/My Drive/linux_command_translator_V2/added_tokens.json')

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

model_path = "/content/drive/My Drive/linux_command_translator_V2"
tokenizer = T5Tokenizer.from_pretrained(model_path)
model = T5ForConditionalGeneration.from_pretrained(model_path)

def load_model(model_path):
    tokenizer = T5Tokenizer.from_pretrained(model_path)
    model = T5ForConditionalGeneration.from_pretrained(model_path)
    return tokenizer, model
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# Function to perform inference
def translate_to_command(input_text, tokenizer, model, device='cpu'):
    model.to(device)
    input_ids = tokenizer.encode("translate English to Bash: " + input_text, return_tensors="pt").to(device)
    with torch.no_grad():
        outputs = model.generate(input_ids, max_length=50, num_beams=5, early_stopping=True)
    command = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return command

# Assuming you have saved your model to the path below
model_path = '/content/drive/My Drive/linux_command_translator_V2'

# Load model and tokenizer
tokenizer, model = load_model(model_path)

# Load the dataset and select the first 10 examples from the 'nl' column
dataset = load_dataset("neulab/tldr")
first_10_commands = dataset['train']['nl'][:10]

# Translate each example sentence
for i, input_text in enumerate(first_10_commands):
    command = translate_to_command(input_text, tokenizer, model)
    print(f"Input: {input_text}\nGenerated Command: {command}\n")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1486: FutureWarning: The repository for neulab/tldr contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/neulab/tldr
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Input: get the label of a fat32 partition
# Generated Command: fat32 path/to/file
#
# Input: set the label of a fat32 partition
# Generated Command: fat32 path/to/file
#
# Input: search for a package in your current sources
# Generated Command: git search path/to/file
#
# Input: show information about a package
# Generated Command: git path/to/ package path/to/ package
#
# Input: show whether a package is installed and up to date
# Generated Command: git path/to/package
#
# Input: show dependencies for a package
# Generated Command: git -dev path/to/package
#
# Input: show packages that depend on a particular package
# Generated Command: git show path/to/file path/to/file
#
# Input: refresh database content
# Generated Command: pc path/to/database
#
# Input: display file names as soon as they are found
# Generated Command: git path/to/filename
#
# Input: install a new package
# Generated Command: install path/to/file

# %%
# Function to translate natural language to command
def translate_to_command(input_text, tokenizer, model, device='cpu'):
    model.to(device)
    input_ids = tokenizer.encode("translate English to Bash: " + input_text, return_tensors="pt").to(device)
    outputs = model.generate(input_ids, max_length=50, num_beams=5, early_stopping=True)
    command = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return command

# Assuming you have saved your model to the path below
model_path = '/content/drive/My Drive/linux_command_translator'

# Load model and tokenizer
tokenizer, model = load_model(model_path)

# Load dataset and select the 'train' split
dataset = load_dataset("neulab/tldr", split='train')

# Iterate over the first 10 entries of the train split
for i in range(100):
    input_text = dataset[i]['nl']  # Natural language instruction
    actual_command = dataset[i]['cmd']  # Corresponding command
    predicted_command = translate_to_command(input_text, tokenizer, model)

    print(f"Input Text: {input_text}")
    print(f"Actual Command: {actual_command}")
    print(f"Predicted Command: {predicted_command}")
    print("-" * 80)  # Separator for readability
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Input Text: get the label of a fat32 partition
# Actual Command: fatlabel {{/dev/sda1}}
# Predicted Command: fat32 filename
# --------------------------------------------------------------------------------
# Input Text: set the label of a fat32 partition
# Actual Command: fatlabel {{/dev/sdc3}} "{{new_label}}"
# Predicted Command: fat32 path/to/file
# --------------------------------------------------------------------------------
# Input Text: search for a package in your current sources
# Actual Command: apt-cache search {{query}}
# Predicted Command: git search path/to/file
# --------------------------------------------------------------------------------
# Input Text: show information about a package
# Actual Command: apt-cache show {{package}}
# Predicted Command: git path/to/package
# --------------------------------------------------------------------------------
# Input Text: show whether a package is installed and up to date
# Actual Command: apt-cache policy {{package}}
# Predicted Command: git path/to/package
# --------------------------------------------------------------------------------
# Input Text: show dependencies for a package
# Actual Command: apt-cache depends {{package}}
# Predicted Command: git show path/to/package path/to/package
# --------------------------------------------------------------------------------
# Input Text: show packages that depend on a particular package
# Actual Command: apt-cache rdepends {{package}}
# Predicted Command: git show path/to/package_name
# --------------------------------------------------------------------------------
# Input Text: refresh database content
# Actual Command: sudo updatedb
# Predicted Command: cd path/to/database
# --------------------------------------------------------------------------------
# Input Text: display file names as soon as they are found
# Actual Command: sudo updatedb --verbose
# Predicted Command: git path/to/filename
# --------------------------------------------------------------------------------
# Input Text: install a new package
# Actual Command: sudo pacman --sync {{package_name}}
# Predicted Command: git install package_name
# --------------------------------------------------------------------------------
# Input Text: synchronize and update all packages (add `downloadonly` to download the packages and not update them)
# Actual Command: sudo pacman --sync --refresh --sysupgrade
# Predicted Command: git synchronize path/to/package_name
# --------------------------------------------------------------------------------
# Input Text: update all packages and install a new one without prompting
# Actual Command: sudo pacman --sync --refresh --sysupgrade --noconfirm {{package_name}}
# Predicted Command: git update path/to/file path/to/file
# --------------------------------------------------------------------------------
# Input Text: search the package database for a regular expression or keyword
# Actual Command: pacman --sync --search "{{search_pattern}}"
# Predicted Command: pc path/to/file.pc
# --------------------------------------------------------------------------------
# Input Text: display information about a package
# Actual Command: pacman --sync --info {{package_name}}
# Predicted Command: git display path/to/package
# --------------------------------------------------------------------------------
# Input Text: overwrite conflicting files during a package update
# Actual Command: sudo pacman --sync --refresh --sysupgrade --overwrite {{path/to/file}}
# Predicted Command: git overwrite path/to/file
# --------------------------------------------------------------------------------
# Input Text: synchronize and update all packages, but ignore a specific package (can be used more than once)
# Actual Command: sudo pacman --sync --refresh --sysupgrade --ignore {{package_name}}
# Predicted Command: git synchronize package_name package_name
# --------------------------------------------------------------------------------
# Input Text: remove not installed packages and unused repositories from the cache (use two `clean` flags to clean all packages)
# Actual Command: sudo pacman --sync --clean
# Predicted Command: git remove path/to/file_name path/to/file_name
# --------------------------------------------------------------------------------
# Input Text: display help for this subcommand
# Actual Command: pacman --remove --help
# Predicted Command: subcommand path/to/command
# --------------------------------------------------------------------------------
# Input Text: remove a package and its dependencies
# Actual Command: sudo pacman --remove --recursive {{package_name}}
# Predicted Command: git remove path/to/package
# --------------------------------------------------------------------------------
# Input Text: remove a package and both its dependencies and configuration files
# Actual Command: sudo pacman --remove --recursive --nosave {{package_name}}
# Predicted Command: git remove path/to/file.config
# --------------------------------------------------------------------------------
# Input Text: remove a package without prompting
# Actual Command: sudo pacman --remove --noconfirm {{package_name}}
# Predicted Command: git remove path/to/package
# --------------------------------------------------------------------------------
# Input Text: remove orphan packages (installed as dependencies but not required by any package)
# Actual Command: sudo pacman --remove --recursive --nosave $(pacman --query --unrequired --deps --quiet)
# Predicted Command: git remove path/to/device_name path/to/device_name path/to/device_name
# --------------------------------------------------------------------------------
# Input Text: remove a package and all packages that depend on it
# Actual Command: sudo pacman --remove --cascade {{package_name}}
# Predicted Command: git remove path/to/package
# --------------------------------------------------------------------------------
# Input Text: list packages that would be affected (does not remove any packages)
# Actual Command: pacman --remove --print {{package_name}}
# Predicted Command: git list path/to/package_name
# --------------------------------------------------------------------------------
# Input Text: display bpftrace version
# Actual Command: bpftrace -V
# Predicted Command: bpftrace
# --------------------------------------------------------------------------------
# Input Text: list all available probes
# Actual Command: sudo bpftrace -l
# Predicted Command: probe list path/to/file
# --------------------------------------------------------------------------------
# Input Text: run a oneliner program (e.g. syscall count by program)
# Actual Command: sudo bpftrace -e '{{tracepoint:raw_syscalls:sys_enter { @[comm] = count(); }}}'
# Predicted Command: syscall path/to/program
# --------------------------------------------------------------------------------
# Input Text: run a program from a file
# Actual Command: sudo bpftrace {{path/to/file}}
# Predicted Command: pc path/to/file.pc
# --------------------------------------------------------------------------------
# Input Text: trace a program by pid
# Actual Command: sudo bpftrace -e '{{tracepoint:raw_syscalls:sys_enter /pid == 123/ { @[comm] = count(); }}}'
# Predicted Command: pid trace path/to/directory
# --------------------------------------------------------------------------------
# Input Text: do a dry run and display the output in ebpf format
# Actual Command: sudo bpftrace -d -e '{{one_line_program}}'
# Predicted Command: ebpf path/to/file.ebpf
# --------------------------------------------------------------------------------
# Input Text: open a file in the default editor
# Actual Command: sensible-editor {{file}}
# Predicted Command: git open filename
# --------------------------------------------------------------------------------
# Input Text: open a file in the default editor, with the cursor at the end of the file
# Actual Command: sensible-editor + {{file}}
# Predicted Command: git open path/to/file
# --------------------------------------------------------------------------------
# Input Text: open a file in the default editor, with the cursor at the beginning of line 10
# Actual Command: sensible-editor +10 {{file}}
# Predicted Command: git path/to/file
# --------------------------------------------------------------------------------
# Input Text: open 3 files in vertically split editor windows at the same time
# Actual Command: sensible-editor -O3 {{file_1}} {{file_2}} {{file_3}}
# Predicted Command: 3 path/to/directory
# --------------------------------------------------------------------------------
# Input Text: integrate firejail with your desktop environment
# Actual Command: sudo firecfg
# Predicted Command: firejail username
# --------------------------------------------------------------------------------
# Input Text: open a restricted mozilla firefox
# Actual Command: firejail {{firefox}}
# Predicted Command: mozilla firefox path/to/file
# --------------------------------------------------------------------------------
# Input Text: start a restricted apache server on a known interface and address
# Actual Command: firejail --net={{eth0}} --ip={{192.168.1.244}} {{/etc/init.d/apache2}} {{start}}
# Predicted Command: apache path/to/host_name
# --------------------------------------------------------------------------------
# Input Text: list running sandboxes
# Actual Command: firejail --list
# Predicted Command: sandboxes
# --------------------------------------------------------------------------------
# Input Text: list network activity from running sandboxes
# Actual Command: firejail --netstats
# Predicted Command: sandboxes list
# --------------------------------------------------------------------------------
# Input Text: shutdown a running sandbox
# Actual Command: firejail --shutdown={{7777}}
# Predicted Command: sandbox shutdown
# --------------------------------------------------------------------------------
# Input Text: build the package in the current directory
# Actual Command: debuild
# Predicted Command: git build path/to/directory
# --------------------------------------------------------------------------------
# Input Text: build a binary package only
# Actual Command: debuild -b
# Predicted Command: git build path/to/file
# --------------------------------------------------------------------------------
# Input Text: do not run lintian after building the package
# Actual Command: debuild --no-lintian
# Predicted Command: lintian path/to/package
# --------------------------------------------------------------------------------
# Input Text: start nmon
# Actual Command: nmon
# Predicted Command: nmon start nmon
# --------------------------------------------------------------------------------
# Input Text: save records to file ("s 300 c 288" by default)
# Actual Command: nmon -f
# Predicted Command: git -s path/to/file
# --------------------------------------------------------------------------------
# Input Text: save records to file with a total of 240 measurements, by taking 30 seconds between each measurement
# Actual Command: nmon -f -s {{30}} -c {{240}}
# Predicted Command: pc -p path/to/measure path/to/file.pc path/to/measure.pc
# --------------------------------------------------------------------------------
# Input Text: view the queue
# Actual Command: squeue
# Predicted Command: sh path/to/file.sh
# --------------------------------------------------------------------------------
# Input Text: view jobs queued by a specific user
# Actual Command: squeue -u {{username}}
# Predicted Command: git username username
# --------------------------------------------------------------------------------
# Input Text: view the queue and refresh every 5 seconds
# Actual Command: squeue -i {{5}}
# Predicted Command: tv -refresh refresh_sequence
# --------------------------------------------------------------------------------
# Input Text: view the queue with expected start times
# Actual Command: squeue --start
# Predicted Command: sh path/to/file path/to/file
# --------------------------------------------------------------------------------
# Input Text: show the progress of running coreutils
# Actual Command: progress
# Predicted Command: coreutils path/to/file
# --------------------------------------------------------------------------------
# Input Text: show the progress of running coreutils in quiet mode
# Actual Command: progress -q
# Predicted Command: coreutils path/to/path/to/path/to/path/to/path/to/path/to/path/to/path/to/path/to/path/to/path/to/
# --------------------------------------------------------------------------------
# Input Text: launch and monitor a single longrunning command
# Actual Command: {{command}} & progress -mp $!
# Predicted Command: longrunning path/to/command
# --------------------------------------------------------------------------------
# Input Text: start i7z (needs to be run in superuser mode)
# Actual Command: sudo i7z
# Predicted Command: i7z start user_name
# --------------------------------------------------------------------------------
# Input Text: discover directories using a [w]ordlist on a target [u]rl with [c]olorized and [v]erbose output
# Actual Command: ffuf -w {{path/to/wordlist}} -u {{https://target/FUZZ}} -c -v
# Predicted Command: w]ordlist path/to/directory path/to/directory
# --------------------------------------------------------------------------------
# Input Text: fuzz host[h]eaders with a host file on a traget website and [m]atch http 200 [c]ode responses
# Actual Command: ffuf -w {{hosts.txt}} -u {{https://example.org}} -H "{{Host: FUZZ}}" -mc {{200}}
# Predicted Command: mcode path/to/file path/to/file
# --------------------------------------------------------------------------------
# Input Text: discover directories using a [w]ordlist on a target website with a max individual job time of 60 seconds and recursion discovery depth of 2 levels
# Actual Command: ffuf -w {{path/to/wordlist}} -u {{https://target/FUZZ}} -maxtime-job {{60}} -recursion -recursion-depth {{2}}
# Predicted Command: wordlist -recursion recursion recursion
# --------------------------------------------------------------------------------
# Input Text: fuzz get parameter on a target website and [f]ilter out message [s]ize response of 4242 bytes
# Actual Command: ffuf -w {{path/to/param_names.txt}} -u {{https://target/script.php?FUZZ=test_value}} -fs {{4242}}
# Predicted Command: fzz get parameter on a target website and [f]ilter out message [s]ize response of 4242 bytes
# --------------------------------------------------------------------------------
# Input Text: fuzz post method with post [d]ata of password on a target website and [f]ilter out http response [c]ode 401
# Actual Command: ffuf -w {{path/to/postdata.txt}} -X {{POST}} -d "{{username=admin\&password=FUZZ}}" -u {{https://target/login.php}} -fc {{401}}
# Predicted Command: fzz path/to/site path/to/site
# --------------------------------------------------------------------------------
# Input Text: discover subdomains using a subdoomain list on a target website
# Actual Command: ffuf -w {{subdomains.txt}} -u {{https://website.com}} -H "{{Host: FUZZ.website.com}}"
# Predicted Command: subdoomain path/to/site path/to/site
# --------------------------------------------------------------------------------
# Input Text: add all package binaries in the current directory and remove the old database file
# Actual Command: repo-add --remove {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}}
# Predicted Command: git add path/to/file
# --------------------------------------------------------------------------------
# Input Text: add all package binaries in the current directory in silent mode except for warning and error messages
# Actual Command: repo-add --quiet {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}}
# Predicted Command: git path/to/directory path/to/directory
# --------------------------------------------------------------------------------
# Input Text: add all package binaries in the current directory without showing color
# Actual Command: repo-add --nocolor {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}}
# Predicted Command: git add path/to/directory
# --------------------------------------------------------------------------------
# Input Text: display executable invocations per user (username not displayed)
# Actual Command: sudo sa
# Predicted Command: git -username username
# --------------------------------------------------------------------------------
# Input Text: display executable invocations per user, showing responsible usernames
# Actual Command: sudo sa --print-users
# Predicted Command: git username username
# --------------------------------------------------------------------------------
# Input Text: list resources used recently per user
# Actual Command: sudo sa --user-summary
# Predicted Command: git list path/to/user
# --------------------------------------------------------------------------------
# Input Text: edit the password file
# Actual Command: vipw
# Predicted Command: password edit path/to/password
# --------------------------------------------------------------------------------
# Input Text: display the current version of `vipw`
# Actual Command: vipw --version
# Predicted Command: vpw vipw
# --------------------------------------------------------------------------------
# Input Text: retrieve current status of the jail service
# Actual Command: fail2ban-client status {{jail}}
# Predicted Command: jail path/to/file
# --------------------------------------------------------------------------------
# Input Text: remove the specified ip from the jail service's ban list
# Actual Command: fail2ban-client set {{jail}} unbanip {{ip}}
# Predicted Command: ip remove path/to/file path/to/file
# --------------------------------------------------------------------------------
# Input Text: verify fail2ban server is alive
# Actual Command: fail2ban-client ping
# Predicted Command: fail2ban path/to/file
# --------------------------------------------------------------------------------
# Input Text: synchronize and set date and time
# Actual Command: sudo ntpdate {{host}}
# Predicted Command: symbol path/to/time
# --------------------------------------------------------------------------------
# Input Text: query the host without setting the time
# Actual Command: ntpdate -q {{host}}
# Predicted Command: git query host_name
# --------------------------------------------------------------------------------
# Input Text: use an unprivileged port in case a firewall is blocking privileged ports
# Actual Command: sudo ntpdate -u {{host}}
# Predicted Command: git -f path/to/file_name
# --------------------------------------------------------------------------------
# Input Text: force time to be stepped using `settimeofday` instead of `slewed`
# Actual Command: sudo ntpdate -b {{host}}
# Predicted Command: slewed settimeofday
# --------------------------------------------------------------------------------
# Input Text: show all running services
# Actual Command: systemctl status
# Predicted Command: git show path/to/services
# --------------------------------------------------------------------------------
# Input Text: list failed units
# Actual Command: systemctl --failed
# Predicted Command: git list units
# --------------------------------------------------------------------------------
# Input Text: start/stop/restart/reload a service
# Actual Command: systemctl {{start|stop|restart|reload}} {{unit}}
# Predicted Command: git start/stop/restart/reload service
# --------------------------------------------------------------------------------
# Input Text: show the status of a unit
# Actual Command: systemctl status {{unit}}
# Predicted Command: git show unit
# --------------------------------------------------------------------------------
# Input Text: enable/disable a unit to be started on bootup
# Actual Command: systemctl {{enable|disable}} {{unit}}
# Predicted Command: bootup path/to/unit
# --------------------------------------------------------------------------------
# Input Text: mask/unmask a unit to prevent enablement and manual activation
# Actual Command: systemctl {{mask|unmask}} {{unit}}
# Predicted Command: mask unit unit
# --------------------------------------------------------------------------------
# Input Text: reload systemd, scanning for new or changed units
# Actual Command: systemctl daemon-reload
# Predicted Command: cd path/to/systemd
# --------------------------------------------------------------------------------
# Input Text: check if a unit is enabled
# Actual Command: systemctl is-enabled {{unit}}
# Predicted Command: git unit unit
# --------------------------------------------------------------------------------
# Input Text: run `ipconfig.exe` program
# Actual Command: wine {{ipconfig}} {{/all}}
# Predicted Command: ipconfig exe
# --------------------------------------------------------------------------------
# Input Text: run `cmd.exe` in background
# Actual Command: wine start {{cmd}}
# Predicted Command: cmd-exe path/to/file
# --------------------------------------------------------------------------------
# Input Text: run windowslike package manager
# Actual Command: wine uninstaller
# Predicted Command: git run path/to/file path/to/directory
# --------------------------------------------------------------------------------
# Input Text: install msi packages
# Actual Command: wine msiexec /i {{package}}
# Predicted Command: msi path/to/msi
# --------------------------------------------------------------------------------
# Input Text: display a message in fullscreen
# Actual Command: sm "{{Hello World!}}"
# Predicted Command: cd path/to/file.cd
# --------------------------------------------------------------------------------
# Input Text: display a message with inverted colors
# Actual Command: sm -i "{{Hello World!}}"
# Predicted Command: cd path/to/file path/to/file
# --------------------------------------------------------------------------------
# Input Text: display a message with a custom foreground color
# Actual Command: sm -f {{blue}} "{{Hello World!}}"
# Predicted Command: git path/to/file path/to/file
# --------------------------------------------------------------------------------
# Input Text: display a message with a custom background color
# Actual Command: sm -b {{#008888}} "{{Hello World!}}"
# Predicted Command: hg path/to/file path/to/file
# --------------------------------------------------------------------------------
# Input Text: display a message rotated 3 times (in steps of 90 degrees, counterclockwise)
# Actual Command: sm -r {{3}} "{{Hello World!}}"
# Predicted Command: pc path/to/file path/to/file.pc
# --------------------------------------------------------------------------------
# Input Text: display a message using the output from another command
# Actual Command: {{echo "Hello World!"}} | sm -
# Predicted Command: hg path/to/command
# --------------------------------------------------------------------------------
# Input Text: create a btrfs filesystem on a single device
# Actual Command: sudo mkfs.btrfs --metadata single --data single {{/dev/sda}}
# Predicted Command: btrfs path/to/file.btrfs
# --------------------------------------------------------------------------------
# Input Text: create a btrfs filesystem on multiple devices with raid1
# Actual Command: sudo mkfs.btrfs --metadata raid1 --data raid1 {{/dev/sda}} {{/dev/sdb}} {{/dev/sdN}}
# Predicted Command: btrfs path/to/filesystem
# --------------------------------------------------------------------------------
# Input Text: set a label for the filesystem
# Actual Command: sudo mkfs.btrfs --label "{{label}}" {{/dev/sda}} [{{/dev/sdN}}]
# Predicted Command: git path/to/filesystem
# --------------------------------------------------------------------------------
# Input Text: mount a `.raw` image file into a dmg container file
# Actual Command: xmount --in {{raw}} {{path/to/image.dd}} --out {{dmg}} {{mountpoint}}
# Predicted Command: dmg mount path/to/file path/to/file
# --------------------------------------------------------------------------------
# Input Text: mount an ewf image file with writecache support into a vhd file to boot from
# Actual Command: xmount --cache {{path/to/cache.ovl}} --in {{ewf}} {{path/to/image.E??}} --out {{vhd}} {{mountpoint}}
# Predicted Command: vhd mount path/to/file
# --------------------------------------------------------------------------------
# Input Text: mount the first partition at sector 2048 into a new `.raw` image file
# Actual Command: xmount --offset {{2048}} --in {{raw}} {{path/to/image.dd}} --out {{raw}} {{mountpoint}}
# Predicted Command: git mount path/to/file.raw
# --------------------------------------------------------------------------------
# Input Text: show the current number lock status
# Actual Command: numlockx status
# Predicted Command: git lock path/to/name
# --------------------------------------------------------------------------------

# %%
# Function to translate natural language to command
def translate_to_command(input_text, tokenizer, model, device='cpu'):
    model.to(device)
    input_ids = tokenizer.encode("translate English to Bash: " + input_text, return_tensors="pt").to(device)
    outputs = model.generate(input_ids, max_length=50, num_beams=5, early_stopping=True)
    command = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return command

# Assuming you have saved your model to the path below
model_path = '/content/drive/My Drive/linux_command_translator'

# Load model and tokenizer
tokenizer, model = load_model(model_path)

# Load dataset and select the 'train' split
dataset = load_dataset("neulab/tldr", split='validation')

# Iterate over the first 10 entries of the train split
for i in range(100):
    input_text = dataset[i]['nl']  # Natural language instruction
    actual_command = dataset[i]['cmd']  # Corresponding command
    predicted_command = translate_to_command(input_text, tokenizer, model)

    print(f"Input Text: {input_text}")
    print(f"Actual Command: {actual_command}")
    print(f"Predicted Command: {predicted_command}")
    print("-" * 80)  # Separator for readability
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1486: FutureWarning: The repository for neulab/tldr contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/neulab/tldr
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Input Text: generate ascii art for a given text
# Actual Command: toilet {{input_text}}
# Predicted Command: ascii path/to/text
# --------------------------------------------------------------------------------
# Input Text: generate ascii art using a custom font file
# Actual Command: toilet {{input_text}} -f {{font_filename}}
# Predicted Command: ascii path/to/file
# --------------------------------------------------------------------------------
# Input Text: generate ascii art using a filter
# Actual Command: toilet {{input_text}} --filter {{filter_name}}
# Predicted Command: ascii path/to/art path/to/art.scii
# --------------------------------------------------------------------------------
# Input Text: show available toilet filters
# Actual Command: toilet --filter list
# Predicted Command: toilet filter path/to/filter
# --------------------------------------------------------------------------------
# Input Text: start an application with the procfile in the current directory
# Actual Command: foreman start
# Predicted Command: procfile path/to/file
# --------------------------------------------------------------------------------
# Input Text: start an application with a specified procfile
# Actual Command: foreman start -f {{Procfile}}
# Predicted Command: procfile path/to/file
# --------------------------------------------------------------------------------
# Input Text: start a specific application
# Actual Command: foreman start {{process}}
# Predicted Command: git start application_name
# --------------------------------------------------------------------------------
# Input Text: validate procfile format
# Actual Command: foreman check
# Predicted Command: procfile validate
# --------------------------------------------------------------------------------
# Input Text: run oneoff commands with the process's environment
# Actual Command: foreman run {{command}}
# Predicted Command: pc path/to/process_name path/to/process_name
# --------------------------------------------------------------------------------
# Input Text: start all processes except the one named "worker"
# Actual Command: foreman start -m all=1,{{worker}}=0
# Predicted Command: git start worker_name
# --------------------------------------------------------------------------------
# Input Text: display a tree of processes
# Actual Command: pstree
# Predicted Command: git path/to/process_name path/to/process_name
# --------------------------------------------------------------------------------
# Input Text: display a tree of processes with pids
# Actual Command: pstree -p
# Predicted Command: pids path/to/process_name path/to/process_name
# --------------------------------------------------------------------------------
# Input Text: display all process trees rooted at processes owned by specified user
# Actual Command: pstree {{user}}
# Predicted Command: git path/to/process_name path/to/username
# --------------------------------------------------------------------------------
# Input Text: check quotas on all mounted nonnfs filesystems
# Actual Command: sudo quotacheck --all
# Predicted Command: nfs path/to/file_system
# --------------------------------------------------------------------------------
# Input Text: force check even if quotas are enabled (this can cause damage or loss to quota files)
# Actual Command: sudo quotacheck --force {{mountpoint}}
# Predicted Command: quota-check path/to/file
# --------------------------------------------------------------------------------
# Input Text: check quotas on a given filesystem in debug mode
# Actual Command: sudo quotacheck --debug {{mountpoint}}
# Predicted Command: debug path/to/filesystem
# --------------------------------------------------------------------------------
# Input Text: check quotas on a given filesystem, displaying the progress
# Actual Command: sudo quotacheck --verbose {{mountpoint}}
# Predicted Command: x path/to/file_system
# --------------------------------------------------------------------------------
# Input Text: check user quotas
# Actual Command: sudo quotacheck --user {{user}} {{mountpoint}}
# Predicted Command: pc path/to/user_quota
# --------------------------------------------------------------------------------
# Input Text: check group quotas
# Actual Command: sudo quotacheck --group {{group}} {{mountpoint}}
# Predicted Command: group quotas
# --------------------------------------------------------------------------------
# Input Text: print the mime type of a given file
# Actual Command: mimetype {{path/to/file}}
# Predicted Command: mime path/to/file
# --------------------------------------------------------------------------------
# Input Text: display only the mime type, and not the filename
# Actual Command: mimetype --brief {{path/to/file}}
# Predicted Command: mime path/to/filename
# --------------------------------------------------------------------------------
# Input Text: display a description of the mime type
# Actual Command: mimetype --describe {{path/to/file}}
# Predicted Command: mime path/to/file
# --------------------------------------------------------------------------------
# Input Text: determine the mime type of stdin (does not check a filename)
# Actual Command: {{some_command}} | mimetype --stdin
# Predicted Command: stdin path/to/filename
# --------------------------------------------------------------------------------
# Input Text: display debug information about how the mime type was determined
# Actual Command: mimetype --debug {{path/to/file}}
# Predicted Command: mime path/to/file
# --------------------------------------------------------------------------------
# Input Text: display all the possible mime types of a given file in confidence order
# Actual Command: mimetype --all {{path/to/file}}
# Predicted Command: mime-type path/to/file_name
# --------------------------------------------------------------------------------
# Input Text: explicitly specify the 2letter language code of the output
# Actual Command: mimetype --language {{path/to/file}}
# Predicted Command: git 2letter path/to/file
# --------------------------------------------------------------------------------
# Input Text: list password information for the user
# Actual Command: chage --list {{username}}
# Predicted Command: password list username
# --------------------------------------------------------------------------------
# Input Text: enable password expiration in 10 days
# Actual Command: sudo chage --maxdays {{10}} {{username}}
# Predicted Command: password expiration 10
# --------------------------------------------------------------------------------
# Input Text: disable password expiration
# Actual Command: sudo chage --maxdays {{-1}} {{username}}
# Predicted Command: pc path/to/password_expiration
# --------------------------------------------------------------------------------
# Input Text: set account expiration date
# Actual Command: sudo chage --expiredate {{YYYY-MM-DD}} {{username}}
# Predicted Command: pc username username
# --------------------------------------------------------------------------------
# Input Text: force user to change password on next log in
# Actual Command: sudo chage --lastday {{0}} {{username}}
# Predicted Command: git path/to/path/to/log/in
# --------------------------------------------------------------------------------
# Input Text: tell the kernel about the existence of the specified partition
# Actual Command: addpart {{device}} {{partition}} {{start}} {{length}}
# Predicted Command: git -p path/to/file path/to/file
# --------------------------------------------------------------------------------
# Input Text: run the daemon with a configuration file
# Actual Command: dbus-daemon --config-file {{path/to/file}}
# Predicted Command: daemon -config config
# --------------------------------------------------------------------------------
# Input Text: run the daemon with the standard perloginsession message bus configuration
# Actual Command: dbus-daemon --session
# Predicted Command: perloginsession path/to/path/to/bus
# --------------------------------------------------------------------------------
# Input Text: run the daemon with the standard systemwide message bus configuration
# Actual Command: dbus-daemon --system
# Predicted Command: cd path/to/daemon path/to/daemon
# --------------------------------------------------------------------------------
# Input Text: set the address to listen on and override the configuration value for it
# Actual Command: dbus-daemon --address {{address}}
# Predicted Command: pc path/to/address path/to/address
# --------------------------------------------------------------------------------
# Input Text: output the process id to stdout
# Actual Command: dbus-daemon --print-pid
# Predicted Command: stdout path/to/stdout
# --------------------------------------------------------------------------------
# Input Text: force the message bus to write to the system log for messages
# Actual Command: dbus-daemon --syslog
# Predicted Command: git path/to/system_log path/to/system_log
# --------------------------------------------------------------------------------
# Input Text: view the available firewall zones
# Actual Command: firewall-cmd --get-active-zones
# Predicted Command: git path/to/firewall_zone
# --------------------------------------------------------------------------------
# Input Text: view the rules which are currently applied
# Actual Command: firewall-cmd --list-all
# Predicted Command: git view path/to/file
# --------------------------------------------------------------------------------
# Input Text: permanently move the interface into the block zone, effectively blocking all communication
# Actual Command: firewall-cmd --permanent --zone={{block}} --change-interface={{enp1s0}}
# Predicted Command: git -block -block block
# --------------------------------------------------------------------------------
# Input Text: permanently open the port for a service in the specified zone (like port 443 when in the `public` zone)
# Actual Command: firewall-cmd --permanent --zone={{public}} --add-service={{https}}
# Predicted Command: port path/to/service path/to/service
# --------------------------------------------------------------------------------
# Input Text: permanently close the port for a service in the specified zone (like port 80 when in the `public` zone)
# Actual Command: firewall-cmd --permanent --zone={{public}} --remove-service={{http}}
# Predicted Command: port path/to/service path/to/service
# --------------------------------------------------------------------------------
# Input Text: permanently open two arbitrary ports in the specified zone
# Actual Command: firewall-cmd --permanent --zone={{public}} --add-port={{25565/tcp}} --add-port={{19132/udp}}
# Predicted Command: git path/to/zone
# --------------------------------------------------------------------------------
# Input Text: reload firewalld to force rule changes to take effect
# Actual Command: firewall-cmd --reload
# Predicted Command: git reload path/to/file
# --------------------------------------------------------------------------------
# Input Text: display information for all cpus
# Actual Command: cpuid
# Predicted Command: cpus path/to/cpus
# --------------------------------------------------------------------------------
# Input Text: display information only for the current cpu
# Actual Command: cpuid -1
# Predicted Command: cpu path/to/cpu
# --------------------------------------------------------------------------------
# Input Text: display raw hex information with no decoding
# Actual Command: cpuid -r
# Predicted Command: hex -d path/to/hex
# --------------------------------------------------------------------------------
# Input Text: create a random uuidv4
# Actual Command: uuidgen --random
# Predicted Command: uuidv4 uuidv4
# --------------------------------------------------------------------------------
# Input Text: create a uuidv1 based on the current time
# Actual Command: uuidgen --time
# Predicted Command: uuidv1
# --------------------------------------------------------------------------------
# Input Text: create a uuidv5 of the name with a specified namespace prefix
# Actual Command: uuidgen --sha1 --namespace {{@dns|@url|@oid|@x500}} --name {{object_name}}
# Predicted Command: uuidv5 namespace
# --------------------------------------------------------------------------------
# Input Text: compute and display the wpapsk key for a given ssid reading the passphrase from stdin
# Actual Command: wpa_passphrase {{SSID}}
# Predicted Command: ssid path/to/ssid path/to/ssid
# --------------------------------------------------------------------------------
# Input Text: compute and display wpapsk key for a given ssid specifying the passphrase as an argument
# Actual Command: wpa_passphrase {{SSID}} {{passphrase}}
# Predicted Command: ssid path/to/file.ssid path/to/file.ssid
# --------------------------------------------------------------------------------
# Input Text: display a summary of the top 10 historical uptime records
# Actual Command: uprecords
# Predicted Command: psg path/to/file.psg
# --------------------------------------------------------------------------------
# Input Text: display the top 25 records
# Actual Command: uprecords -m {{25}}
# Predicted Command: pc path/to/file.pc
# --------------------------------------------------------------------------------
# Input Text: display the downtime between reboots instead of the kernel version
# Actual Command: uprecords -d
# Predicted Command: git path/to/remote_time
# --------------------------------------------------------------------------------
# Input Text: show the most recent reboots
# Actual Command: uprecords -B
# Predicted Command: git show reboot
# --------------------------------------------------------------------------------
# Input Text: don't truncate information
# Actual Command: uprecords -w
# Predicted Command: truncate path/to/file
# --------------------------------------------------------------------------------
# Input Text: change the line endings of a file
# Actual Command: dos2unix {{filename}}
# Predicted Command: sh path/to/file
# --------------------------------------------------------------------------------
# Input Text: create a copy with unixstyle line endings
# Actual Command: dos2unix -n {{filename}} {{new_filename}}
# Predicted Command: unixstyle file_name
# --------------------------------------------------------------------------------
# Input Text: check a btrfs filesystem
# Actual Command: sudo btrfs check {{path/to/partition}}
# Predicted Command: btrfs path/to/file
# --------------------------------------------------------------------------------
# Input Text: check and repair a btrfs filesystem (dangerous)
# Actual Command: sudo btrfs check --repair {{path/to/partition}}
# Predicted Command: btrfs path/to/file_system
# --------------------------------------------------------------------------------
# Input Text: show the progress of the check
# Actual Command: sudo btrfs check --progress {{path/to/partition}}
# Predicted Command: git path/to/check
# --------------------------------------------------------------------------------
# Input Text: verify the checksum of each data block (if the filesystem is good)
# Actual Command: sudo btrfs check --check-data-csum {{path/to/partition}}
# Predicted Command: git path/to/data_block path/to/data_block
# --------------------------------------------------------------------------------
# Input Text: use the `n`th superblock (`n` can be 0, 1 or 2)
# Actual Command: sudo btrfs check --super {{n}} {{path/to/partition}}
# Predicted Command: nth superblock n
# --------------------------------------------------------------------------------
# Input Text: rebuild the checksum tree
# Actual Command: sudo btrfs check --repair --init-csum-tree {{path/to/partition}}
# Predicted Command: checksum rebuild
# --------------------------------------------------------------------------------
# Input Text: rebuild the extent tree
# Actual Command: sudo btrfs check --repair --init-extent-tree {{path/to/partition}}
# Predicted Command: bb path/to/project_name
# --------------------------------------------------------------------------------
# Input Text: list all available playback targets
# Actual Command: pw-play --list-targets
# Predicted Command: playback list path/to/target
# --------------------------------------------------------------------------------
# Input Text: play a wav sound file over the default target
# Actual Command: pw-play {{path/to/file.wav}}
# Predicted Command: wav path/to/file path/to/file
# --------------------------------------------------------------------------------
# Input Text: play a wav sound file at a different volume level
# Actual Command: pw-play --volume={{0.1}} {{path/to/file.wav}}
# Predicted Command: wav path/to/file path/to/file
# --------------------------------------------------------------------------------
# Input Text: generate a permuted index where the first field of each line is an index reference
# Actual Command: ptx --references {{path/to/file}}
# Predicted Command: git path/to/file path/to/file
# --------------------------------------------------------------------------------
# Input Text: generate a permuted index with automatically generated index references
# Actual Command: ptx --auto-reference {{path/to/file}}
# Predicted Command: git path/to/index_name
# --------------------------------------------------------------------------------
# Input Text: generate a permuted index with a fixed width
# Actual Command: ptx --width={{width_in_columns}} {{path/to/file}}
# Predicted Command: git path/to/index path/to/index
# --------------------------------------------------------------------------------
# Input Text: generate a permuted index with a list of filtered words
# Actual Command: ptx --only-file={{path/to/filter}} {{path/to/file}}
# Predicted Command: git path/to/index path/to/index
# --------------------------------------------------------------------------------
# Input Text: generate a permuted index with sysvstyle behaviors
# Actual Command: ptx --traditional {{path/to/file}}
# Predicted Command: sysvstyle path/to/index.sysv
# --------------------------------------------------------------------------------
# Input Text: perform a dry run (print what would be done without actually doing it)
# Actual Command: mkinitcpio
# Predicted Command: pc path/to/file.pc
# --------------------------------------------------------------------------------
# Input Text: generate a ramdisk environment based on the `linux` preset
# Actual Command: mkinitcpio --preset {{linux}}
# Predicted Command: ramdisk -s linux
# --------------------------------------------------------------------------------
# Input Text: generate a ramdisk environment based on the `linuxlts` preset
# Actual Command: mkinitcpio --preset {{linux-lts}}
# Predicted Command: ramdisk -s linuxlts
# --------------------------------------------------------------------------------
# Input Text: generate ramdisk environments based on all existing presets (used to regenerate all the initramfs images after a change in `/etc/mkinitcpio.conf`)
# Actual Command: mkinitcpio --allpresets
# Predicted Command: ramdisk path/to/path/to/path/to/path/to/path/to/path/to/path/to/path/to/mkinitcpio.conf
# --------------------------------------------------------------------------------
# Input Text: generate an initramfs image using an alternative configuration file
# Actual Command: mkinitcpio --config {{path/to/mkinitcpio.conf}} --generate {{path/to/initramfs.img}}
# Predicted Command: initramfs path/to/image
# --------------------------------------------------------------------------------
# Input Text: generate an initramfs image for a kernel other than the one currently running (the installed kernel releases can be found in `/usr/lib/modules/`)
# Actual Command: mkinitcpio --kernel {{kernel_version}} --generate {{path/to/initramfs.img}}
# Predicted Command: initramfs path/to/initramfs
# --------------------------------------------------------------------------------
# Input Text: list all available hooks
# Actual Command: mkinitcpio --listhooks
# Predicted Command: hook path/to/ hooks
# --------------------------------------------------------------------------------
# Input Text: display help for a specific hook
# Actual Command: mkinitcpio --hookhelp {{hook_name}}
# Predicted Command: hook path/to/ hook
# --------------------------------------------------------------------------------
# Input Text: check cluster health status
# Actual Command: ceph status
# Predicted Command: cluster health status path/to/file
# --------------------------------------------------------------------------------
# Input Text: check cluster usage stats
# Actual Command: ceph df
# Predicted Command: cctv ctv ctv
# --------------------------------------------------------------------------------
# Input Text: get the statistics for the placement groups in a cluster
# Actual Command: ceph pg dump --format {{plain}}
# Predicted Command: git path/to/group_name
# --------------------------------------------------------------------------------
# Input Text: create a storage pool
# Actual Command: ceph osd pool create {{pool_name}} {{page_number}}
# Predicted Command: git -pool path/to/file_pool
# --------------------------------------------------------------------------------
# Input Text: delete a storage pool
# Actual Command: ceph osd pool delete {{pool_name}}
# Predicted Command: git delete path/to/file
# --------------------------------------------------------------------------------
# Input Text: rename a storage pool
# Actual Command: ceph osd pool rename {{current_name}} {{new_name}}
# Predicted Command: git rename path/to/pool
# --------------------------------------------------------------------------------
# Input Text: selfrepair pool storage
# Actual Command: ceph pg repair {{pool_name}}
# Predicted Command: pc -p path/to/file path/to/file
# --------------------------------------------------------------------------------
# Input Text: create new user
# Actual Command: useradd {{name}}
# Predicted Command: git create username
# --------------------------------------------------------------------------------
# Input Text: create new user with a default home directory
# Actual Command: useradd --create-home {{name}}
# Predicted Command: git path/to/home_directory
# --------------------------------------------------------------------------------
# Input Text: create new user with specified shell
# Actual Command: useradd --shell {{path/to/shell}} {{name}}
# Predicted Command: shell username username
# --------------------------------------------------------------------------------
# Input Text: create new user belonging to additional groups (mind the lack of whitespace)
# Actual Command: useradd --groups {{group1,group2}} {{name}}
# Predicted Command: git create username groupname
# --------------------------------------------------------------------------------
# Input Text: create new system user without a home directory
# Actual Command: useradd --no-create-home --system {{name}}
# Predicted Command: git path/to/system_user
# --------------------------------------------------------------------------------
# Input Text: open the terminal with a title of `example`
# Actual Command: xterm -T {{Example}}
# Predicted Command: gp example example
# --------------------------------------------------------------------------------
# Input Text: open the terminal in fullscreen mode
# Actual Command: xterm -fullscreen
# Predicted Command: sh path/to/sh
# --------------------------------------------------------------------------------
# Input Text: open the terminal with a dark blue background and yellow foreground (font color)
# Actual Command: xterm -bg {{darkblue}} -fg {{yellow}}
# Predicted Command: font-color font_color
# --------------------------------------------------------------------------------
# Input Text: open the terminal with 100 characters per line and 35 lines, in screen position x=200px, y=20px
# Actual Command: xterm -geometry {{100}}x{{35}}+{{200}}+{{20}}
# Predicted Command: x=200px, y=20px
# --------------------------------------------------------------------------------
# Input Text: open the terminal using a serif font and a font size equal to 20
# Actual Command: xterm -fa {{'Serif'}} -fs {{20}}
# Predicted Command: serif path/to/file
# --------------------------------------------------------------------------------

# %%
# Load dataset and select the 'train' split
dataset = load_dataset("neulab/tldr", split='test')

# Iterate over the first 10 entries of the train split
for i in range(100):
    input_text = dataset[i]['nl']  # Natural language instruction
    actual_command = dataset[i]['cmd']  # Corresponding command
    predicted_command = translate_to_command(input_text, tokenizer, model)

    print(f"Input Text: {input_text}")
    print(f"Actual Command: {actual_command}")
    print(f"Predicted Command: {predicted_command}")
    print("-" * 80)  # Separator for readability
# Out:
# Input Text: delete a shared memory segment by id
# Actual Command: ipcrm --shmem-id {{shmem_id}}
# Predicted Command: id path/to/segment
# --------------------------------------------------------------------------------
# Input Text: delete a shared memory segment by key
# Actual Command: ipcrm --shmem-key {{shmem_key}}
# Predicted Command: cd path/to/segment path/to/segment
# --------------------------------------------------------------------------------
# Input Text: delete an ipc queue by id
# Actual Command: ipcrm --queue-id {{ipc_queue_id}}
# Predicted Command: ipc path/to/file path/to/file
# --------------------------------------------------------------------------------
# Input Text: delete an ipc queue by key
# Actual Command: ipcrm --queue-key {{ipc_queue_key}}
# Predicted Command: ipc path/to/file path/to/file
# --------------------------------------------------------------------------------
# Input Text: delete a semaphore by id
# Actual Command: ipcrm --semaphore-id {{semaphore_id}}
# Predicted Command: semaphore path/to/semaphore
# --------------------------------------------------------------------------------
# Input Text: delete a semaphore by key
# Actual Command: ipcrm --semaphore-key {{semaphore_key}}
# Predicted Command: semaphore key
# --------------------------------------------------------------------------------
# Input Text: delete all ipc resources
# Actual Command: ipcrm --all
# Predicted Command: ipc path/to/ipc
# --------------------------------------------------------------------------------
# Input Text: retrieve the xwindows window id of the running firefox window(s)
# Actual Command: xdotool search --onlyvisible --name {{firefox}}
# Predicted Command: xwindows path/to/directory
# --------------------------------------------------------------------------------
# Input Text: click the right mouse button
# Actual Command: xdotool click {{3}}
# Predicted Command: pcc path/to/file
# --------------------------------------------------------------------------------
# Input Text: get the id of the currently active window
# Actual Command: xdotool getactivewindow
# Predicted Command: git path/to/directory
# --------------------------------------------------------------------------------
# Input Text: focus on the window with id of 12345
# Actual Command: xdotool windowfocus --sync {{12345}}
# Predicted Command: 12345 path/to/directory
# --------------------------------------------------------------------------------
# Input Text: type a message, with a 500ms delay for each letter
# Actual Command: xdotool type --delay {{500}} "Hello world"
# Predicted Command: ms path/to/file path/to/file.ms
# --------------------------------------------------------------------------------
# Input Text: press the enter key
# Actual Command: xdotool key {{KP_Enter}}
# Predicted Command: enter key -d key
# --------------------------------------------------------------------------------
# Input Text: display all information about the elf file
# Actual Command: readelf -all {{path/to/binary}}
# Predicted Command: elf path/to/file
# --------------------------------------------------------------------------------
# Input Text: display all the headers present in the elf file
# Actual Command: readelf --headers {{path/to/binary}}
# Predicted Command: elf path/to/file
# --------------------------------------------------------------------------------
# Input Text: display the entries in symbol table section of the elf file, if it has one
# Actual Command: readelf --symbols {{path/to/binary}}
# Predicted Command: elf path/to/file
# --------------------------------------------------------------------------------
# Input Text: display the information contained in the elf header at the start of the file
# Actual Command: readelf --file-header {{path/to/binary}}
# Predicted Command: elf path/to/file
# --------------------------------------------------------------------------------
# Input Text: generate a random uuid
# Actual Command: uuidd --random
# Predicted Command: uuid uuid
# --------------------------------------------------------------------------------
# Input Text: generate a bulk number of random uuids
# Actual Command: uuidd --random --uuids {{number_of_uuids}}
# Predicted Command: uuid -g uuid
# --------------------------------------------------------------------------------
# Input Text: generate a timebased uuid, based on the current time and mac address of the system
# Actual Command: uuidd --time
# Predicted Command: uuid path/to/time
# --------------------------------------------------------------------------------
# Input Text: edit action can be used to view any file on default mailcap explorer
# Actual Command: edit {{filename}}
# Predicted Command: mailcap path/to/file
# --------------------------------------------------------------------------------
# Input Text: with `runmailcap`
# Actual Command: run-mailcap --action=edit {{filename}}
# Predicted Command: git runmailcap
# --------------------------------------------------------------------------------
# Input Text: display the search path used to find man pages
# Actual Command: manpath
# Predicted Command: git path/to/man_page path/to/man_page
# --------------------------------------------------------------------------------
# Input Text: show the entire global manpath
# Actual Command: manpath --global
# Predicted Command: manpath path/to/path/to/path/to/path/to/path/to/path
# --------------------------------------------------------------------------------
# Input Text: install a service
# Actual Command: update-rc.d {{mysql}} defaults
# Predicted Command: git install service
# --------------------------------------------------------------------------------
# Input Text: enable a service
# Actual Command: update-rc.d {{mysql}} enable
# Predicted Command: git enable service
# --------------------------------------------------------------------------------
# Input Text: disable a service
# Actual Command: update-rc.d {{mysql}} disable
# Predicted Command: sh -d service
# --------------------------------------------------------------------------------
# Input Text: forcibly remove a service
# Actual Command: update-rc.d -f {{mysql}} remove
# Predicted Command: git remove service service
# --------------------------------------------------------------------------------
# Input Text: submit a batch job
# Actual Command: sbatch {{path/to/job.sh}}
# Predicted Command: tv -s job_name
# --------------------------------------------------------------------------------
# Input Text: submit a batch job with a custom name
# Actual Command: sbatch --job-name={{myjob}} {{path/to/job.sh}}
# Predicted Command: git -name job_name
# --------------------------------------------------------------------------------
# Input Text: submit a batch job with a time limit of 30 minutes
# Actual Command: sbatch --time={{00:30:00}} {{path/to/job.sh}}
# Predicted Command: sh -s job_name job_name
# --------------------------------------------------------------------------------
# Input Text: submit a job and request multiple nodes
# Actual Command: sbatch --nodes={{3}} {{path/to/job.sh}}
# Predicted Command: git -job job_name
# --------------------------------------------------------------------------------
# Input Text: create a new linux group
# Actual Command: groupadd {{group_name}}
# Predicted Command: linux -group group
# --------------------------------------------------------------------------------
# Input Text: create new group with a specific groupid
# Actual Command: groupadd {{group_name}} -g {{group_id}}
# Predicted Command: groupid groupid
# --------------------------------------------------------------------------------
# Input Text: list all containers (running and stopped)
# Actual Command: ctr containers list
# Predicted Command: git list path/to/container
# --------------------------------------------------------------------------------
# Input Text: list all images
# Actual Command: ctr images list
# Predicted Command: sh -list path/to/image
# --------------------------------------------------------------------------------
# Input Text: pull an image
# Actual Command: ctr images pull {{image}}
# Predicted Command: git pull image
# --------------------------------------------------------------------------------
# Input Text: tag an image
# Actual Command: ctr images tag {{souce_image}}:{{source_tag}} {{target_image}}:{{target_tag}}
# Predicted Command: git tag image
# --------------------------------------------------------------------------------
# Input Text: log in as a user
# Actual Command: login {{user}}
# Predicted Command: log-in username
# --------------------------------------------------------------------------------
# Input Text: log in as user without authentication if user is preauthenticated
# Actual Command: login -f {{user}}
# Predicted Command: git log-in user_name
# --------------------------------------------------------------------------------
# Input Text: log in as user and preserve environment
# Actual Command: login -p {{user}}
# Predicted Command: log in as user and preserve environment
# --------------------------------------------------------------------------------
# Input Text: log in as a user on a remote host
# Actual Command: login -h {{host}} {{user}}
# Predicted Command: git log-in user_name
# --------------------------------------------------------------------------------
# Input Text: print a summary of cpu, memory, hard drive and kernel information
# Actual Command: inxi
# Predicted Command: cpu --resume path/to/file
# --------------------------------------------------------------------------------
# Input Text: print a full description of cpu, memory, disk, network and process information
# Actual Command: inxi -Fz
# Predicted Command: cpu path/to/file.cpu path/to/file.cpu
# --------------------------------------------------------------------------------
# Input Text: print information about the distribution's repository
# Actual Command: inxi -r
# Predicted Command: git path/to/repository path/to/repository
# --------------------------------------------------------------------------------
# Input Text: return the current vmware software version (exit status determines whether the system is a vm or not)
# Actual Command: vmware-checkvm
# Predicted Command: vmware path/to/file path/to/file.vm
# --------------------------------------------------------------------------------
# Input Text: return the vmware hardware version
# Actual Command: vmware-checkvm -h
# Predicted Command: vmware --device device
# --------------------------------------------------------------------------------
# Input Text: enable a virtual host
# Actual Command: sudo a2ensite {{virtual_host}}
# Predicted Command: git -host host_name
# --------------------------------------------------------------------------------
# Input Text: don't show informative messages
# Actual Command: sudo a2ensite --quiet {{virtual_host}}
# Predicted Command: cd path/to/file.cd
# --------------------------------------------------------------------------------
# Input Text: submit a basic interactive job
# Actual Command: srun --pty /bin/bash
# Predicted Command: git submit job
# --------------------------------------------------------------------------------
# Input Text: submit an interactive job with different attributes
# Actual Command: srun --ntasks-per-node={{num_cores}} --mem-per-cpu={{memory_MB}} --pty /bin/bash
# Predicted Command: git submit job_name
# --------------------------------------------------------------------------------
# Input Text: connect to a worker node with a job running
# Actual Command: srun --jobid={{job_id}} --pty /bin/bash
# Predicted Command: cnn path/to/worker_knode
# --------------------------------------------------------------------------------
# Input Text: display the current time as reported by the hardware clock
# Actual Command: hwclock
# Predicted Command: git -clock clock
# --------------------------------------------------------------------------------
# Input Text: write the current software clock time to the hardware clock (sometimes used during system setup)
# Actual Command: hwclock --systohc
# Predicted Command: pc -c clock_time clock_time
# --------------------------------------------------------------------------------
# Input Text: write the current hardware clock time to the software clock
# Actual Command: hwclock --hctosys
# Predicted Command: pc -c clock_time
# --------------------------------------------------------------------------------
# Input Text: connect to a share (user will be prompted for password; `exit` to quit the session)
# Actual Command: smbclient {{//server/share}}
# Predicted Command: git connect share username
# --------------------------------------------------------------------------------
# Input Text: connect with a different username
# Actual Command: smbclient {{//server/share}} --user {{username}}
# Predicted Command: git connect username
# --------------------------------------------------------------------------------
# Input Text: connect with a different workgroup
# Actual Command: smbclient {{//server/share}} --workgroup {{domain}} --user {{username}}
# Predicted Command: git connect workgroup
# --------------------------------------------------------------------------------
# Input Text: connect with a username and password
# Actual Command: smbclient {{//server/share}} --user {{username%password}}
# Predicted Command: git connect username
# --------------------------------------------------------------------------------
# Input Text: download a file from the server
# Actual Command: smbclient {{//server/share}} --directory {{path/to/directory}} --command "get {{file.txt}}"
# Predicted Command: git download path/to/file
# --------------------------------------------------------------------------------
# Input Text: upload a file to the server
# Actual Command: smbclient {{//server/share}} --directory {{path/to/directory}} --command "put {{file.txt}}"
# Predicted Command: git upload filename
# --------------------------------------------------------------------------------
# Input Text: launch xeyes on the local machine's default display
# Actual Command: xeyes
# Predicted Command: xeyes
# --------------------------------------------------------------------------------
# Input Text: launch xeyes on a remote machine's display 0, screen 0
# Actual Command: xeyes -display {{remote_host}}:{{0}}.{{0}}
# Predicted Command: xeyes --screen 0
# --------------------------------------------------------------------------------
# Input Text: delete a file (send to trash)
# Actual Command: trash {{path/to/file}}
# Predicted Command: git delete path/to/file
# --------------------------------------------------------------------------------
# Input Text: list files in trash
# Actual Command: trash-list
# Predicted Command: git list path/to/file
# --------------------------------------------------------------------------------
# Input Text: restore file from trash
# Actual Command: trash-restore
# Predicted Command: git restore file_name
# --------------------------------------------------------------------------------
# Input Text: empty trash
# Actual Command: trash-empty
# Predicted Command: tsh -t tst tst
# --------------------------------------------------------------------------------
# Input Text: empty trash, keeping files trashed less than {{10}} days ago
# Actual Command: trash-empty {{10}}
# Predicted Command: git -t path/to/file
# --------------------------------------------------------------------------------
# Input Text: remove all files named 'foo' from the trash
# Actual Command: trash-rm foo
# Predicted Command: foo remove path/to/file_name
# --------------------------------------------------------------------------------
# Input Text: remove all files with a given original location
# Actual Command: trash-rm {{/absolute/path/to/file_or_directory}}
# Predicted Command: git remove path/to/file
# --------------------------------------------------------------------------------
# Input Text: capture a screenshot and save it to the current directory with the current date as the filename
# Actual Command: scrot
# Predicted Command: git capture path/to/directory
# --------------------------------------------------------------------------------
# Input Text: capture a screenshot and save it as `capture.png`
# Actual Command: scrot {{capture.png}}
# Predicted Command: png capture capture.png
# --------------------------------------------------------------------------------
# Input Text: capture a screenshot interactively
# Actual Command: scrot --select
# Predicted Command: pc path/to/screenshot
# --------------------------------------------------------------------------------
# Input Text: capture a screenshot from the currently focused window
# Actual Command: scrot --focused
# Predicted Command: sh -s path/to/screenshot
# --------------------------------------------------------------------------------
# Input Text: display a countdown of 10 seconds before taking a screenshot
# Actual Command: scrot --count --delay {{10}}
# Predicted Command: tv path/to/screen path/to/screenshot
# --------------------------------------------------------------------------------
# Input Text: show a brief list of devices
# Actual Command: lspci
# Predicted Command: git show path/to/device path/to/device
# --------------------------------------------------------------------------------
# Input Text: display additional info
# Actual Command: lspci -v
# Predicted Command: git path/to/info
# --------------------------------------------------------------------------------
# Input Text: display drivers and modules handling each device
# Actual Command: lspci -k
# Predicted Command: git path/to/device path/to/device
# --------------------------------------------------------------------------------
# Input Text: show a specific device
# Actual Command: lspci -s {{00:18.3}}
# Predicted Command: git show path/to/device
# --------------------------------------------------------------------------------
# Input Text: dump info in a readable form
# Actual Command: lspci -vm
# Predicted Command: git dump path/to/file
# --------------------------------------------------------------------------------
# Input Text: resolve a hostname to an ip address
# Actual Command: resolveip {{example.org}}
# Predicted Command: ip path/to/hostname
# --------------------------------------------------------------------------------
# Input Text: resolve an ip address to a hostname
# Actual Command: resolveip {{1.1.1.1}}
# Predicted Command: ip path/to/hostname
# --------------------------------------------------------------------------------
# Input Text: silent mode. produces less output
# Actual Command: resolveip --silent {{example.org}}
# Predicted Command: pc path/to/file path/to/file
# --------------------------------------------------------------------------------
# Input Text: reserve a file taking up 700 mib of disk space
# Actual Command: fallocate --length {{700M}} {{path/to/file}}
# Predicted Command: git reserve path/to/file
# --------------------------------------------------------------------------------
# Input Text: shrink an already allocated file by 200 mib
# Actual Command: fallocate --collapse-range --length {{200M}} {{path/to/file}}
# Predicted Command: git shrink path/to/file
# --------------------------------------------------------------------------------
# Input Text: shrink 20 mb of space after 100 mib in a file
# Actual Command: fallocate --collapse-range --offset {{100M}} --length {{20M}} {{path/to/file}}
# Predicted Command: git shrink 20 mb of space after 100 mib in a file
# --------------------------------------------------------------------------------
# Input Text: make a file or directory immutable to changes and deletion, even by superuser
# Actual Command: chattr +i {{path/to/file_or_directory}}
# Predicted Command: superuser path/to/file/directory
# --------------------------------------------------------------------------------
# Input Text: make a file or directory mutable
# Actual Command: chattr -i {{path/to/file_or_directory}}
# Predicted Command: git path/to/directory
# --------------------------------------------------------------------------------
# Input Text: recursively make an entire directory and contents immutable
# Actual Command: chattr -R +i {{path/to/directory}}
# Predicted Command: recursive path/to/directory path/to/directory
# --------------------------------------------------------------------------------
# Input Text: check filesystem, reporting any damaged blocks
# Actual Command: e2fsck {{/dev/sdXN}}
# Predicted Command: git check path/to/filesystem
# --------------------------------------------------------------------------------
# Input Text: check filesystem and automatically repair any damaged blocks
# Actual Command: e2fsck -p {{/dev/sdXN}}
# Predicted Command: git check path/to/filesystem
# --------------------------------------------------------------------------------
# Input Text: check filesystem in read only mode
# Actual Command: e2fsck -c {{/dev/sdXN}}
# Predicted Command: git check path/to/filesystem
# --------------------------------------------------------------------------------
# Input Text: launch virtmanager
# Actual Command: virt-manager
# Predicted Command: virtmanager
# --------------------------------------------------------------------------------
# Input Text: connect to a hypervisor
# Actual Command: virt-manager --connect {{hypervisor_uri}}
# Predicted Command: hypervisor connect
# --------------------------------------------------------------------------------
# Input Text: don't fork virtmanager process into background on startup
# Actual Command: virt-manager --no-fork
# Predicted Command: virtmanager path/to/file
# --------------------------------------------------------------------------------
# Input Text: print debug output
# Actual Command: virt-manager --debug
# Predicted Command: debug output
# --------------------------------------------------------------------------------
# Input Text: open the "new vm" wizard
# Actual Command: virt-manager --show-domain-creator
# Predicted Command: vm new vm
# --------------------------------------------------------------------------------
# Input Text: show domain details window
# Actual Command: virt-manager --show-domain-editor {{name|id|uuid}}
# Predicted Command: git path/to/directory
# --------------------------------------------------------------------------------
# Input Text: show domain performance window
# Actual Command: virt-manager --show-domain-performance {{name|id|uuid}}
# Predicted Command: git path/to/directory
# --------------------------------------------------------------------------------
# Input Text: show connection details window
# Actual Command: virt-manager --show-host-summary
# Predicted Command: git path/to/directory
# --------------------------------------------------------------------------------
