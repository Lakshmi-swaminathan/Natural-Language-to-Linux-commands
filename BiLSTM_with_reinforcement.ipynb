# %%
# !pip install tensorflow tensorflow-text datasets nltk rouge pydot graphviz
import nltk
nltk.download('punkt')
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting tensorflow-text
#   Downloading tensorflow_text-2.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 39.8 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.19.0-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 37.7 MB/s eta 0:00:00
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: pydot in /usr/local/lib/python3.10/dist-packages (1.4.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (0.20.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Collecting tensorflow
#   Downloading tensorflow-2.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (589.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 1.8 MB/s eta 0:00:00
# Collecting h5py>=3.10.0 (from tensorflow)
#   Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 49.9 MB/s eta 0:00:00
# Collecting ml-dtypes~=0.3.1 (from tensorflow)
#   Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 78.9 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.31.0)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow)
#   Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 97.1 MB/s eta 0:00:00
# Collecting keras>=3.0.0 (from tensorflow)
#   Downloading keras-3.3.3-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 57.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.7 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Collecting huggingface-hub>=0.21.2 (from datasets)
#   Downloading huggingface_hub-0.22.2-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 28.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from pydot) (3.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.0.0->tensorflow) (13.7.1)
# Collecting namex (from keras>=3.0.0->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Collecting optree (from keras>=3.0.0->tensorflow)
#   Downloading optree-0.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.0.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.0.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.2)
# Installing collected packages: namex, xxhash, rouge, optree, ml-dtypes, h5py, dill, tensorboard, multiprocess, huggingface-hub, keras, tensorflow, datasets, tensorflow-text
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.16.1 which is incompatible.
# Successfully installed datasets-2.19.0 dill-0.3.8 h5py-3.11.0 huggingface-hub-0.22.2 keras-3.3.3 ml-dtypes-0.3.2 multiprocess-0.70.16 namex-0.0.8 optree-0.11.0 rouge-1.0.1 tensorboard-2.16.2 tensorflow-2.16.1 tensorflow-text-2.16.1 xxhash-3.4.1
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, TimeDistributed, Concatenate, Dropout, Bidirectional, MultiHeadAttention
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np
import os
import pickle
from google.colab import drive
from datasets import load_dataset
from nltk.translate.bleu_score import sentence_bleu
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.optimizers import Adam
from nltk.translate import bleu_score

# %%
# Mount Google Drive
drive.mount('/content/drive')
model_path = '/content/drive/My Drive/model_BiLSTM_word_reinforcement.h5'
history_path = '/content/drive/My Drive/history_BiLSTM_word_reinforcement.pkl'
# Out:
# Mounted at /content/drive

# %%
# Load dataset
dataset = load_dataset("neulab/tldr", split='train')

# Append <start> and <end> tokens to cmd_texts
cmd_texts = ["<start> " + item['cmd'] + " <end>" for item in dataset]

# Combine nl_texts and cmd_texts for tokenizer fitting
nl_texts = [item['nl'] for item in dataset]
all_texts = nl_texts + cmd_texts

# Initialize and fit tokenizer
tokenizer = Tokenizer(filters='', lower=True, split=' ')
tokenizer.fit_on_texts(all_texts)
vocab_size = len(tokenizer.word_index) + 1  # +1 for zero padding

# Prepare sequences
nl_sequences = tokenizer.texts_to_sequences(nl_texts)
cmd_sequences = tokenizer.texts_to_sequences(cmd_texts)

# Determine maximum sequence length
max_length = max(max(len(seq) for seq in nl_sequences), max(len(seq) for seq in cmd_sequences))

# Pad sequences
nl_sequences_padded = pad_sequences(nl_sequences, maxlen=max_length, padding='post')
cmd_sequences_padded = pad_sequences(cmd_sequences, maxlen=max_length, padding='post')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1486: FutureWarning: The repository for neulab/tldr contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/neulab/tldr
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/4.92k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/2.97k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.76M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.28M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]

# %%
# Prepare decoder input data and target data
decoder_input_data = np.zeros_like(cmd_sequences_padded)
decoder_input_data[:, 1:] = cmd_sequences_padded[:, :-1]

# RL Training Setup
optimizer = Adam(learning_rate=1e-3)
epochs = 200
batch_size = 64
def build_model(vocab_size, max_length):
    # Define the dimensionality of the embedding and LSTM units
    embedding_dim = 256
    lstm_units = 256

    # Encoder
    encoder_inputs = Input(shape=(None,), name='encoder_inputs')
    encoder_embedding = Embedding(input_dim=vocab_size, output_dim=embedding_dim, name='encoder_embedding')(encoder_inputs)
    encoder_lstm = Bidirectional(LSTM(lstm_units, return_sequences=True, return_state=True, name='encoder_lstm'), name='bidirectional_encoder')
    encoder_outputs, forward_h, forward_c, backward_h, backward_c = encoder_lstm(encoder_embedding)

    # Since we are using a bidirectional LSTM, we need to concatenate the final states
    state_h = Concatenate(name='encoder_state_h')([forward_h, backward_h])
    state_c = Concatenate(name='encoder_state_c')([forward_c, backward_c])

    # Decoder
    decoder_inputs = Input(shape=(None,), name='decoder_inputs')
    decoder_embedding = Embedding(input_dim=vocab_size, output_dim=embedding_dim, name='decoder_embedding')(decoder_inputs)
    decoder_lstm = LSTM(2 * lstm_units, return_sequences=True, return_state=True, name='decoder_lstm')
    decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=[state_h, state_c])

    # Attention
    attention_layer = MultiHeadAttention(num_heads=4, key_dim=2 * lstm_units, name='multihead_attention')
    attention_output = attention_layer(query=decoder_outputs, key=encoder_outputs, value=encoder_outputs)

    # Concatenate attention input and decoder LSTM output
    decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attention_output])

    # Dense layer to predict each word probability
    dense_output = TimeDistributed(Dense(vocab_size, activation='softmax'), name='output_dense')(decoder_concat_input)

    # Define the model
    model = Model(inputs=[encoder_inputs, decoder_inputs], outputs=dense_output)

    # Compile the model with a suitable optimizer, loss, and metric
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    model.summary()  # Show model architecture

    return model

# %%
# Load or create model
if os.path.exists(model_path):
    print("Loading existing model...")
    model = load_model(model_path)
else:
    print("Creating new model...")
    # [Insert model architecture here, similar to what you've defined]
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    model.summary()

# Define the RL training function
import tensorflow as tf
from nltk.translate import bleu_score

def rl_training_step(input_seqs, target_seqs, model, tokenizer, optimizer):
    with tf.GradientTape() as tape:
        predictions = model([input_seqs, np.zeros_like(input_seqs)], training=True)
        loss = tf.keras.losses.sparse_categorical_crossentropy(target_seqs, predictions, from_logits=False)
        avg_loss = tf.reduce_mean(loss)  # Average over batch and sequence

    grads = tape.gradient(avg_loss, model.trainable_variables)
    if not grads or any(g is None for g in grads):
        print("No gradients were calculated. Check the loss computation.")
        return None, None  # Return None for both rewards and loss

    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return tf.reduce_mean(loss).numpy(), avg_loss.numpy()  # Dummy reward, actual loss


# Create and compile model as before
model = build_model(vocab_size, max_length)
optimizer = Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# Creating new model...
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ encoder_inputs            │ (None, None)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_embedding         │ (None, None, 256)      │      3,058,688 │ encoder_inputs[0][0]   │
# │ (Embedding)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ decoder_inputs            │ (None, None)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bidirectional_encoder     │ [(None, None, 512),    │      1,050,624 │ encoder_embedding[0][… │
# │ (Bidirectional)           │ (None, 256), (None,    │                │                        │
# │                           │ 256), (None, 256),     │                │                        │
# │                           │ (None, 256)]           │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ decoder_embedding         │ (None, None, 256)      │      3,058,688 │ decoder_inputs[0][0]   │
# │ (Embedding)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_state_h           │ (None, 512)            │              0 │ bidirectional_encoder… │
# │ (Concatenate)             │                        │                │ bidirectional_encoder… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_state_c           │ (None, 512)            │              0 │ bidirectional_encoder… │
# │ (Concatenate)             │                        │                │ bidirectional_encoder… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ decoder_lstm (LSTM)       │ [(None, None, 512),    │      1,574,912 │ decoder_embedding[0][… │
# │                           │ (None, 512), (None,    │                │ encoder_state_h[0][0], │
# │                           │ 512)]                  │                │ encoder_state_c[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multihead_attention       │ (None, None, 512)      │      4,200,960 │ bidirectional_encoder… │
# │ (MultiHeadAttention)      │                        │                │ decoder_lstm[0][0],    │
# │                           │                        │                │ bidirectional_encoder… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concat_layer              │ (None, None, 1024)     │              0 │ decoder_lstm[0][0],    │
# │ (Concatenate)             │                        │                │ multihead_attention[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_dense              │ (None, None, 11948)    │     12,246,700 │ concat_layer[0][0]     │
# │ (TimeDistributed)         │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 25,190,572 (96.09 MB)
#  Trainable params: 25,190,572 (96.09 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ encoder_inputs            │ (None, None)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_embedding         │ (None, None, 256)      │      3,058,688 │ encoder_inputs[0][0]   │
# │ (Embedding)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ decoder_inputs            │ (None, None)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bidirectional_encoder     │ [(None, None, 512),    │      1,050,624 │ encoder_embedding[0][… │
# │ (Bidirectional)           │ (None, 256), (None,    │                │                        │
# │                           │ 256), (None, 256),     │                │                        │
# │                           │ (None, 256)]           │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ decoder_embedding         │ (None, None, 256)      │      3,058,688 │ decoder_inputs[0][0]   │
# │ (Embedding)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_state_h           │ (None, 512)            │              0 │ bidirectional_encoder… │
# │ (Concatenate)             │                        │                │ bidirectional_encoder… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_state_c           │ (None, 512)            │              0 │ bidirectional_encoder… │
# │ (Concatenate)             │                        │                │ bidirectional_encoder… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ decoder_lstm (LSTM)       │ [(None, None, 512),    │      1,574,912 │ decoder_embedding[0][… │
# │                           │ (None, 512), (None,    │                │ encoder_state_h[0][0], │
# │                           │ 512)]                  │                │ encoder_state_c[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multihead_attention       │ (None, None, 512)      │      4,200,960 │ bidirectional_encoder… │
# │ (MultiHeadAttention)      │                        │                │ decoder_lstm[0][0],    │
# │                           │                        │                │ bidirectional_encoder… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concat_layer              │ (None, None, 1024)     │              0 │ decoder_lstm[0][0],    │
# │ (Concatenate)             │                        │                │ multihead_attention[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_dense              │ (None, None, 11948)    │     12,246,700 │ concat_layer[0][0]     │
# │ (TimeDistributed)         │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 25,190,572 (96.09 MB)
#  Trainable params: 25,190,572 (96.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Training loop with early stopping and checkpointing
best_bleu = 0
patience = 5
wait = 0
for epoch in range(epochs):
    indices = np.random.permutation(len(nl_sequences_padded))
    t_rewards = []
    t_losses = []
    for i in range(0, len(nl_sequences_padded), batch_size):
        batch_indices = indices[i:i + batch_size]
        rewards, loss = rl_training_step(
            nl_sequences_padded[batch_indices],
            cmd_sequences_padded[batch_indices],
            model,
            tokenizer,
            optimizer
        )
        if rewards is not None and loss is not None:
            t_rewards.append(rewards)
            t_losses.append(loss)
        else:
            print("Skipping batch due to gradient issues.")

    if t_losses:  # Check if there were any successful batches
        avg_reward = np.mean(t_rewards)
        avg_loss = np.mean(t_losses)
        print(f"Epoch {epoch+1}: Average Reward = {avg_reward}, Loss = {avg_loss}")
        if avg_reward > best_bleu:
            best_bleu = avg_reward
            model.save(model_path)
            print(f"New best model saved with BLEU score: {best_bleu}")
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                print("Early stopping...")
                break
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: Average Reward = 1.4233031272888184, Loss = 1.4233031272888184
# New best model saved with BLEU score: 1.4233031272888184
# Epoch 2: Average Reward = 0.944885790348053, Loss = 0.944885790348053
# Epoch 3: Average Reward = 0.887574315071106, Loss = 0.887574315071106
# Epoch 4: Average Reward = 0.8452404737472534, Loss = 0.8452404737472534
# Epoch 5: Average Reward = 0.8118176460266113, Loss = 0.8118176460266113
# Epoch 6: Average Reward = 0.757774293422699, Loss = 0.757774293422699
# Early stopping...

# %%
def translate(model, tokenizer, text, max_length):
    # Tokenize the input text
    sequence = tokenizer.texts_to_sequences([text])
    sequence_padded = pad_sequences(sequence, maxlen=max_length, padding='post')

    # Prepare the decoder input data
    decoder_input_data = np.zeros_like(sequence_padded)
    decoder_input_data[:, 1:] = sequence_padded[:, :-1]

    # Predict
    prediction = model.predict([sequence_padded, decoder_input_data])

    # Convert prediction to text
    predicted_sequence = np.argmax(prediction[0], axis=-1)
    predicted_text = tokenizer.sequences_to_texts([predicted_sequence])

    # Remove the <start> and <end> tokens
    predicted_text_clean = [token for token in predicted_text[0].split() if token not in ['<start>', '<end>']]

    # Join the tokens back together
    predicted_command = ' '.join(predicted_text_clean)

    return predicted_command

# %%
# Get the first 10 rows of the training dataset
first_10_nl_texts = nl_texts[:100]
first_10_cmd_texts = cmd_texts[:100]

# Translate each text and print the input, prediction, and actual command
for i in range(100):
    input_text = first_10_nl_texts[i]
    actual_command = first_10_cmd_texts[i]
    predicted_command = translate(model, tokenizer, input_text, max_length)

    print(f"Input Text: {input_text}")
    print(f"Predicted Command: {predicted_command}")
    print(f"Actual Command: {actual_command}")
    print("\n---\n")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Input Text: get the label of a fat32 partition
# Predicted Command: lrzip
# Actual Command: <start> fatlabel {{/dev/sda1}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Input Text: set the label of a fat32 partition
# Predicted Command: aria2c -o
# Actual Command: <start> fatlabel {{/dev/sdc3}} "{{new_label}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: search for a package in your current sources
# Predicted Command: git status
# Actual Command: <start> apt-cache search {{query}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: show information about a package
# Predicted Command: git status
# Actual Command: <start> apt-cache show {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Input Text: show whether a package is installed and up to date
# Predicted Command: git init init
# Actual Command: <start> apt-cache policy {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Input Text: show dependencies for a package
# Predicted Command: git install
# Actual Command: <start> apt-cache depends {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: show packages that depend on a particular package
# Predicted Command: git pacman status
# Actual Command: <start> apt-cache rdepends {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: refresh database content
# Predicted Command: git search
# Actual Command: <start> sudo updatedb <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Input Text: display file names as soon as they are found
# Predicted Command: git
# Actual Command: <start> sudo updatedb --verbose <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Input Text: install a new package
# Predicted Command: sudo install --upgrade install
# Actual Command: <start> sudo pacman --sync {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: synchronize and update all packages (add `downloadonly` to download the packages and not update them)
# Predicted Command: sudo install install install install {{path/to/package.pkg.tar.zst}}
# Actual Command: <start> sudo pacman --sync --refresh --sysupgrade <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Input Text: update all packages and install a new one without prompting
# Predicted Command: sudo install install install install install
# Actual Command: <start> sudo pacman --sync --refresh --sysupgrade --noconfirm {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Input Text: search the package database for a regular expression or keyword
# Predicted Command: git status
# Actual Command: <start> pacman --sync --search "{{search_pattern}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Input Text: display information about a package
# Predicted Command: git status
# Actual Command: <start> pacman --sync --info {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Input Text: overwrite conflicting files during a package update
# Predicted Command: sudo install install install install install
# Actual Command: <start> sudo pacman --sync --refresh --sysupgrade --overwrite {{path/to/file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Input Text: synchronize and update all packages, but ignore a specific package (can be used more than once)
# Predicted Command: git install install install install install {{remote_repository_location}}
# Actual Command: <start> sudo pacman --sync --refresh --sysupgrade --ignore {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: remove not installed packages and unused repositories from the cache (use two `clean` flags to clean all packages)
# Predicted Command: git install remove {{package_name}} {{package_name}}
# Actual Command: <start> sudo pacman --sync --clean <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: display help for this subcommand
# Predicted Command: git status
# Actual Command: <start> pacman --remove --help <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Input Text: remove a package and its dependencies
# Predicted Command: sudo install remove {{package_name}}
# Actual Command: <start> sudo pacman --remove --recursive {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Input Text: remove a package and both its dependencies and configuration files
# Predicted Command: git install remove remove install {{package_name}}
# Actual Command: <start> sudo pacman --remove --recursive --nosave {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: remove a package without prompting
# Predicted Command: sudo install remove {{package_name}}
# Actual Command: <start> sudo pacman --remove --noconfirm {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Input Text: remove orphan packages (installed as dependencies but not required by any package)
# Predicted Command: git clone clone install install install install install clone clone clone
# Actual Command: <start> sudo pacman --remove --recursive --nosave $(pacman --query --unrequired --deps --quiet) <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Input Text: remove a package and all packages that depend on it
# Predicted Command: git install remove install {{path/to/package.pkg.tar.zst}}
# Actual Command: <start> sudo pacman --remove --cascade {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Input Text: list packages that would be affected (does not remove any packages)
# Predicted Command: git pacman filesystem
# Actual Command: <start> pacman --remove --print {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: display bpftrace version
# Predicted Command: sudo
# Actual Command: <start> bpftrace -V <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Input Text: list all available probes
# Predicted Command: sudo btrfs
# Actual Command: <start> sudo bpftrace -l <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Input Text: run a oneliner program (e.g. syscall count by program)
# Predicted Command: sudo -c {{/example/dconf/path}} {{blockmap.bmap}}
# Actual Command: <start> sudo bpftrace -e '{{tracepoint:raw_syscalls:sys_enter { @[comm] = count(); }}}' <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Input Text: run a program from a file
# Predicted Command: julia -f
# Actual Command: <start> sudo bpftrace {{path/to/file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: trace a program by pid
# Predicted Command: run-mailcap -c {{path/to/input_file.cs}}
# Actual Command: <start> sudo bpftrace -e '{{tracepoint:raw_syscalls:sys_enter /pid == 123/ { @[comm] = count(); }}}' <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Input Text: do a dry run and display the output in ebpf format
# Predicted Command: git -u -m {{username}}
# Actual Command: <start> sudo bpftrace -d -e '{{one_line_program}}' <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Input Text: open a file in the default editor
# Predicted Command: mysqld
# Actual Command: <start> sensible-editor {{file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: open a file in the default editor, with the cursor at the end of the file
# Predicted Command: choose --daemon
# Actual Command: <start> sensible-editor + {{file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Input Text: open a file in the default editor, with the cursor at the beginning of line 10
# Predicted Command: choose pool-list
# Actual Command: <start> sensible-editor +10 {{file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Input Text: open 3 files in vertically split editor windows at the same time
# Predicted Command: kubectl --cpu-list --cpu-list {{command}} {{command}} {{command}}
# Actual Command: <start> sensible-editor -O3 {{file_1}} {{file_2}} {{file_3}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Input Text: integrate firejail with your desktop environment
# Predicted Command: sudo
# Actual Command: <start> sudo firecfg <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: open a restricted mozilla firefox
# Predicted Command: super
# Actual Command: <start> firejail {{firefox}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Input Text: start a restricted apache server on a known interface and address
# Predicted Command: git run --pool
# Actual Command: <start> firejail --net={{eth0}} --ip={{192.168.1.244}} {{/etc/init.d/apache2}} {{start}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Input Text: list running sandboxes
# Predicted Command: git
# Actual Command: <start> firejail --list <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: list network activity from running sandboxes
# Predicted Command: git -c
# Actual Command: <start> firejail --netstats <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Input Text: shutdown a running sandbox
# Predicted Command: git search
# Actual Command: <start> firejail --shutdown={{7777}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Input Text: build the package in the current directory
# Predicted Command: go install
# Actual Command: <start> debuild <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Input Text: build a binary package only
# Predicted Command: sudo install --upgrade
# Actual Command: <start> debuild -b <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Input Text: do not run lintian after building the package
# Predicted Command: sudo install
# Actual Command: <start> debuild --no-lintian <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Input Text: start nmon
# Predicted Command: ctrl
# Actual Command: <start> nmon <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Input Text: save records to file ("s 300 c 288" by default)
# Predicted Command: sudo
# Actual Command: <start> nmon -f <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Input Text: save records to file with a total of 240 measurements, by taking 30 seconds between each measurement
# Predicted Command: git -c | --prompt
# Actual Command: <start> nmon -f -s {{30}} -c {{240}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: view the queue
# Predicted Command: sudo
# Actual Command: <start> squeue <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: view jobs queued by a specific user
# Predicted Command: git -c
# Actual Command: <start> squeue -u {{username}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Input Text: view the queue and refresh every 5 seconds
# Predicted Command: git
# Actual Command: <start> squeue -i {{5}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Input Text: view the queue with expected start times
# Predicted Command: obs
# Actual Command: <start> squeue --start <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: show the progress of running coreutils
# Predicted Command: sudo
# Actual Command: <start> progress <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: show the progress of running coreutils in quiet mode
# Predicted Command: choose -f
# Actual Command: <start> progress -q <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: launch and monitor a single longrunning command
# Predicted Command: kubectl logs {{link}} {{command}}
# Actual Command: <start> {{command}} & progress -mp $! <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: start i7z (needs to be run in superuser mode)
# Predicted Command: sudo
# Actual Command: <start> sudo i7z <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Input Text: discover directories using a [w]ordlist on a target [u]rl with [c]olorized and [v]erbose output
# Predicted Command: smbmap -t {{filename}}.blend -o -o -o -o -t -t -t patchwork patchwork patchwork
# Actual Command: <start> ffuf -w {{path/to/wordlist}} -u {{https://target/FUZZ}} -c -v <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: fuzz host[h]eaders with a host file on a traget website and [m]atch http 200 [c]ode responses
# Predicted Command: blender -t {{filename}}.blend {{filename}}.blend -o {{filename}}.blend ffuf ffuf ffuf ffuf {{filename}}.blend {{filename}}.blend -o -o
# Actual Command: <start> ffuf -w {{hosts.txt}} -u {{https://example.org}} -H "{{Host: FUZZ}}" -mc {{200}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Input Text: discover directories using a [w]ordlist on a target website with a max individual job time of 60 seconds and recursion discovery depth of 2 levels
# Predicted Command: smbmap -t {{filename}}.blend --prompt --prompt --prompt {{path/to/wordlist.txt}} {{path/to/wordlist.txt}} {{path/to/local_file}} smbmap ffuf ffuf ffuf {{path/to/usernames.txt}} --pool ffuf {{filename}}.blend --prompt -o
# Actual Command: <start> ffuf -w {{path/to/wordlist}} -u {{https://target/FUZZ}} -maxtime-job {{60}} -recursion -recursion-depth {{2}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Input Text: fuzz get parameter on a target website and [f]ilter out message [s]ize response of 4242 bytes
# Predicted Command: echo -t {{filename}}.blend -o -o -o -o -o
# Actual Command: <start> ffuf -w {{path/to/param_names.txt}} -u {{https://target/script.php?FUZZ=test_value}} -fs {{4242}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: fuzz post method with post [d]ata of password on a target website and [f]ilter out http response [c]ode 401
# Predicted Command: echo -t {{filename}}.blend -o -o {{filename}}.blend ffuf --column ffuf ffuf {{filename}}.blend {{filename}}.blend {{filename}}.blend {{filename}}.blend -o -o -o
# Actual Command: <start> ffuf -w {{path/to/postdata.txt}} -X {{POST}} -d "{{username=admin\&password=FUZZ}}" -u {{https://target/login.php}} -fc {{401}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Input Text: discover subdomains using a subdoomain list on a target website
# Predicted Command: echo -o -o -o -o -o -o -o {{gif}}
# Actual Command: <start> ffuf -w {{subdomains.txt}} -u {{https://website.com}} -H "{{Host: FUZZ.website.com}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Input Text: add all package binaries in the current directory and remove the old database file
# Predicted Command: sudo install {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}}
# Actual Command: <start> repo-add --remove {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Input Text: add all package binaries in the current directory in silent mode except for warning and error messages
# Predicted Command: sudo install {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}}
# Actual Command: <start> repo-add --quiet {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Input Text: add all package binaries in the current directory without showing color
# Predicted Command: sudo install {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}}
# Actual Command: <start> repo-add --nocolor {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: display executable invocations per user (username not displayed)
# Predicted Command: git status
# Actual Command: <start> sudo sa <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: display executable invocations per user, showing responsible usernames
# Predicted Command: git search ls
# Actual Command: <start> sudo sa --print-users <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Input Text: list resources used recently per user
# Predicted Command: git status
# Actual Command: <start> sudo sa --user-summary <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Input Text: edit the password file
# Predicted Command: git
# Actual Command: <start> vipw <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Input Text: display the current version of `vipw`
# Predicted Command: obs
# Actual Command: <start> vipw --version <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Input Text: retrieve current status of the jail service
# Predicted Command: git -i
# Actual Command: <start> fail2ban-client status {{jail}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Input Text: remove the specified ip from the jail service's ban list
# Predicted Command: git -i create
# Actual Command: <start> fail2ban-client set {{jail}} unbanip {{ip}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: verify fail2ban server is alive
# Predicted Command: go
# Actual Command: <start> fail2ban-client ping <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: synchronize and set date and time
# Predicted Command: sudo install {{path/to/archive.7z}}
# Actual Command: <start> sudo ntpdate {{host}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: query the host without setting the time
# Predicted Command: sudo -c
# Actual Command: <start> ntpdate -q {{host}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: use an unprivileged port in case a firewall is blocking privileged ports
# Predicted Command: git -t add
# Actual Command: <start> sudo ntpdate -u {{host}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Input Text: force time to be stepped using `settimeofday` instead of `slewed`
# Predicted Command: sudo install add
# Actual Command: <start> sudo ntpdate -b {{host}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: show all running services
# Predicted Command: git
# Actual Command: <start> systemctl status <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: list failed units
# Predicted Command: sudo +
# Actual Command: <start> systemctl --failed <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: start/stop/restart/reload a service
# Predicted Command: sudo -c {{data_directory}}
# Actual Command: <start> systemctl {{start|stop|restart|reload}} {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: show the status of a unit
# Predicted Command: git status
# Actual Command: <start> systemctl status {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Input Text: enable/disable a unit to be started on bootup
# Predicted Command: lrzip {{/dev/sdb1}}
# Actual Command: <start> systemctl {{enable|disable}} {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: mask/unmask a unit to prevent enablement and manual activation
# Predicted Command: sudo clean
# Actual Command: <start> systemctl {{mask|unmask}} {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Input Text: reload systemd, scanning for new or changed units
# Predicted Command: sudo
# Actual Command: <start> systemctl daemon-reload <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Input Text: check if a unit is enabled
# Predicted Command: csc {{/dev/sdb1}} {{path/to/input_file.cs}}
# Actual Command: <start> systemctl is-enabled {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: run `ipconfig.exe` program
# Predicted Command: run-mailcap + {{path/to/input_file.cs}}
# Actual Command: <start> wine {{ipconfig}} {{/all}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Input Text: run `cmd.exe` in background
# Predicted Command: sudo -c
# Actual Command: <start> wine start {{cmd}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Input Text: run windowslike package manager
# Predicted Command: sudo install
# Actual Command: <start> wine uninstaller <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: install msi packages
# Predicted Command: sudo install {{path/to/archive.7z}}
# Actual Command: <start> wine msiexec /i {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: display a message in fullscreen
# Predicted Command: kubectl -c {{command}}
# Actual Command: <start> sm "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Input Text: display a message with inverted colors
# Predicted Command: kubectl logs {{link}} {{command}}
# Actual Command: <start> sm -i "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: display a message with a custom foreground color
# Predicted Command: kubectl copy {{command}} {{command}} {{command}}
# Actual Command: <start> sm -f {{blue}} "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Input Text: display a message with a custom background color
# Predicted Command: kubectl logs --cpu-list {{command}} {{command}}
# Actual Command: <start> sm -b {{#008888}} "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Input Text: display a message rotated 3 times (in steps of 90 degrees, counterclockwise)
# Predicted Command: kubectl -e --cpu-list {{command}} {{command}}
# Actual Command: <start> sm -r {{3}} "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Input Text: display a message using the output from another command
# Predicted Command: kubectl -e --cpu-list {{command}} {{command}}
# Actual Command: <start> {{echo "Hello World!"}} | sm - <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Input Text: create a btrfs filesystem on a single device
# Predicted Command: sudo --issue {{svg}} -> that} {{path/to/image.svg}} {{path/to/image.svg}} {{path/to/archive.7z}}
# Actual Command: <start> sudo mkfs.btrfs --metadata single --data single {{/dev/sda}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Input Text: create a btrfs filesystem on multiple devices with raid1
# Predicted Command: acme.sh --issue {this -> that} that} that} that} that} }}" -o
# Actual Command: <start> sudo mkfs.btrfs --metadata raid1 --data raid1 {{/dev/sda}} {{/dev/sdb}} {{/dev/sdN}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Input Text: set a label for the filesystem
# Predicted Command: sudo install {{path/to/input_file.cs}} {{/dev/sdb1}}
# Actual Command: <start> sudo mkfs.btrfs --label "{{label}}" {{/dev/sda}} [{{/dev/sdN}}] <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Input Text: mount a `.raw` image file into a dmg container file
# Predicted Command: pssh openvpn --cpu-list {{path/to/hosts_file}} {{path/to/hosts_file}} {{tun1}} --ifconfig {{10.4.0.2}}
# Actual Command: <start> xmount --in {{raw}} {{path/to/image.dd}} --out {{dmg}} {{mountpoint}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Input Text: mount an ewf image file with writecache support into a vhd file to boot from
# Predicted Command: pssh openvpn --generator=run-pod/v1 {{path/to/hosts_file}} {{path/to/hosts_file}} {{tun1}} {{tun1}} {{tun1}} --ifconfig {{10.4.0.1}}
# Actual Command: <start> xmount --cache {{path/to/cache.ovl}} --in {{ewf}} {{path/to/image.E??}} --out {{vhd}} {{mountpoint}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Input Text: mount the first partition at sector 2048 into a new `.raw` image file
# Predicted Command: pssh openvpn --format=cd {{path/to/hosts_file}} {{path/to/hosts_file}} {{tun1}} --ifconfig
# Actual Command: <start> xmount --offset {{2048}} --in {{raw}} {{path/to/image.dd}} --out {{raw}} {{mountpoint}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Input Text: show the current number lock status
# Predicted Command: git
# Actual Command: <start> numlockx status <end>
#
# ---
