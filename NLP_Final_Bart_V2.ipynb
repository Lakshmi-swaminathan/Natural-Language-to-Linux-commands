# %%
# !pip install transformers torch datasets sacrebleu rouge_score accelerate
from transformers import BartTokenizer, BartForConditionalGeneration, Trainer, TrainingArguments
from transformers import DataCollatorForSeq2Seq, EarlyStoppingCallback
from datasets import load_dataset, load_metric
import torch
import numpy as np
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Collecting datasets
#   Downloading datasets-2.19.0-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 12.0 MB/s eta 0:00:00
# Collecting sacrebleu
#   Downloading sacrebleu-2.4.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 10.7 MB/s eta 0:00:00
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting accelerate
#   Downloading accelerate-0.29.3-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.6 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Collecting huggingface-hub<1.0,>=0.19.3 (from transformers)
#   Downloading huggingface_hub-0.22.2-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 21.2 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=690c6786f94c5f6c928f01a427a082d8c4bf937b7a240b72baa00f8bbe9dc3e3
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# Installing collected packages: xxhash, portalocker, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, dill, colorama, sacrebleu, rouge_score, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, huggingface-hub, nvidia-cusolver-cu12, datasets, accelerate
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# Successfully installed accelerate-0.29.3 colorama-0.4.6 datasets-2.19.0 dill-0.3.8 huggingface-hub-0.22.2 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 portalocker-2.8.2 rouge_score-0.1.2 sacrebleu-2.4.2 xxhash-3.4.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def load_and_prepare_data(model_name):

    dataset = load_dataset("neulab/tldr")
    train_test_split = dataset["train"].train_test_split(test_size=0.2)

    tokenizer = BartTokenizer.from_pretrained(model_name)

    def preprocess_function(examples):
        input_texts = ["translate English to Bash: " + inp for inp in examples['nl']]
        model_inputs = tokenizer(input_texts, max_length=30, truncation=True, padding="max_length")
        labels = tokenizer(examples['cmd'], max_length=30, truncation=True, padding="max_length")
        model_inputs['labels'] = labels['input_ids']
        return model_inputs

    tokenized_train = train_test_split['train'].map(preprocess_function, batched=True)
    tokenized_validation = train_test_split['test'].map(preprocess_function, batched=True)

    return {'train': tokenized_train, 'validation': tokenized_validation}

# %%
from transformers import BartTokenizer, BartForConditionalGeneration

def load_model(model_name):
    """
    Loads a BART model and its tokenizer from the specified pre-trained name or path.

    Parameters:
        model_name (str): The name or path of the pre-trained model on Hugging Face's model hub
                          or your local saved model.

    Returns:
        tokenizer (BartTokenizer): The tokenizer for the specified BART model.
        model (BartForConditionalGeneration): The BART model loaded with pre-trained weights.
    """
    # Load the tokenizer for the specified model
    tokenizer = BartTokenizer.from_pretrained(model_name)

    # Load the BART model
    model = BartForConditionalGeneration.from_pretrained(model_name)

    # Return both the model and tokenizer
    return tokenizer, model

# %%
bleu_metric = load_metric('sacrebleu')
rouge_metric = load_metric('rouge')

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    if isinstance(logits, tuple):  # Extract logits from model outputs
        logits = logits[0]

    decoded_preds = tokenizer.batch_decode(torch.argmax(logits, dim=-1), skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    decoded_preds = [pred.strip() for pred in decoded_preds]
    decoded_labels = [[label.strip()] for label in decoded_labels]

    bleu = bleu_metric.compute(predictions=decoded_preds, references=decoded_labels)
    rouge = rouge_metric.compute(predictions=decoded_preds, references=decoded_labels)

    return {
        'bleu': bleu['score'],
        'rouge-l': rouge['rougeL'].mid.fmeasure,
        'perplexity': torch.exp(torch.tensor(logits)).mean().item()
    }
# Out:
# <ipython-input-5-3f4c0f252532>:1: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   bleu_metric = load_metric('sacrebleu')
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for sacrebleu contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/sacrebleu/sacrebleu.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/2.85k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for rouge contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/rouge/rouge.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/2.17k [00:00<?, ?B/s]

# %%
import os
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

# %%
model_name = "facebook/bart-base"
tokenizer, model = load_model(model_name)
tokenized_datasets = load_and_prepare_data(model_name)


training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="steps",
    eval_steps=500,
    learning_rate=2e-5,
    per_device_train_batch_size=1,  # Already minimal; consider gradient accumulation if further reduction is needed
    per_device_eval_batch_size=1,
    gradient_accumulation_steps=32,  # Increase if necessary
    num_train_epochs=5,
    weight_decay=0.01,
    save_strategy="steps",
    save_steps=500,
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model='bleu',
    report_to="none",
    fp16=False
)


trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['validation'],
    data_collator=DataCollatorForSeq2Seq(tokenizer, model=model),
    compute_metrics=lambda eval_pred: compute_metrics(eval_pred, tokenizer),
    callbacks=[EarlyStoppingCallback(early_stopping_patience=1)]
)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1486: FutureWarning: The repository for neulab/tldr contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/neulab/tldr
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Map:   0%|          | 0/5131 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1283 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='420' max='800' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [420/800 1:29:49 < 1:21:39, 0.08 it/s, Epoch 2.61/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='501' max='800' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [501/800 1:49:18 < 1:05:30, 0.08 it/s, Epoch 3.12/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1003' max='1283' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1003/1283 11:40 < 03:15, 1.43 it/s]
#     </div>

# %%
from google.colab import drive
drive.mount('/content/drive')
model.save_pretrained("/content/drive/My Drive/bart_command_translator_V2")
tokenizer.save_pretrained("/content/drive/My Drive/bart_command_translator_V2")
# Out:
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'early_stopping': True, 'num_beams': 4, 'no_repeat_ngram_size': 3, 'forced_bos_token_id': 0, 'forced_eos_token_id': 2}
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ('/content/drive/My Drive/bart_command_translator_V2/tokenizer_config.json',
#  '/content/drive/My Drive/bart_command_translator_V2/special_tokens_map.json',
#  '/content/drive/My Drive/bart_command_translator_V2/vocab.json',
#  '/content/drive/My Drive/bart_command_translator_V2/merges.txt',
#  '/content/drive/My Drive/bart_command_translator_V2/added_tokens.json')

# %%
from transformers import BartTokenizer, BartForConditionalGeneration

def load_model_from_path(model_path):
    """
    Loads a BART model and its tokenizer from a specified path.

    Parameters:
        model_path (str): The file path or directory where the model and tokenizer are saved.

    Returns:
        tokenizer (BartTokenizer): The tokenizer for the BART model loaded from the specified path.
        model (BartForConditionalGeneration): The BART model loaded from the specified path.
    """
    # Load the tokenizer and model using the provided model path
    tokenizer = BartTokenizer.from_pretrained(model_path)
    model = BartForConditionalGeneration.from_pretrained(model_path)

    return tokenizer, model

# %%
def translate_to_command(input_text, tokenizer, model, device='cpu'):
    """
    Translate input text into a command using the provided BART model.

    Parameters:
        input_text (str): Natural language text to be translated.
        tokenizer (BartTokenizer): Tokenizer for the BART model.
        model (BartForConditionalGeneration): Pre-trained BART model.
        device (str): Device to perform computation on ('cpu' or 'cuda').

    Returns:
        str: Translated command.
    """
    # Move the model to the specified device and set it to evaluation mode
    model.to(device)
    model.eval()

    # Prepare the input text for the model
    input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)

    # Generate the command using the model
    outputs = model.generate(input_ids, max_length=50, num_beams=5, early_stopping=True)

    # Decode and return the generated text
    command = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return command

# %%
model_path = "/content/drive/My Drive/bart_command_translator_V2"
tokenizer, model = load_model_from_path(model_path)

for i in range(100):
    example = tokenized_datasets['validation'][i]
    input_text = tokenizer.decode(example['input_ids'], skip_special_tokens=True)
    actual_command = tokenizer.decode(example['labels'], skip_special_tokens=True)
    predicted_command = translate_to_command(input_text, tokenizer, model)

    print(f"Input Text: {input_text}")
    print(f"Actual Command: {actual_command}")
    print(f"Predicted Command: {predicted_command}")
    print("-" * 80)
# Out:
# Input Text: translate English to Bash: replace environment variables in an input file from a spaceseparated list
# Actual Command: envsubst '{{$USER $SHELL $HOME}}' < {{path/to/input_file}}
# Predicted Command: screenspace {{path/to/input.sc}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: automatically start recording a video on launch
# Actual Command: obs --startrecording
# Predicted Command: youtube -i {{video}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: download a torrent to a specific directory
# Actual Command: transmission-cli --download-dir {{path/to/download_directory}} {{url|magnet|path/to/file
# Predicted Command: torrent {{path/to/file.torrent}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: compare diff files, ignoring whitespace
# Actual Command: interdiff -w {{old_file}} {{new_file}}
# Predicted Command: diff {{path/to/file.diff}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: convert filename encoding and rename the file to the new encoding
# Actual Command: convmv -f {{from_encoding}} -t {{to_encoding}} --notest {{input_file}}
# Predicted Command: gzip -c {{path/to/file.gzip}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: run individual tasks
# Actual Command: gulp {{task}} {{othertask}}
# Predicted Command: task {{task_name}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: add a new table with family "inet" and table "filter"
# Actual Command: sudo nft add table {{inet}} {{filter}}
# Predicted Command: pio table add {{table_name}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: display a diff of the changes that would be made, without making them (dryrun)
# Actual Command: yapf --diff {{path/to/file}}
# Predicted Command: git diff --diff {{path/to/file}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: find the package that owns a specific file
# Actual Command: pacman --files {{filename}}
# Predicted Command: pio package {{path/to/file}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: execute a script, printing each command before executing it
# Actual Command: ksh -x {{path/to/script.ksh}}
# Predicted Command: script {{path/to/script.script}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: create an image with nothing but a solid background
# Actual Command: convert -size {{800x600}} "xc:{{#ff0000}}" {{image.png}}
# Predicted Command: pio image {{image1.png}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: display commits since yesterday 2pm
# Actual Command: git commits-since {{yesterday 2pm}}
# Predicted Command: git commit --since {{2pm}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: generate tags for all files in the current directory and all subdirectories
# Actual Command: ctags --recurse
# Predicted Command: git tags --all {{path/to/directory}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: search for lines that do not match a pattern
# Actual Command: egrep --invert-match "{{search_pattern}}" {{path/to/file}}
# Predicted Command: search {{pattern}} {{path/to/file}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: remove not installed packages and unused repositories from the cache (use two `clean` flags to clean all packages)
# Actual Command: sudo pacman --sync --clean
# Predicted Command: sudo pacman --clean
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: build a platformio project and don't delete the build directory
# Actual Command: pio ci --keep-build-dir {{path/to/project}}
# Predicted Command: pio build
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: show pod logs newer than a relative time like `10s`, `5m`, or `1h`
# Actual Command: kubectl logs --since={{relative_time}} {{pod_name}}
# Predicted Command: pod logs {{10s}} {{5m}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: edit most recent frame
# Actual Command: watson edit
# Predicted Command: git edit {{frame1}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: convert stereo audio at the highest quality level
# Actual Command: opusenc --bitrate {{512}} {{path/to/input.wav}} {{path/to/output}}.opus
# Predicted Command: mp3 -m {{path/to/audio.mp3}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: list nonfree and contrib packages (and their description)
# Actual Command: vrms
# Predicted Command: pio package list {{package_name}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: print a file to the console with 24bit (truecolor) rainbow colors
# Actual Command: lolcat -t {{path/to/file}}
# Predicted Command: gpg -f {{path/to/file.gpg}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: browse for both ssh and vnc servers
# Actual Command: bssh --shell
# Predicted Command: ssh --vnc
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: mount an encrypted snapshot of a plain directory
# Actual Command: encfs --reverse {{path/to/plain_dir}} {{path/to/cipher_dir}}
# Predicted Command: snapshot {{path/to/file.snapshot}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: view smart selftest log (if supported)
# Actual Command: sudo smartctl --log selftest {{/dev/sdX}}
# Predicted Command: sudo selftest
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: replace all occurrences of a character from another command's output
# Actual Command: echo {{text}} | tr {{find_character}} {{replace_character}}
# Predicted Command: echo "{{command}}" {{command}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: run project tests
# Actual Command: mix test
# Predicted Command: pio test
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: create a patch
# Actual Command: xdelta -e -s {{path/to/old_file}} {{path/to/new_file}} {{path/to
# Predicted Command: patch {{path/to/patch.patch}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: generate scaffolding for a new project based on a template
# Actual Command: lein new {{template_name}} {{project_name}}
# Predicted Command: gh scaffolding --template {{template}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: record a sample recording using a different sample rate
# Actual Command: pw-cat --record --rate={{6000}} {{path/to/file.wav}}
# Predicted Command: mp3 --recording {{path/to/file.mp3}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: generate a certificate signing request to be sent to a certificate authority
# Actual Command: openssl req -new -sha256 -key {{filename.key}} -out {{filename.csr}}
# Predicted Command: certificate generate {{path/to/file.certificate}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: enable tcp fast open
# Actual Command: ss-local --fast-open
# Predicted Command: sudo tcpctl --fast
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: convert blanks in each file to tabs, writing to standard output
# Actual Command: unexpand {{file}}
# Predicted Command: blanks {{path/to/file.blanks}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: split a file at lines 5 and 23
# Actual Command: csplit {{file}} {{5}} {{23}}
# Predicted Command: git split {{path/to/file}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: wrap each line to width "30"
# Actual Command: fold -w30 {{file}}
# Predicted Command: gzip -f {{30}} {{path/to/file.gzip}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: restore dependencies without caching the http requests
# Actual Command: dotnet restore --no-cache
# Predicted Command: pio restore --cache
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: compare files, showing the differences in unified format (as used by `git diff`)
# Actual Command: diff --unified {{old_file}} {{new_file}}
# Predicted Command: git diff {{path/to/file1}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: output the clipboard's contents into the terminal (equivalent to `ctrl + v`)
# Actual Command: xsel -ob
# Predicted Command: cargo -c {{path/to/ clipboard.cargo}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: download with multiple connections
# Actual Command: aria2c --split={{number_of_connections}} {{url}}
# Predicted Command: hg download {{path/to/file.hg}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: convert the image to grayscale
# Actual Command: jpegtran -grayscale {{path/to/image.jpg}} > {{path/to/output.jpg}}
# Predicted Command: pio image {{path/to/image.png}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: set a changeable kernel state variable
# Actual Command: sysctl -w {{section.tunable}}={{value}}
# Predicted Command: kernel state set {{path/to/file.kernel}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: open a terminal, execute a given command, and write the output to a file
# Actual Command: st -o {{path/to/file}} -e {{command argument1 argument2}}
# Predicted Command: sudo terminal --write-command {{path/to/file}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: check r version
# Actual Command: R --version
# Predicted Command: r version
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: print all lines where the 10th column value equals the specified value
# Actual Command: awk '($10 == value)'
# Predicted Command: calendar -c {{10}} {{path/to/file}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: display information about a specific user
# Actual Command: w {{user}}
# Predicted Command: hguser --user {{username}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: abort a git rebase, merge, or cherrypick
# Actual Command: git abort
# Predicted Command: git rebase {{path/to/file.git}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: display a multiplechoice menu
# Actual Command: {{result_variable_name}}=$(whiptail --title "{{title}}" --menu "{{message}}" {{height
# Predicted Command: pio menu {{path/to/menu.pio}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: display the point size of a font
# Actual Command: xprop -font "{{font_name}}" POINT_SIZE
# Predicted Command: fontsize {{path/to/file}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: discover other virtual hosts on the server
# Actual Command: gobuster vhost --url {{https://example.com/}} --wordlist {{path/to/file}}
# Predicted Command: vpn discover {{host}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: store a certificate's public key in a file
# Actual Command: openssl x509 -in {{certificate_file}} -noout -pubkey -out {{output_file}}
# Predicted Command: certificate store {{path/to/file}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: reverse and save an audio file
# Actual Command: sox {{input_audiofile}} {{output_audiofile}} reverse
# Predicted Command: echo "{{path/to/audio.wav}}"
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: install one or more spaceseparated versions of ruby
# Actual Command: rvm install {{version(s)}}
# Predicted Command: rvm install {{path/to/file.rvm}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: display help for `edgepaint`
# Actual Command: edgepaint -?
# Predicted Command: edgepaint --help
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: increase or decrease image size
# Actual Command: qemu-img resize {{image_name.img}} {{gigabytes}}G
# Predicted Command: pio image {{image1.png}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: list all available project targets
# Actual Command: pio run --list-targets
# Predicted Command: pio project list
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: load values (e.g. style rules) from a resource file
# Actual Command: xrdb -load {{~/.Xresources}}
# Predicted Command: gv load {{path/to/resource_file}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: start `gpgtui`
# Actual Command: gpg-tui
# Predicted Command: gpgtui
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: analyze a specific file
# Actual Command: alex {{textfile.md}}
# Predicted Command: git analyze {{path/to/file}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: launch a git daemon with a specific base directory and allow pulling from all subdirectories that look like git repositories
# Actual Command: git daemon --base-path={{path/to/directory}} --export-all --reuseaddr
# Predicted Command: git daemon --base {{path/to/directory}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: preview the programs would be executed in a regular autostart
# Actual Command: dex --autostart --dry-run
# Predicted Command: autostart {{path/to/program}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: connect to a music player daemon on a given host and port
# Actual Command: ncmpcpp --host {{ip}} --port {{port}}
# Predicted Command: pio -d {{host}} {{port}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: remove the current directory from `z`'s database
# Actual Command: z -x.
# Predicted Command: z {{path/to/database.z}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: create a tar archive from the contents of the current head and print it to standard output
# Actual Command: git archive --verbose HEAD
# Predicted Command: tar archive {{path/to/file.tar}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: execute a single scala command in the commandline
# Actual Command: scala -e {{command}}
# Predicted Command: scala --command {{command}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: show the specific pep 8 text for each error
# Actual Command: pycodestyle --show-pep8 {{file.py}}
# Predicted Command: pep8 -p {{path/to/file.txt}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: view documentation for the original command
# Actual Command: tldr nm
# Predicted Command: pio -c {{command}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: create a skeleton `shard.yml` file
# Actual Command: shards init
# Predicted Command: shard --create {{path/to/file.yml}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: connect to a given network
# Actual Command: nmtui connect {{name|uuid|device|SSID}}
# Predicted Command: npm connect {{network_name}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: delete multiple local and remote git branches
# Actual Command: git delete-branch {{branch_name1 branch_name2...}}
# Predicted Command: git delete {{branch_name}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: get lines only found in first file, saving the result to a third file
# Actual Command: comm -23 {{file1}} {{file2}} > {{file1_only}}
# Predicted Command: ls -f {{path/to/file}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: execute commands from standard input in 5 minutes (press `ctrl + d` when done)
# Actual Command: at now + 5 minutes
# Predicted Command: sudo pacman --command {{command}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: remove a package without prompting
# Actual Command: sudo pacman --remove --noconfirm {{package_name}}
# Predicted Command: pio package remove {{package_name}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: set the operating mode of the specified interface
# Actual Command: iwconfig {{interface}} mode {{ad hoc|Managed|Master|Repeater|Secondary|Monitor|Auto}}
# Predicted Command: pioctl set-interface {{interface}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: trace the route to a host
# Actual Command: tcptraceroute {{host}}
# Predicted Command: hg trace {{path/to/host}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: list the name and uuid of active storage pools
# Actual Command: virsh pool-list --name --uuid
# Predicted Command: pio pool list {{pool_name}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: browse for ssh servers
# Actual Command: bssh
# Predicted Command: ssh
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: set a reminder to leave at noon
# Actual Command: leave {{1200}}
# Predicted Command: meltdown --set a reminder
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: kill the current screen session
# Actual Command: Ctrl + A, K
# Predicted Command: gh kill
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: run a packaged dotnet application (only needs the runtime, the rest of the commands require the.net core
# Actual Command: dotnet {{path/to/application.dll}}
# Predicted Command: dotnet --runtime {{runtime}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: connect to the wifi network with a specified name and password
# Actual Command: nmcli device wifi connect {{ssid}} password {{password}}
# Predicted Command: wifi --name {{username}} {{password}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: generate a text report from a specific profiling file, on fibbo binary
# Actual Command: pprof -top {{./fibbo}} {{./fibbo-profile.pb.gz}}
# Predicted Command: fibbo --report {{path/to/file}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: output the results to a file instead of stdout
# Actual Command: phpmd {{path/to/file_or_directory}} {{xml|text|html}} {{rulesets}} --reportfile
# Predicted Command: hg --output {{path/to/file}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: do not show any idle (sleeping) threads
# Actual Command: mytop -u {{user}} -p {{password}} --noidle
# Predicted Command: hg --no-threads
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: issue a certificate while disabling automatic cloudflare / google dns polling after the dns record is added by
# Actual Command: acme.sh --issue --dns {{dns_namecheap}} --domain {{example.com}} --dnssleep
# Predicted Command: dns --issue-certificate {{path/to/file.dns}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: skip some checks and force compression or decompression
# Actual Command: p7zip -f {{path/to/file}}
# Predicted Command: cargo -c {{path/to/file.cargo}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: automatically start streaming on launch
# Actual Command: obs --startstreaming
# Predicted Command: pioctl start
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: launch a vnc client which connects to a host on a given display
# Actual Command: vncviewer {{host}}:{{display_number}}
# Predicted Command: vncclient --host {{host}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: download from multiple sources with each uri pointing to the same file
# Actual Command: aria2c {{url_1}} {{url_2}}
# Predicted Command: git download {{path/to/file}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: remove a package and all packages depending on it
# Actual Command: aptitude remove {{package}}
# Predicted Command: pio package remove {{package_name}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: start a new session
# Actual Command: tmux
# Predicted Command: session start
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: defragment a directory recursively (does not cross subvolume boundaries)
# Actual Command: sudo btrfs filesystem defragment -v -r {{path/to/directory}}
# Predicted Command: git defragment {{path/to/directory}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: copy sources of all dependencies into the vendor directory
# Actual Command: go mod vendor
# Predicted Command: vendor copy {{path/to/directory}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: display help for a subcommand
# Actual Command: next {{build|dev|export|start|telemetry}} --help
# Predicted Command: git help {{subcommand}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: don't show informative messages
# Actual Command: sudo a2enmod --quiet {{module}}
# Predicted Command: echo "{{message}}"
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: mount a device with a specific filesystem type to `/media/label`
# Actual Command: pmount --type {{filesystem}} {{/dev/to/block/device}} {{label}}
# Predicted Command: mkfs {{/media/label}} {{/dev/sdXN}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: compare a given branch with the current branch
# Actual Command: git show-branch --current {{commit|branch_name|ref}}
# Predicted Command: git branch compare {{branch_name}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: display smb shares and permissions on a host, prompting for user's password or ntlm hash
# Actual Command: smbmap -u {{username}} --prompt -H {{ip}}
# Predicted Command: smb --user {{username}} {{password}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: show details of kubernetes objects defined in a yaml manifest
# Actual Command: kubectl describe -f {{path/to/manifest}}.yaml
# Predicted Command: kubernetes --details {{path/to/file}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: enable network time protocol (ntp) synchronization
# Actual Command: timedatectl set-ntp on
# Predicted Command: sudo nntp --synchronization
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: find the package that owns a specific file, using a regular expression
# Actual Command: pacman --files --regex '{{regular_expression}}'
# Predicted Command: pio package {{path/to/file}}
# --------------------------------------------------------------------------------
# Input Text: translate English to Bash: set button to only work when the tip of the pen is touching the tablet
# Actual Command: xsetwacom set "{{device_name}}" TabletPCButton "on"
# Predicted Command: pio -p {{pad}}
# --------------------------------------------------------------------------------

# %%
import torch
import numpy as np
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, Trainer, TrainingArguments
from datasets import load_metric

# Assuming sacrebleu and rouge are the metrics you want
bleu_metric = load_metric('sacrebleu')
rouge_metric = load_metric('rouge')

def compute_metrics(eval_pred, tokenizer):
    logits, labels = eval_pred
    if isinstance(logits, tuple):
        logits = logits[0]

    # Ensure logits are PyTorch tensors
    if isinstance(logits, np.ndarray):
        logits = torch.tensor(logits)

    # Ensure labels are tensors (convert if they're not)
    if isinstance(labels, np.ndarray):
        labels = torch.tensor(labels)

    decoded_preds = tokenizer.batch_decode(torch.argmax(logits, dim=-1), skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    decoded_preds = [pred.strip() for pred in decoded_preds]
    decoded_labels = [[label.strip()] for label in decoded_labels]
    bleu = bleu_metric.compute(predictions=decoded_preds, references=decoded_labels)
    rouge = rouge_metric.compute(predictions=decoded_preds, references=decoded_labels)
    return {
        'bleu': bleu['score'],
        'rouge-l': rouge['rougeL'].mid.fmeasure
    }

# Load the model and tokenizer from the saved directory
model_path = "/content/drive/My Drive/bart_command_translator_V2"
model = AutoModelForSeq2SeqLM.from_pretrained(model_path)
tokenizer = AutoTokenizer.from_pretrained(model_path)

# Load the evaluation dataset
# This needs to be adjusted according to how you have stored or can load your dataset
eval_dataset = load_and_prepare_data(model_path)['validation']  # Placeholder function

# Setup the Trainer instance
training_args = TrainingArguments(
    output_dir="./results",  # Change this if you want to save evaluation results
    per_device_eval_batch_size=1  # Adjust based on your available resources
)

trainer = Trainer(
    model=model,
    args=training_args,
    eval_dataset=eval_dataset,
    compute_metrics=lambda eval_pred: compute_metrics(eval_pred, tokenizer)
)

# Evaluate the model
results = trainer.evaluate()

# Print the results
print(results)
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for sacrebleu contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/sacrebleu/sacrebleu.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for rouge contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/rouge/rouge.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1486: FutureWarning: The repository for neulab/tldr contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/neulab/tldr
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
#     <div>
#
#       <progress value='1283' max='1283' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1283/1283 17:29]
#     </div>
# {'eval_loss': 1.077932596206665, 'eval_bleu': 31.6993525869949, 'eval_rouge-l': 0.33450529363648085, 'eval_runtime': 1052.3463, 'eval_samples_per_second': 1.219, 'eval_steps_per_second': 1.219}

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, Trainer, TrainingArguments
import torch
from datasets import load_metric

# Assuming sacrebleu and rouge are the metrics you want
bleu_metric = load_metric('sacrebleu')
rouge_metric = load_metric('rouge')

def compute_metrics(eval_pred, tokenizer):
    logits, labels = eval_pred
    if isinstance(logits, tuple):
        logits = logits[0]
    decoded_preds = tokenizer.batch_decode(torch.argmax(logits, dim=-1), skip_special_tokens=True)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    decoded_preds = [pred.strip() for pred in decoded_preds]
    decoded_labels = [[label.strip()] for label in decoded_labels]
    bleu = bleu_metric.compute(predictions=decoded_preds, references=decoded_labels)
    rouge = rouge_metric.compute(predictions=decoded_preds, references=decoded_labels)
    return {
        'bleu': bleu['score'],
        'rouge-l': rouge['rougeL'].mid.fmeasure
    }

# Load the model and tokenizer from the saved directory
model_path = "/content/drive/My Drive/bart_command_translator_V2"
model = AutoModelForSeq2SeqLM.from_pretrained(model_path)
tokenizer = AutoTokenizer.from_pretrained(model_path)

# Load the evaluation dataset
# This needs to be adjusted according to how you have stored or can load your dataset
eval_dataset = load_and_prepare_data(model_path)['train']  # Placeholder function

# Setup the Trainer instance
training_args = TrainingArguments(
    output_dir="./results",  # Change this if you want to save evaluation results
    per_device_eval_batch_size=1  # Adjust based on your available resources
)

trainer = Trainer(
    model=model,
    args=training_args,
    eval_dataset=eval_dataset,
    compute_metrics=lambda eval_pred: compute_metrics(eval_pred, tokenizer)
)

# Evaluate the model
results = trainer.evaluate()

# Print the results
print(results)
