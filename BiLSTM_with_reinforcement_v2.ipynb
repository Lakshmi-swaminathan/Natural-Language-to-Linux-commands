# %%
# !pip install tensorflow tensorflow-text datasets nltk rouge pydot graphviz
import nltk
nltk.download('punkt')
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Collecting tensorflow-text
#   Downloading tensorflow_text-2.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 33.5 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.19.0-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 29.5 MB/s eta 0:00:00
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: pydot in /usr/local/lib/python3.10/dist-packages (1.4.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (0.20.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Collecting tensorflow
#   Downloading tensorflow-2.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (589.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 2.2 MB/s eta 0:00:00
# Collecting h5py>=3.10.0 (from tensorflow)
#   Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 74.8 MB/s eta 0:00:00
# Collecting ml-dtypes~=0.3.1 (from tensorflow)
#   Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 61.2 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.31.0)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow)
#   Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 74.9 MB/s eta 0:00:00
# Collecting keras>=3.0.0 (from tensorflow)
#   Downloading keras-3.3.3-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 16.4 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Collecting huggingface-hub>=0.21.2 (from datasets)
#   Downloading huggingface_hub-0.22.2-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 29.3 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from pydot) (3.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.0.0->tensorflow) (13.7.1)
# Collecting namex (from keras>=3.0.0->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Collecting optree (from keras>=3.0.0->tensorflow)
#   Downloading optree-0.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 23.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.0.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.0.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.2)
# Installing collected packages: namex, xxhash, rouge, optree, ml-dtypes, h5py, dill, tensorboard, multiprocess, huggingface-hub, keras, tensorflow, datasets, tensorflow-text
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.2.0
#     Uninstalling ml-dtypes-0.2.0:
#       Successfully uninstalled ml-dtypes-0.2.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.2
#     Uninstalling tensorboard-2.15.2:
#       Successfully uninstalled tensorboard-2.15.2
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.15.0
#     Uninstalling tensorflow-2.15.0:
#       Successfully uninstalled tensorflow-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.15.1 requires tensorflow<2.16,>=2.15, but you have tensorflow 2.16.1 which is incompatible.
# Successfully installed datasets-2.19.0 dill-0.3.8 h5py-3.11.0 huggingface-hub-0.22.2 keras-3.3.3 ml-dtypes-0.3.2 multiprocess-0.70.16 namex-0.0.8 optree-0.11.0 rouge-1.0.1 tensorboard-2.16.2 tensorflow-2.16.1 tensorflow-text-2.16.1 xxhash-3.4.1
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, TimeDistributed, Concatenate, Dropout, Bidirectional, MultiHeadAttention
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np
import os
import pickle
from google.colab import drive
from datasets import load_dataset
from nltk.translate.bleu_score import sentence_bleu
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.optimizers import Adam
from nltk.translate import bleu_score

# %%
# Mount Google Drive
drive.mount('/content/drive')
model_path = '/content/drive/My Drive/model_BiLSTM_word_reinforcement_V2.h5'
history_path = '/content/drive/My Drive/history_BiLSTM_word_reinforcement_V2.pkl'
# Out:
# Mounted at /content/drive

# %%
# Load dataset
dataset = load_dataset("neulab/tldr", split='train')

# Append <start> and <end> tokens to cmd_texts
cmd_texts = ["<start> " + item['cmd'] + " <end>" for item in dataset]

# Combine nl_texts and cmd_texts for tokenizer fitting
nl_texts = [item['nl'] for item in dataset]
all_texts = nl_texts + cmd_texts

# Initialize and fit tokenizer
tokenizer = Tokenizer(filters='', lower=True, split=' ')
tokenizer.fit_on_texts(all_texts)
vocab_size = len(tokenizer.word_index) + 1  # +1 for zero padding

# Prepare sequences
nl_sequences = tokenizer.texts_to_sequences(nl_texts)
cmd_sequences = tokenizer.texts_to_sequences(cmd_texts)

# Determine maximum sequence length
max_length = max(max(len(seq) for seq in nl_sequences), max(len(seq) for seq in cmd_sequences))

# Pad sequences
nl_sequences_padded = pad_sequences(nl_sequences, maxlen=max_length, padding='post')
cmd_sequences_padded = pad_sequences(cmd_sequences, maxlen=max_length, padding='post')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1486: FutureWarning: The repository for neulab/tldr contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/neulab/tldr
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/4.92k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/2.97k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.76M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.28M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]

# %%
# Prepare decoder input data and target data
decoder_input_data = np.zeros_like(cmd_sequences_padded)
decoder_input_data[:, 1:] = cmd_sequences_padded[:, :-1]

# RL Training Setup
optimizer = Adam(learning_rate=1e-3)
epochs = 200
batch_size = 64
def build_model(vocab_size, max_length):
    # Define the dimensionality of the embedding and LSTM units
    embedding_dim = 256
    lstm_units = 256

    # Encoder
    encoder_inputs = Input(shape=(None,), name='encoder_inputs')
    encoder_embedding = Embedding(input_dim=vocab_size, output_dim=embedding_dim, name='encoder_embedding')(encoder_inputs)
    encoder_lstm = Bidirectional(LSTM(lstm_units, return_sequences=True, return_state=True, name='encoder_lstm'), name='bidirectional_encoder')
    encoder_outputs, forward_h, forward_c, backward_h, backward_c = encoder_lstm(encoder_embedding)

    # Since we are using a bidirectional LSTM, we need to concatenate the final states
    state_h = Concatenate(name='encoder_state_h')([forward_h, backward_h])
    state_c = Concatenate(name='encoder_state_c')([forward_c, backward_c])

    # Decoder
    decoder_inputs = Input(shape=(None,), name='decoder_inputs')
    decoder_embedding = Embedding(input_dim=vocab_size, output_dim=embedding_dim, name='decoder_embedding')(decoder_inputs)
    decoder_lstm = LSTM(2 * lstm_units, return_sequences=True, return_state=True, name='decoder_lstm')
    decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=[state_h, state_c])

    # Attention
    attention_layer = MultiHeadAttention(num_heads=4, key_dim=2 * lstm_units, name='multihead_attention')
    attention_output = attention_layer(query=decoder_outputs, key=encoder_outputs, value=encoder_outputs)

    # Concatenate attention input and decoder LSTM output
    decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attention_output])

    # Dense layer to predict each word probability
    dense_output = TimeDistributed(Dense(vocab_size, activation='softmax'), name='output_dense')(decoder_concat_input)

    # Define the model
    model = Model(inputs=[encoder_inputs, decoder_inputs], outputs=dense_output)

    # Compile the model with a suitable optimizer, loss, and metric
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    model.summary()  # Show model architecture

    return model

# Instantiate and compile the model
model = build_model(vocab_size, max_length)
optimizer = Adam(learning_rate=1e-3)
patience = 10  # Define patience for early stopping
best_bleu = 0   # Initialize the best BLEU score tracker
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ encoder_inputs            │ (None, None)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_embedding         │ (None, None, 256)      │      3,058,688 │ encoder_inputs[0][0]   │
# │ (Embedding)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ decoder_inputs            │ (None, None)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bidirectional_encoder     │ [(None, None, 512),    │      1,050,624 │ encoder_embedding[0][… │
# │ (Bidirectional)           │ (None, 256), (None,    │                │                        │
# │                           │ 256), (None, 256),     │                │                        │
# │                           │ (None, 256)]           │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ decoder_embedding         │ (None, None, 256)      │      3,058,688 │ decoder_inputs[0][0]   │
# │ (Embedding)               │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_state_h           │ (None, 512)            │              0 │ bidirectional_encoder… │
# │ (Concatenate)             │                        │                │ bidirectional_encoder… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ encoder_state_c           │ (None, 512)            │              0 │ bidirectional_encoder… │
# │ (Concatenate)             │                        │                │ bidirectional_encoder… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ decoder_lstm (LSTM)       │ [(None, None, 512),    │      1,574,912 │ decoder_embedding[0][… │
# │                           │ (None, 512), (None,    │                │ encoder_state_h[0][0], │
# │                           │ 512)]                  │                │ encoder_state_c[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multihead_attention       │ (None, None, 512)      │      4,200,960 │ bidirectional_encoder… │
# │ (MultiHeadAttention)      │                        │                │ decoder_lstm[0][0],    │
# │                           │                        │                │ bidirectional_encoder… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concat_layer              │ (None, None, 1024)     │              0 │ decoder_lstm[0][0],    │
# │ (Concatenate)             │                        │                │ multihead_attention[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_dense              │ (None, None, 11948)    │     12,246,700 │ concat_layer[0][0]     │
# │ (TimeDistributed)         │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 25,190,572 (96.09 MB)
#  Trainable params: 25,190,572 (96.09 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow as tf
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from nltk.translate import bleu_score

from nltk.translate.bleu_score import SmoothingFunction

def compute_bleu(references, predictions):
    """ Compute BLEU score for batch predictions with smoothing """
    smoothie = SmoothingFunction().method1  # Using smoothing technique method1
    bleu_scores = [sentence_bleu([ref.split()], pred.split(), weights=(0.25, 0.25, 0.25, 0.25), smoothing_function=smoothie) for ref, pred in zip(references, predictions)]
    return np.mean(bleu_scores)


def rl_training_step(input_seqs, target_seqs, model, tokenizer, optimizer):
    """ Perform a training step and return reward and loss """
    with tf.GradientTape() as tape:
        predictions = model([input_seqs, np.zeros_like(input_seqs)], training=True)
        loss = SparseCategoricalCrossentropy(from_logits=False)(target_seqs, predictions)

        # Convert predictions to text
        predicted_sequences = tf.argmax(predictions, axis=-1)
        predicted_texts = tokenizer.sequences_to_texts(predicted_sequences.numpy())
        target_texts = tokenizer.sequences_to_texts(target_seqs)

        # Compute BLEU score
        rewards = compute_bleu(target_texts, predicted_texts)
        reward = tf.reduce_mean(rewards)
        reward = tf.cast(reward, dtype=tf.float32)

        # Compute combined loss
        combined_loss = -tf.math.log(reward + 1e-9) + loss

    gradients = tape.gradient(combined_loss, model.trainable_variables)
    if gradients is None or any(g is None for g in gradients):
        print("No valid gradients. Check model and loss configuration.")
        return 0, 0

    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    return reward.numpy(), loss.numpy()


# Example use in the training loop
for epoch in range(epochs):
    indices = np.random.permutation(len(nl_sequences_padded))
    epoch_rewards = []
    epoch_losses = []
    for i in range(0, len(nl_sequences_padded), batch_size):
        batch_indices = indices[i:i + batch_size]
        reward, loss = rl_training_step(
            nl_sequences_padded[batch_indices],
            cmd_sequences_padded[batch_indices],
            model,
            tokenizer,
            optimizer
        )
        epoch_rewards.append(reward)
        epoch_losses.append(loss)

    avg_reward = np.mean(epoch_rewards)
    avg_loss = np.mean(epoch_losses)
    print(f"Epoch {epoch+1}: Average BLEU Reward = {avg_reward}, Loss = {avg_loss}")
    if avg_reward > best_bleu:
        best_bleu = avg_reward
        model.save(model_path)
        print(f"New best model saved with BLEU score: {best_bleu}")
        wait = 0
    else:
        wait += 1
        if wait >= patience:
            print("Early stopping...")
            break
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: Average BLEU Reward = 0.0552549734711647, Loss = 1.427756428718567
# New best model saved with BLEU score: 0.0552549734711647
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 2: Average BLEU Reward = 0.06440562754869461, Loss = 0.9528326392173767
# New best model saved with BLEU score: 0.06440562754869461
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3: Average BLEU Reward = 0.06533413380384445, Loss = 0.8930621147155762
# New best model saved with BLEU score: 0.06533413380384445
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 4: Average BLEU Reward = 0.06564897298812866, Loss = 0.8492655754089355
# New best model saved with BLEU score: 0.06564897298812866
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 5: Average BLEU Reward = 0.06650618463754654, Loss = 0.8080022931098938
# New best model saved with BLEU score: 0.06650618463754654
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 6: Average BLEU Reward = 0.06823883205652237, Loss = 0.7547717690467834
# New best model saved with BLEU score: 0.06823883205652237
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7: Average BLEU Reward = 0.07147785276174545, Loss = 0.7086248397827148
# New best model saved with BLEU score: 0.07147785276174545
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 8: Average BLEU Reward = 0.07547813653945923, Loss = 0.6655876040458679
# New best model saved with BLEU score: 0.07547813653945923
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 9: Average BLEU Reward = 0.08108708262443542, Loss = 0.6227487325668335
# New best model saved with BLEU score: 0.08108708262443542
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 10: Average BLEU Reward = 0.0889061912894249, Loss = 0.5720441341400146
# New best model saved with BLEU score: 0.0889061912894249
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 11: Average BLEU Reward = 0.10548181086778641, Loss = 0.5127752423286438
# New best model saved with BLEU score: 0.10548181086778641
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 12: Average BLEU Reward = 0.1255510300397873, Loss = 0.4538021981716156
# New best model saved with BLEU score: 0.1255510300397873
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 13: Average BLEU Reward = 0.15550807118415833, Loss = 0.39738327264785767
# New best model saved with BLEU score: 0.15550807118415833
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 14: Average BLEU Reward = 0.20904138684272766, Loss = 0.3415793478488922
# New best model saved with BLEU score: 0.20904138684272766
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 15: Average BLEU Reward = 0.2619902789592743, Loss = 0.29559794068336487
# New best model saved with BLEU score: 0.2619902789592743
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 16: Average BLEU Reward = 0.3258368968963623, Loss = 0.2578856348991394
# New best model saved with BLEU score: 0.3258368968963623
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 17: Average BLEU Reward = 0.3726440370082855, Loss = 0.2267271876335144
# New best model saved with BLEU score: 0.3726440370082855
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 18: Average BLEU Reward = 0.4276638627052307, Loss = 0.2013530284166336
# New best model saved with BLEU score: 0.4276638627052307
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 19: Average BLEU Reward = 0.4776475429534912, Loss = 0.18129490315914154
# New best model saved with BLEU score: 0.4776475429534912
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 20: Average BLEU Reward = 0.5183087587356567, Loss = 0.16399477422237396
# New best model saved with BLEU score: 0.5183087587356567
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 21: Average BLEU Reward = 0.5561036467552185, Loss = 0.14777132868766785
# New best model saved with BLEU score: 0.5561036467552185
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 22: Average BLEU Reward = 0.5875452160835266, Loss = 0.13590960204601288
# New best model saved with BLEU score: 0.5875452160835266
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 23: Average BLEU Reward = 0.6207478642463684, Loss = 0.12290127575397491
# New best model saved with BLEU score: 0.6207478642463684
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 24: Average BLEU Reward = 0.6560900807380676, Loss = 0.11188386380672455
# New best model saved with BLEU score: 0.6560900807380676
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 25: Average BLEU Reward = 0.6744707226753235, Loss = 0.10494065284729004
# New best model saved with BLEU score: 0.6744707226753235
# Epoch 26: Average BLEU Reward = 0.663984477519989, Loss = 0.10665435343980789
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 27: Average BLEU Reward = 0.6864967942237854, Loss = 0.10112183541059494
# New best model saved with BLEU score: 0.6864967942237854
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 28: Average BLEU Reward = 0.7239920496940613, Loss = 0.09010479599237442
# New best model saved with BLEU score: 0.7239920496940613
# Epoch 29: Average BLEU Reward = 0.5428977608680725, Loss = 0.16626647114753723
# Epoch 30: Average BLEU Reward = 0.6540541648864746, Loss = 0.10525581985712051
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 31: Average BLEU Reward = 0.7322658896446228, Loss = 0.08418123424053192
# New best model saved with BLEU score: 0.7322658896446228
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 32: Average BLEU Reward = 0.7750787138938904, Loss = 0.07287289947271347
# New best model saved with BLEU score: 0.7750787138938904
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 33: Average BLEU Reward = 0.7972219586372375, Loss = 0.06722596287727356
# New best model saved with BLEU score: 0.7972219586372375
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 34: Average BLEU Reward = 0.8155980110168457, Loss = 0.0625862181186676
# New best model saved with BLEU score: 0.8155980110168457
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 35: Average BLEU Reward = 0.8302013874053955, Loss = 0.05804962292313576
# New best model saved with BLEU score: 0.8302013874053955
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 36: Average BLEU Reward = 0.8391112685203552, Loss = 0.055187858641147614
# New best model saved with BLEU score: 0.8391112685203552
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 37: Average BLEU Reward = 0.8443979024887085, Loss = 0.05343588814139366
# New best model saved with BLEU score: 0.8443979024887085
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 38: Average BLEU Reward = 0.8485697507858276, Loss = 0.051236122846603394
# New best model saved with BLEU score: 0.8485697507858276
# Epoch 39: Average BLEU Reward = 0.8472580313682556, Loss = 0.05286308377981186
# Epoch 40: Average BLEU Reward = 0.8479263186454773, Loss = 0.05136576294898987
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 41: Average BLEU Reward = 0.8566272854804993, Loss = 0.04817615821957588
# New best model saved with BLEU score: 0.8566272854804993
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 42: Average BLEU Reward = 0.8636630177497864, Loss = 0.04572529345750809
# New best model saved with BLEU score: 0.8636630177497864
# Epoch 43: Average BLEU Reward = 0.8456494212150574, Loss = 0.04879550263285637
# Epoch 44: Average BLEU Reward = 0.8394469618797302, Loss = 0.051158588379621506
# Epoch 45: Average BLEU Reward = 0.8479113578796387, Loss = 0.048498280346393585
# Epoch 46: Average BLEU Reward = 0.8599933385848999, Loss = 0.045452333986759186
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 47: Average BLEU Reward = 0.8739767074584961, Loss = 0.041716400533914566
# New best model saved with BLEU score: 0.8739767074584961
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 48: Average BLEU Reward = 0.8785683512687683, Loss = 0.04074179753661156
# New best model saved with BLEU score: 0.8785683512687683
# Epoch 49: Average BLEU Reward = 0.8785335421562195, Loss = 0.04009300470352173
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 50: Average BLEU Reward = 0.8804525136947632, Loss = 0.04137453809380531
# New best model saved with BLEU score: 0.8804525136947632
# Epoch 51: Average BLEU Reward = 0.875637412071228, Loss = 0.04088438302278519
# Epoch 52: Average BLEU Reward = 0.8716857433319092, Loss = 0.04116284102201462
# Epoch 53: Average BLEU Reward = 0.8771958947181702, Loss = 0.040746986865997314
# Epoch 54: Average BLEU Reward = 0.8750103712081909, Loss = 0.0400402806699276
# Epoch 55: Average BLEU Reward = 0.8758222460746765, Loss = 0.039519235491752625
# Epoch 56: Average BLEU Reward = 0.8712751269340515, Loss = 0.040087681263685226
# Epoch 57: Average BLEU Reward = 0.8690462112426758, Loss = 0.04060320928692818
# Epoch 58: Average BLEU Reward = 0.8779487013816833, Loss = 0.03786556422710419
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 59: Average BLEU Reward = 0.8828919529914856, Loss = 0.03746591880917549
# New best model saved with BLEU score: 0.8828919529914856
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 60: Average BLEU Reward = 0.8886860609054565, Loss = 0.0359245240688324
# New best model saved with BLEU score: 0.8886860609054565
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 61: Average BLEU Reward = 0.8948726058006287, Loss = 0.03553905710577965
# New best model saved with BLEU score: 0.8948726058006287
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 62: Average BLEU Reward = 0.8997297286987305, Loss = 0.032974276691675186
# New best model saved with BLEU score: 0.8997297286987305
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 63: Average BLEU Reward = 0.9033153057098389, Loss = 0.03170562908053398
# New best model saved with BLEU score: 0.9033153057098389
# Epoch 64: Average BLEU Reward = 0.8821078538894653, Loss = 0.037381112575531006
# Epoch 65: Average BLEU Reward = 0.8750813603401184, Loss = 0.0380539633333683
# Epoch 66: Average BLEU Reward = 0.8895054459571838, Loss = 0.035750482231378555
# Epoch 67: Average BLEU Reward = 0.890917956829071, Loss = 0.034358132630586624
# Epoch 68: Average BLEU Reward = 0.8904756307601929, Loss = 0.03423405811190605
# Epoch 69: Average BLEU Reward = 0.9008812308311462, Loss = 0.032118551433086395
# Epoch 70: Average BLEU Reward = 0.8982999920845032, Loss = 0.03218657523393631
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 71: Average BLEU Reward = 0.904762327671051, Loss = 0.030205441638827324
# New best model saved with BLEU score: 0.904762327671051
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 72: Average BLEU Reward = 0.9104154109954834, Loss = 0.02951730042695999
# New best model saved with BLEU score: 0.9104154109954834
# Epoch 73: Average BLEU Reward = 0.9102648496627808, Loss = 0.03051701933145523
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 74: Average BLEU Reward = 0.9109330773353577, Loss = 0.02981886826455593
# New best model saved with BLEU score: 0.9109330773353577
# Exception ignored in: <function _xla_gc_callback at 0x7b61d0eb0ee0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 98, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-fdde600dabe9> in <cell line: 43>()
#      47     for i in range(0, len(nl_sequences_padded), batch_size):
#      48         batch_indices = indices[i:i + batch_size]
# ---> 49         reward, loss = rl_training_step(
#      50             nl_sequences_padded[batch_indices],
#      51             cmd_sequences_padded[batch_indices],
#
# <ipython-input-12-fdde600dabe9> in rl_training_step(input_seqs, target_seqs, model, tokenizer, optimizer)
#      15     """ Perform a training step and return reward and loss """
#      16     with tf.GradientTape() as tape:
# ---> 17         predictions = model([input_seqs, np.zeros_like(input_seqs)], training=True)
#      18         loss = SparseCategoricalCrossentropy(from_logits=False)(target_seqs, predictions)
#      19
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py in __call__(self, *args, **kwargs)
#     844                         outputs = super().__call__(*args, **kwargs)
#     845                 else:
# --> 846                     outputs = super().__call__(*args, **kwargs)
#     847                 # Change the layout for the layer output if needed.
#     848                 # This is useful for relayout intermediate tensor in the model
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/operation.py in __call__(self, *args, **kwargs)
#      46                 object_name=(f"{self.__class__.__name__}.call()"),
#      47             )
# ---> 48             return call_fn(*args, **kwargs)
#      49
#      50         # Plain flow.
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     154         bound_signature = None
#     155         try:
# --> 156             return fn(*args, **kwargs)
#     157         except Exception as e:
#     158             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/functional.py in call(self, inputs, training, mask)
#     200                 if mask is not None:
#     201                     x._keras_mask = mask
# --> 202         outputs = self._run_through_graph(
#     203             inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     204         )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/function.py in _run_through_graph(self, inputs, operation_fn, call_fn)
#     153                     outputs = call_fn(op, *args, **kwargs)
#     154                 else:
# --> 155                     outputs = op(*args, **kwargs)
#     156
#     157                 # Update tensor_dict.
#
# /usr/local/lib/python3.10/dist-packages/keras/src/models/functional.py in call(*args, **kwargs)
#     590         ):
#     591             kwargs["training"] = training
# --> 592         return operation(*args, **kwargs)
#     593
#     594     return call
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py in __call__(self, *args, **kwargs)
#     844                         outputs = super().__call__(*args, **kwargs)
#     845                 else:
# --> 846                     outputs = super().__call__(*args, **kwargs)
#     847                 # Change the layout for the layer output if needed.
#     848                 # This is useful for relayout intermediate tensor in the model
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/operation.py in __call__(self, *args, **kwargs)
#      46                 object_name=(f"{self.__class__.__name__}.call()"),
#      47             )
# ---> 48             return call_fn(*args, **kwargs)
#      49
#      50         # Plain flow.
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     154         bound_signature = None
#     155         try:
# --> 156             return fn(*args, **kwargs)
#     157         except Exception as e:
#     158             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py in call(self, sequences, initial_state, mask, training)
#     216             forward_state, backward_state = None, None
#     217
# --> 218         y = self.forward_layer(
#     219             forward_inputs, initial_state=forward_state, **kwargs
#     220         )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py in __call__(self, *args, **kwargs)
#     844                         outputs = super().__call__(*args, **kwargs)
#     845                 else:
# --> 846                     outputs = super().__call__(*args, **kwargs)
#     847                 # Change the layout for the layer output if needed.
#     848                 # This is useful for relayout intermediate tensor in the model
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/operation.py in __call__(self, *args, **kwargs)
#      46                 object_name=(f"{self.__class__.__name__}.call()"),
#      47             )
# ---> 48             return call_fn(*args, **kwargs)
#      49
#      50         # Plain flow.
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     154         bound_signature = None
#     155         try:
# --> 156             return fn(*args, **kwargs)
#     157         except Exception as e:
#     158             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/lstm.py in call(self, sequences, initial_state, mask, training)
#     558
#     559     def call(self, sequences, initial_state=None, mask=None, training=False):
# --> 560         return super().call(
#     561             sequences, mask=mask, training=training, initial_state=initial_state
#     562         )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py in call(self, sequences, initial_state, mask, training)
#     404         )
#     405
# --> 406         last_output, outputs, states = self.inner_loop(
#     407             sequences=sequences,
#     408             initial_state=initial_state,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/lstm.py in inner_loop(self, sequences, initial_state, mask, training)
#     553                 "to a non-cuDNN implementation."
#     554             )
# --> 555         return super().inner_loop(
#     556             sequences, initial_state, mask=mask, training=training
#     557         )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py in inner_loop(self, sequences, initial_state, mask, training)
#     344             initial_state = [initial_state]
#     345
# --> 346         return backend.rnn(
#     347             step,
#     348             sequences,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/rnn.py in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask, return_all_outputs)
#     426                 return (time + 1, output_ta_t) + tuple(new_states)
#     427
# --> 428             final_outputs = tf.while_loop(
#     429                 body=_step,
#     430                 loop_vars=(time, output_ta) + states,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     658                   'in a future version' if date is None else
#     659                   ('after %s' % date), instructions)
# --> 660       return func(*args, **kwargs)
#     661
#     662     doc = _add_deprecated_arg_value_notice_to_docstring(func.__doc__, date,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/while_loop.py in while_loop_v2(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#     239
#     240   """
# --> 241   return while_loop(
#     242       cond=cond,
#     243       body=body,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/while_loop.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     486                                               list(loop_vars))
#     487       while cond(*loop_vars):
# --> 488         loop_vars = body(*loop_vars)
#     489         if try_to_pack and not isinstance(loop_vars, (list, tuple)):
#     490           packed = True
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/while_loop.py in <lambda>(i, lv)
#     477         cond = lambda i, lv: (  # pylint: disable=g-long-lambda
#     478             math_ops.logical_and(i < maximum_iterations, orig_cond(*lv)))
# --> 479         body = lambda i, lv: (i + 1, orig_body(*lv))
#     480       try_to_pack = False
#     481
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/rnn.py in _step(time, output_ta_t, *states)
#     409                 current_input = tuple(ta.read(time) for ta in input_ta)
#     410                 current_input = tree.pack_sequence_as(inputs, current_input)
# --> 411                 output, new_states = step_function(
#     412                     current_input, tuple(states) + tuple(constants)
#     413                 )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py in step(inputs, states)
#     336
#     337         def step(inputs, states):
# --> 338             output, new_states = self.cell(inputs, states, **cell_kwargs)
#     339             if not tree.is_nested(new_states):
#     340                 new_states = [new_states]
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py in __call__(self, *args, **kwargs)
#     844                         outputs = super().__call__(*args, **kwargs)
#     845                 else:
# --> 846                     outputs = super().__call__(*args, **kwargs)
#     847                 # Change the layout for the layer output if needed.
#     848                 # This is useful for relayout intermediate tensor in the model
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/operation.py in __call__(self, *args, **kwargs)
#      46                 object_name=(f"{self.__class__.__name__}.call()"),
#      47             )
# ---> 48             return call_fn(*args, **kwargs)
#      49
#      50         # Plain flow.
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     154         bound_signature = None
#     155         try:
# --> 156             return fn(*args, **kwargs)
#     157         except Exception as e:
#     158             if hasattr(e, "_keras_call_info_injected"):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/lstm.py in call(self, inputs, states, training)
#     262             c, o = self._compute_carry_and_output(x, h_tm1, c_tm1)
#     263         else:
# --> 264             z = ops.matmul(inputs, self.kernel)
#     265
#     266             z += ops.matmul(h_tm1, self.recurrent_kernel)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/ops/numpy.py in matmul(x1, x2)
#    3438     if any_symbolic_tensors((x1, x2)):
#    3439         return Matmul().symbolic_call(x1, x2)
# -> 3440     return backend.numpy.matmul(x1, x2)
#    3441
#    3442
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/numpy.py in matmul(x1, x2)
#     373         output_type = None
#     374     x1 = tf.cast(x1, compute_dtype)
# --> 375     x2 = tf.cast(x2, compute_dtype)
#     376
#     377     def with_combined_batch_dimensions(a, b, output_shape, fn_3d):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/math_ops.py in cast(x, dtype, name)
#    1016             "intended."
#    1017         )
# -> 1018       if x.dtype != base_type:
#    1019         x = gen_math_ops.cast(x, base_type, name=name)
#    1020     return x
#
# KeyboardInterrupt:

# %%
# Load the model
model_path = '/content/drive/My Drive/model_BiLSTM_word_reinforcement_V2.h5'
model = load_model(model_path)
def translate(model, tokenizer, text, max_length):
    # Tokenize the input text
    sequence = tokenizer.texts_to_sequences([text])
    sequence_padded = pad_sequences(sequence, maxlen=max_length, padding='post')

    # Prepare the decoder input data
    decoder_input_data = np.zeros_like(sequence_padded)
    decoder_input_data[:, 1:] = sequence_padded[:, :-1]

    # Predict
    prediction = model.predict([sequence_padded, decoder_input_data])

    # Convert prediction to text
    predicted_sequence = np.argmax(prediction[0], axis=-1)
    predicted_text = tokenizer.sequences_to_texts([predicted_sequence])

    # Remove the <start> and <end> tokens
    predicted_text_clean = [token for token in predicted_text[0].split() if token not in ['<start>', '<end>']]

    # Join the tokens back together
    predicted_command = ' '.join(predicted_text_clean)

    return predicted_command
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Get the first 10 rows of the training dataset
first_10_nl_texts = nl_texts[:100]
first_10_cmd_texts = cmd_texts[:100]

# Translate each text and print the input, prediction, and actual command
for i in range(100):
    input_text = first_10_nl_texts[i]
    actual_command = first_10_cmd_texts[i]
    predicted_command = translate(model, tokenizer, input_text, max_length)

    print(f"Input Text: {input_text}")
    print(f"Predicted Command: {predicted_command}")
    print(f"Actual Command: {actual_command}")
    print("\n---\n")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Input Text: <start> get the label of a fat32 partition <end>
# Predicted Command: decode members generate unused logs
# Actual Command: <start> fatlabel {{/dev/sda1}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Input Text: <start> set the label of a fat32 partition <end>
# Predicted Command: ascii framework generate {{file.pdf}} logs {{foo}}
# Actual Command: <start> fatlabel {{/dev/sdc3}} "{{new_label}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Input Text: <start> search for a package in your current sources <end>
# Predicted Command: "{{title}}" docker file,
# Actual Command: <start> apt-cache search {{query}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Input Text: <start> show information about a package <end>
# Predicted Command: sudo default
# Actual Command: <start> apt-cache show {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Input Text: <start> show whether a package is installed and up to date <end>
# Predicted Command: sudo openconnect information pr entire
# Actual Command: <start> apt-cache policy {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> show dependencies for a package <end>
# Predicted Command: assimp default default
# Actual Command: <start> apt-cache depends {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Input Text: <start> show packages that depend on a particular package <end>
# Predicted Command: -with default {{5}} allows
# Actual Command: <start> apt-cache rdepends {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: <start> refresh database content <end>
# Predicted Command: wc default additional email
# Actual Command: <start> sudo updatedb <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Input Text: <start> display file names as soon as they are found <end>
# Predicted Command: {{50}} {{user}} size video
# Actual Command: <start> sudo updatedb --verbose <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Input Text: <start> install a new package <end>
# Predicted Command: {{app_name}} multiple
# Actual Command: <start> sudo pacman --sync {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Input Text: <start> synchronize and update all packages (add `downloadonly` to download the packages and not update them) <end>
# Predicted Command: decoding -u {{command}}
# Actual Command: <start> sudo pacman --sync --refresh --sysupgrade <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Input Text: <start> update all packages and install a new one without prompting <end>
# Predicted Command: newline btrfs index
# Actual Command: <start> sudo pacman --sync --refresh --sysupgrade --noconfirm {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Input Text: <start> search the package database for a regular expression or keyword <end>
# Predicted Command: sudo docker mode information
# Actual Command: <start> pacman --sync --search "{{search_pattern}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Input Text: <start> display information about a package <end>
# Predicted Command: sudo information
# Actual Command: <start> pacman --sync --info {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Input Text: <start> overwrite conflicting files during a package update <end>
# Predicted Command: sudo docker issue
# Actual Command: <start> sudo pacman --sync --refresh --sysupgrade --overwrite {{path/to/file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Input Text: <start> synchronize and update all packages, but ignore a specific package (can be used more than once) <end>
# Predicted Command: editor) --package launch launch
# Actual Command: <start> sudo pacman --sync --refresh --sysupgrade --ignore {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Input Text: <start> remove not installed packages and unused repositories from the cache (use two `clean` flags to clean all packages) <end>
# Predicted Command: --quiet unload mpd guix annex
# Actual Command: <start> sudo pacman --sync --clean <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Input Text: <start> display help for this subcommand <end>
# Predicted Command: set {{command}}
# Actual Command: <start> pacman --remove --help <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Input Text: <start> remove a package and its dependencies <end>
# Predicted Command: {{project}} that that information
# Actual Command: <start> sudo pacman --remove --recursive {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Input Text: <start> remove a package and both its dependencies and configuration files <end>
# Predicted Command: asterisk docker docker pattern
# Actual Command: <start> sudo pacman --remove --recursive --nosave {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Input Text: <start> remove a package without prompting <end>
# Predicted Command: save secret tabletpcbutton
# Actual Command: <start> sudo pacman --remove --noconfirm {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Input Text: <start> remove orphan packages (installed as dependencies but not required by any package) <end>
# Predicted Command: system gh devices undo
# Actual Command: <start> sudo pacman --remove --recursive --nosave $(pacman --query --unrequired --deps --quiet) <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Input Text: <start> remove a package and all packages that depend on it <end>
# Predicted Command: duplicity -u commit
# Actual Command: <start> sudo pacman --remove --cascade {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Input Text: <start> list packages that would be affected (does not remove any packages) <end>
# Predicted Command: number devices
# Actual Command: <start> pacman --remove --print {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Input Text: <start> display bpftrace version <end>
# Predicted Command: bpftrace detailed nft
# Actual Command: <start> bpftrace -V <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> list all available probes <end>
# Predicted Command: battery branch
# Actual Command: <start> sudo bpftrace -l <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Input Text: <start> run a oneliner program (e.g. syscall count by program) <end>
# Predicted Command: uncrustify
# Actual Command: <start> sudo bpftrace -e '{{tracepoint:raw_syscalls:sys_enter { @[comm] = count(); }}}' <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Input Text: <start> run a program from a file <end>
# Predicted Command: from additional
# Actual Command: <start> sudo bpftrace {{path/to/file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Input Text: <start> trace a program by pid <end>
# Predicted Command: that} devices
# Actual Command: <start> sudo bpftrace -e '{{tracepoint:raw_syscalls:sys_enter /pid == 123/ { @[comm] = count(); }}}' <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Input Text: <start> do a dry run and display the output in ebpf format <end>
# Predicted Command: tput cpu cpu
# Actual Command: <start> sudo bpftrace -d -e '{{one_line_program}}' <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Input Text: <start> open a file in the default editor <end>
# Predicted Command: battery by by
# Actual Command: <start> sensible-editor {{file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Input Text: <start> open a file in the default editor, with the cursor at the end of the file <end>
# Predicted Command: specified docker line by
# Actual Command: <start> sensible-editor + {{file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Input Text: <start> open a file in the default editor, with the cursor at the beginning of line 10 <end>
# Predicted Command: tr that https docker tsacert.pem 1
# Actual Command: <start> sensible-editor +10 {{file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Input Text: <start> open 3 files in vertically split editor windows at the same time <end>
# Predicted Command: hostnames password password password gpg2
# Actual Command: <start> sensible-editor -O3 {{file_1}} {{file_2}} {{file_3}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Input Text: <start> integrate firejail with your desktop environment <end>
# Predicted Command: {{filename.svg}} information information `perf.data` logs `/`)
# Actual Command: <start> sudo firecfg <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Input Text: <start> open a restricted mozilla firefox <end>
# Predicted Command: into -type user
# Actual Command: <start> firejail {{firefox}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Input Text: <start> start a restricted apache server on a known interface and address <end>
# Predicted Command: save -u shell docker
# Actual Command: <start> firejail --net={{eth0}} --ip={{192.168.1.244}} {{/etc/init.d/apache2}} {{start}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Input Text: <start> list running sandboxes <end>
# Predicted Command: keys start {{file_opt.bc}}
# Actual Command: <start> firejail --list <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Input Text: <start> list network activity from running sandboxes <end>
# Predicted Command: keys agent {{file_opt.bc}}
# Actual Command: <start> firejail --netstats <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> shutdown a running sandbox <end>
# Predicted Command: sudo help
# Actual Command: <start> firejail --shutdown={{7777}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: <start> build the package in the current directory <end>
# Predicted Command: wireless without logs
# Actual Command: <start> debuild <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: <start> build a binary package only <end>
# Predicted Command: sudo gunicorn default 3
# Actual Command: <start> debuild -b <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Input Text: <start> do not run lintian after building the package <end>
# Predicted Command: rather gunicorn '{{mariadb*}}' 3 3
# Actual Command: <start> debuild --no-lintian <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> start nmon <end>
# Predicted Command: year
# Actual Command: <start> nmon <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Input Text: <start> save records to file ("s 300 c 288" by default) <end>
# Predicted Command: xman mode julia user
# Actual Command: <start> nmon -f <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> save records to file with a total of 240 measurements, by taking 30 seconds between each measurement <end>
# Predicted Command: --database that xpdf
# Actual Command: <start> nmon -f -s {{30}} -c {{240}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Input Text: <start> view the queue <end>
# Predicted Command: diff [a]rchive logs
# Actual Command: <start> squeue <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Input Text: <start> view jobs queued by a specific user <end>
# Predicted Command: jobs help showing
# Actual Command: <start> squeue -u {{username}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> view the queue and refresh every 5 seconds <end>
# Predicted Command: entry 75% remove llvm-bcanalyzer
# Actual Command: <start> squeue -i {{5}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Input Text: <start> view the queue with expected start times <end>
# Predicted Command: from start kate --column stty
# Actual Command: <start> squeue --start <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Input Text: <start> show the progress of running coreutils <end>
# Predicted Command: gzip enable vnc also
# Actual Command: <start> progress <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Input Text: <start> show the progress of running coreutils in quiet mode <end>
# Predicted Command: gzip enable vnc also
# Actual Command: <start> progress -q <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Input Text: <start> launch and monitor a single longrunning command <end>
# Predicted Command: keys removed runlevels enscript 3
# Actual Command: <start> {{command}} & progress -mp $! <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# Input Text: <start> start i7z (needs to be run in superuser mode) <end>
# Predicted Command: sudo "select until
# Actual Command: <start> sudo i7z <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Input Text: <start> discover directories using a [w]ordlist on a target [u]rl with [c]olorized and [v]erbose output <end>
# Predicted Command: into file, mocp dumpe2fs information
# Actual Command: <start> ffuf -w {{path/to/wordlist}} -u {{https://target/FUZZ}} -c -v <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> fuzz host[h]eaders with a host file on a traget website and [m]atch http 200 [c]ode responses <end>
# Predicted Command: dnsrecon gh remove would remove default
# Actual Command: <start> ffuf -w {{hosts.txt}} -u {{https://example.org}} -H "{{Host: FUZZ}}" -mc {{200}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: <start> discover directories using a [w]ordlist on a target website with a max individual job time of 60 seconds and recursion discovery depth of 2 levels <end>
# Predicted Command: outlining custom platformio dumpe2fs pool-build {{path/to/output_file.pdf}} slackbuild
# Actual Command: <start> ffuf -w {{path/to/wordlist}} -u {{https://target/FUZZ}} -maxtime-job {{60}} -recursion -recursion-depth {{2}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> fuzz get parameter on a target website and [f]ilter out message [s]ize response of 4242 bytes <end>
# Predicted Command: from basic gw4 uploading {{num}} if=/dev/urandom shut
# Actual Command: <start> ffuf -w {{path/to/param_names.txt}} -u {{https://target/script.php?FUZZ=test_value}} -fs {{4242}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> fuzz post method with post [d]ata of password on a target website and [f]ilter out http response [c]ode 401 <end>
# Predicted Command: configure password information prompt --list-targets password password java
# Actual Command: <start> ffuf -w {{path/to/postdata.txt}} -X {{POST}} -d "{{username=admin\&password=FUZZ}}" -u {{https://target/login.php}} -fc {{401}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Input Text: <start> discover subdomains using a subdoomain list on a target website <end>
# Predicted Command: lpr generate generate generate
# Actual Command: <start> ffuf -w {{subdomains.txt}} -u {{https://website.com}} -H "{{Host: FUZZ.website.com}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: <start> add all package binaries in the current directory and remove the old database file <end>
# Predicted Command: running that
# Actual Command: <start> repo-add --remove {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Input Text: <start> add all package binaries in the current directory in silent mode except for warning and error messages <end>
# Predicted Command: from basic force stash
# Actual Command: <start> repo-add --quiet {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Input Text: <start> add all package binaries in the current directory without showing color <end>
# Predicted Command: babel multiple
# Actual Command: <start> repo-add --nocolor {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Input Text: <start> display executable invocations per user (username not displayed) <end>
# Predicted Command: phpdox only, runlevels one, 3
# Actual Command: <start> sudo sa <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> display executable invocations per user, showing responsible usernames <end>
# Predicted Command: key {{path/to/directory}} logs
# Actual Command: <start> sudo sa --print-users <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> list resources used recently per user <end>
# Predicted Command: == records) months|weeks|days|hours|seconds
# Actual Command: <start> sudo sa --user-summary <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Input Text: <start> edit the password file <end>
# Predicted Command: + by
# Actual Command: <start> vipw <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Input Text: <start> display the current version of `vipw` <end>
# Predicted Command: from height logs newer)
# Actual Command: <start> vipw --version <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Input Text: <start> retrieve current status of the jail service <end>
# Predicted Command: sudo {{rtmp://example.com/path/to/video}} initialization gh {{foo}}
# Actual Command: <start> fail2ban-client status {{jail}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Input Text: <start> remove the specified ip from the jail service's ban list <end>
# Predicted Command: from {{path/to/file_or_directory}} information devices homectl
# Actual Command: <start> fail2ban-client set {{jail}} unbanip {{ip}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Input Text: <start> verify fail2ban server is alive <end>
# Predicted Command: than --exclude
# Actual Command: <start> fail2ban-client ping <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Input Text: <start> synchronize and set date and time <end>
# Predicted Command: desktop default name days http//localhostport
# Actual Command: <start> sudo ntpdate {{host}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Input Text: <start> query the host without setting the time <end>
# Predicted Command: from name logs
# Actual Command: <start> ntpdate -q {{host}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: <start> use an unprivileged port in case a firewall is blocking privileged ports <end>
# Predicted Command: fonts -u docker
# Actual Command: <start> sudo ntpdate -u {{host}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Input Text: <start> force time to be stepped using `settimeofday` instead of `slewed` <end>
# Predicted Command: inventory {{network_name}} test}} elvi's
# Actual Command: <start> sudo ntpdate -b {{host}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> show all running services <end>
# Predicted Command: {{hash_value}} default fcrackzip
# Actual Command: <start> systemctl status <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: <start> list failed units <end>
# Predicted Command: wc default
# Actual Command: <start> systemctl --failed <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> start/stop/restart/reload a service <end>
# Predicted Command: {{7}} gh
# Actual Command: <start> systemctl {{start|stop|restart|reload}} {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Input Text: <start> show the status of a unit <end>
# Predicted Command: sudo default by
# Actual Command: <start> systemctl status {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Input Text: <start> enable/disable a unit to be started on bootup <end>
# Predicted Command: musescore
# Actual Command: <start> systemctl {{enable|disable}} {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# Input Text: <start> mask/unmask a unit to prevent enablement and manual activation <end>
# Predicted Command: trans file, pdfgrep
# Actual Command: <start> systemctl {{mask|unmask}} {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> reload systemd, scanning for new or changed units <end>
# Predicted Command: system -u index {{/dev/sdxn}}
# Actual Command: <start> systemctl daemon-reload <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> check if a unit is enabled <end>
# Predicted Command: than
# Actual Command: <start> systemctl is-enabled {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: <start> run `ipconfig.exe` program <end>
# Predicted Command: + -d
# Actual Command: <start> wine {{ipconfig}} {{/all}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> run `cmd.exe` in background <end>
# Predicted Command: transmission-cli {{75}}% {{header-name:header-value}} tagged
# Actual Command: <start> wine start {{cmd}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Input Text: <start> run windowslike package manager <end>
# Predicted Command: sudo
# Actual Command: <start> wine uninstaller <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> install msi packages <end>
# Predicted Command: argument encryption {{path/to/cipher_dir}}
# Actual Command: <start> wine msiexec /i {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> display a message in fullscreen <end>
# Predicted Command: computer information
# Actual Command: <start> sm "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> display a message with inverted colors <end>
# Predicted Command: ngrok java information returning
# Actual Command: <start> sm -i "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Input Text: <start> display a message with a custom foreground color <end>
# Predicted Command: from "{{title}}" secret secret
# Actual Command: <start> sm -f {{blue}} "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Input Text: <start> display a message with a custom background color <end>
# Predicted Command: system background {{input_file}} its {{8.8.8.8}}
# Actual Command: <start> sm -b {{#008888}} "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> display a message rotated 3 times (in steps of 90 degrees, counterclockwise) <end>
# Predicted Command: sudo start ag jstack state, --web
# Actual Command: <start> sm -r {{3}} "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Input Text: <start> display a message using the output from another command <end>
# Predicted Command: from {{path/to/file_or_directory}} cmatrix prompted
# Actual Command: <start> {{echo "Hello World!"}} | sm - <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Input Text: <start> create a btrfs filesystem on a single device <end>
# Predicted Command: connects name generate
# Actual Command: <start> sudo mkfs.btrfs --metadata single --data single {{/dev/sda}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Input Text: <start> create a btrfs filesystem on multiple devices with raid1 <end>
# Predicted Command: e default default {{path/to/file.tar}}
# Actual Command: <start> sudo mkfs.btrfs --metadata raid1 --data raid1 {{/dev/sda}} {{/dev/sdb}} {{/dev/sdN}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Input Text: <start> set a label for the filesystem <end>
# Predicted Command: into user ghci omitted that
# Actual Command: <start> sudo mkfs.btrfs --label "{{label}}" {{/dev/sda}} [{{/dev/sdN}}] <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Input Text: <start> mount a `.raw` image file into a dmg container file <end>
# Predicted Command: unused mode gh by
# Actual Command: <start> xmount --in {{raw}} {{path/to/image.dd}} --out {{dmg}} {{mountpoint}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Input Text: <start> mount an ewf image file with writecache support into a vhd file to boot from <end>
# Predicted Command: {{archive_file.dump}} unused then one one
# Actual Command: <start> xmount --cache {{path/to/cache.ovl}} --in {{ewf}} {{path/to/image.E??}} --out {{vhd}} {{mountpoint}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> mount the first partition at sector 2048 into a new `.raw` image file <end>
# Predicted Command: {{file.ext}} first julia one
# Actual Command: <start> xmount --offset {{2048}} --in {{raw}} {{path/to/image.dd}} --out {{raw}} {{mountpoint}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Input Text: <start> show the current number lock status <end>
# Predicted Command: sudo default default
# Actual Command: <start> numlockx status <end>
#
# ---

# %%
# Load dataset
dataset_val = load_dataset("neulab/tldr", split='validation')

# Append <start> and <end> tokens to cmd_texts
cmd_text_val = ["<start> " + item['cmd'] + " <end>" for item in dataset_val]

# Combine nl_texts and cmd_texts for tokenizer fitting
nl_texts_val = [item['nl'] for item in dataset_val]

# Get the first 10 rows of the training dataset
first_100_nl_texts_val = nl_texts[:100]
first_100_cmd_texts_val = cmd_texts[:100]

# Translate each text and print the input, prediction, and actual command
for i in range(100):
    input_text = first_100_nl_texts_val[i]
    actual_command = first_100_cmd_texts_val[i]
    predicted_command = translate(model, tokenizer, input_text, max_length)

    print(f"Input Text: {input_text}")
    print(f"Predicted Command: {predicted_command}")
    print(f"Actual Command: {actual_command}")
    print("\n---\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1486: FutureWarning: The repository for neulab/tldr contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/neulab/tldr
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Input Text: <start> get the label of a fat32 partition <end>
# Predicted Command: decode members generate unused logs
# Actual Command: <start> fatlabel {{/dev/sda1}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> set the label of a fat32 partition <end>
# Predicted Command: ascii framework generate {{file.pdf}} logs {{foo}}
# Actual Command: <start> fatlabel {{/dev/sdc3}} "{{new_label}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: <start> search for a package in your current sources <end>
# Predicted Command: "{{title}}" docker file,
# Actual Command: <start> apt-cache search {{query}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> show information about a package <end>
# Predicted Command: sudo default
# Actual Command: <start> apt-cache show {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Input Text: <start> show whether a package is installed and up to date <end>
# Predicted Command: sudo openconnect information pr entire
# Actual Command: <start> apt-cache policy {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> show dependencies for a package <end>
# Predicted Command: assimp default default
# Actual Command: <start> apt-cache depends {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: <start> show packages that depend on a particular package <end>
# Predicted Command: -with default {{5}} allows
# Actual Command: <start> apt-cache rdepends {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> refresh database content <end>
# Predicted Command: wc default additional email
# Actual Command: <start> sudo updatedb <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: <start> display file names as soon as they are found <end>
# Predicted Command: {{50}} {{user}} size video
# Actual Command: <start> sudo updatedb --verbose <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Input Text: <start> install a new package <end>
# Predicted Command: {{app_name}} multiple
# Actual Command: <start> sudo pacman --sync {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Input Text: <start> synchronize and update all packages (add `downloadonly` to download the packages and not update them) <end>
# Predicted Command: decoding -u {{command}}
# Actual Command: <start> sudo pacman --sync --refresh --sysupgrade <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> update all packages and install a new one without prompting <end>
# Predicted Command: newline btrfs index
# Actual Command: <start> sudo pacman --sync --refresh --sysupgrade --noconfirm {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> search the package database for a regular expression or keyword <end>
# Predicted Command: sudo docker mode information
# Actual Command: <start> pacman --sync --search "{{search_pattern}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> display information about a package <end>
# Predicted Command: sudo information
# Actual Command: <start> pacman --sync --info {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: <start> overwrite conflicting files during a package update <end>
# Predicted Command: sudo docker issue
# Actual Command: <start> sudo pacman --sync --refresh --sysupgrade --overwrite {{path/to/file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: <start> synchronize and update all packages, but ignore a specific package (can be used more than once) <end>
# Predicted Command: editor) --package launch launch
# Actual Command: <start> sudo pacman --sync --refresh --sysupgrade --ignore {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> remove not installed packages and unused repositories from the cache (use two `clean` flags to clean all packages) <end>
# Predicted Command: --quiet unload mpd guix annex
# Actual Command: <start> sudo pacman --sync --clean <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: <start> display help for this subcommand <end>
# Predicted Command: set {{command}}
# Actual Command: <start> pacman --remove --help <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Input Text: <start> remove a package and its dependencies <end>
# Predicted Command: {{project}} that that information
# Actual Command: <start> sudo pacman --remove --recursive {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: <start> remove a package and both its dependencies and configuration files <end>
# Predicted Command: asterisk docker docker pattern
# Actual Command: <start> sudo pacman --remove --recursive --nosave {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> remove a package without prompting <end>
# Predicted Command: save secret tabletpcbutton
# Actual Command: <start> sudo pacman --remove --noconfirm {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Input Text: <start> remove orphan packages (installed as dependencies but not required by any package) <end>
# Predicted Command: system gh devices undo
# Actual Command: <start> sudo pacman --remove --recursive --nosave $(pacman --query --unrequired --deps --quiet) <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Input Text: <start> remove a package and all packages that depend on it <end>
# Predicted Command: duplicity -u commit
# Actual Command: <start> sudo pacman --remove --cascade {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: <start> list packages that would be affected (does not remove any packages) <end>
# Predicted Command: number devices
# Actual Command: <start> pacman --remove --print {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: <start> display bpftrace version <end>
# Predicted Command: bpftrace detailed nft
# Actual Command: <start> bpftrace -V <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: <start> list all available probes <end>
# Predicted Command: battery branch
# Actual Command: <start> sudo bpftrace -l <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Input Text: <start> run a oneliner program (e.g. syscall count by program) <end>
# Predicted Command: uncrustify
# Actual Command: <start> sudo bpftrace -e '{{tracepoint:raw_syscalls:sys_enter { @[comm] = count(); }}}' <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> run a program from a file <end>
# Predicted Command: from additional
# Actual Command: <start> sudo bpftrace {{path/to/file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Input Text: <start> trace a program by pid <end>
# Predicted Command: that} devices
# Actual Command: <start> sudo bpftrace -e '{{tracepoint:raw_syscalls:sys_enter /pid == 123/ { @[comm] = count(); }}}' <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Input Text: <start> do a dry run and display the output in ebpf format <end>
# Predicted Command: tput cpu cpu
# Actual Command: <start> sudo bpftrace -d -e '{{one_line_program}}' <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: <start> open a file in the default editor <end>
# Predicted Command: battery by by
# Actual Command: <start> sensible-editor {{file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: <start> open a file in the default editor, with the cursor at the end of the file <end>
# Predicted Command: specified docker line by
# Actual Command: <start> sensible-editor + {{file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Input Text: <start> open a file in the default editor, with the cursor at the beginning of line 10 <end>
# Predicted Command: tr that https docker tsacert.pem 1
# Actual Command: <start> sensible-editor +10 {{file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> open 3 files in vertically split editor windows at the same time <end>
# Predicted Command: hostnames password password password gpg2
# Actual Command: <start> sensible-editor -O3 {{file_1}} {{file_2}} {{file_3}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: <start> integrate firejail with your desktop environment <end>
# Predicted Command: {{filename.svg}} information information `perf.data` logs `/`)
# Actual Command: <start> sudo firecfg <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Input Text: <start> open a restricted mozilla firefox <end>
# Predicted Command: into -type user
# Actual Command: <start> firejail {{firefox}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> start a restricted apache server on a known interface and address <end>
# Predicted Command: save -u shell docker
# Actual Command: <start> firejail --net={{eth0}} --ip={{192.168.1.244}} {{/etc/init.d/apache2}} {{start}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> list running sandboxes <end>
# Predicted Command: keys start {{file_opt.bc}}
# Actual Command: <start> firejail --list <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> list network activity from running sandboxes <end>
# Predicted Command: keys agent {{file_opt.bc}}
# Actual Command: <start> firejail --netstats <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: <start> shutdown a running sandbox <end>
# Predicted Command: sudo help
# Actual Command: <start> firejail --shutdown={{7777}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: <start> build the package in the current directory <end>
# Predicted Command: wireless without logs
# Actual Command: <start> debuild <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Input Text: <start> build a binary package only <end>
# Predicted Command: sudo gunicorn default 3
# Actual Command: <start> debuild -b <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> do not run lintian after building the package <end>
# Predicted Command: rather gunicorn '{{mariadb*}}' 3 3
# Actual Command: <start> debuild --no-lintian <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Input Text: <start> start nmon <end>
# Predicted Command: year
# Actual Command: <start> nmon <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Input Text: <start> save records to file ("s 300 c 288" by default) <end>
# Predicted Command: xman mode julia user
# Actual Command: <start> nmon -f <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Input Text: <start> save records to file with a total of 240 measurements, by taking 30 seconds between each measurement <end>
# Predicted Command: --database that xpdf
# Actual Command: <start> nmon -f -s {{30}} -c {{240}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Input Text: <start> view the queue <end>
# Predicted Command: diff [a]rchive logs
# Actual Command: <start> squeue <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: <start> view jobs queued by a specific user <end>
# Predicted Command: jobs help showing
# Actual Command: <start> squeue -u {{username}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Input Text: <start> view the queue and refresh every 5 seconds <end>
# Predicted Command: entry 75% remove llvm-bcanalyzer
# Actual Command: <start> squeue -i {{5}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> view the queue with expected start times <end>
# Predicted Command: from start kate --column stty
# Actual Command: <start> squeue --start <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Input Text: <start> show the progress of running coreutils <end>
# Predicted Command: gzip enable vnc also
# Actual Command: <start> progress <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: <start> show the progress of running coreutils in quiet mode <end>
# Predicted Command: gzip enable vnc also
# Actual Command: <start> progress -q <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: <start> launch and monitor a single longrunning command <end>
# Predicted Command: keys removed runlevels enscript 3
# Actual Command: <start> {{command}} & progress -mp $! <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Input Text: <start> start i7z (needs to be run in superuser mode) <end>
# Predicted Command: sudo "select until
# Actual Command: <start> sudo i7z <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Input Text: <start> discover directories using a [w]ordlist on a target [u]rl with [c]olorized and [v]erbose output <end>
# Predicted Command: into file, mocp dumpe2fs information
# Actual Command: <start> ffuf -w {{path/to/wordlist}} -u {{https://target/FUZZ}} -c -v <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Input Text: <start> fuzz host[h]eaders with a host file on a traget website and [m]atch http 200 [c]ode responses <end>
# Predicted Command: dnsrecon gh remove would remove default
# Actual Command: <start> ffuf -w {{hosts.txt}} -u {{https://example.org}} -H "{{Host: FUZZ}}" -mc {{200}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Input Text: <start> discover directories using a [w]ordlist on a target website with a max individual job time of 60 seconds and recursion discovery depth of 2 levels <end>
# Predicted Command: outlining custom platformio dumpe2fs pool-build {{path/to/output_file.pdf}} slackbuild
# Actual Command: <start> ffuf -w {{path/to/wordlist}} -u {{https://target/FUZZ}} -maxtime-job {{60}} -recursion -recursion-depth {{2}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> fuzz get parameter on a target website and [f]ilter out message [s]ize response of 4242 bytes <end>
# Predicted Command: from basic gw4 uploading {{num}} if=/dev/urandom shut
# Actual Command: <start> ffuf -w {{path/to/param_names.txt}} -u {{https://target/script.php?FUZZ=test_value}} -fs {{4242}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Input Text: <start> fuzz post method with post [d]ata of password on a target website and [f]ilter out http response [c]ode 401 <end>
# Predicted Command: configure password information prompt --list-targets password password java
# Actual Command: <start> ffuf -w {{path/to/postdata.txt}} -X {{POST}} -d "{{username=admin\&password=FUZZ}}" -u {{https://target/login.php}} -fc {{401}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Input Text: <start> discover subdomains using a subdoomain list on a target website <end>
# Predicted Command: lpr generate generate generate
# Actual Command: <start> ffuf -w {{subdomains.txt}} -u {{https://website.com}} -H "{{Host: FUZZ.website.com}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Input Text: <start> add all package binaries in the current directory and remove the old database file <end>
# Predicted Command: running that
# Actual Command: <start> repo-add --remove {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# Input Text: <start> add all package binaries in the current directory in silent mode except for warning and error messages <end>
# Predicted Command: from basic force stash
# Actual Command: <start> repo-add --quiet {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Input Text: <start> add all package binaries in the current directory without showing color <end>
# Predicted Command: babel multiple
# Actual Command: <start> repo-add --nocolor {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Input Text: <start> display executable invocations per user (username not displayed) <end>
# Predicted Command: phpdox only, runlevels one, 3
# Actual Command: <start> sudo sa <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Input Text: <start> display executable invocations per user, showing responsible usernames <end>
# Predicted Command: key {{path/to/directory}} logs
# Actual Command: <start> sudo sa --print-users <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Input Text: <start> list resources used recently per user <end>
# Predicted Command: == records) months|weeks|days|hours|seconds
# Actual Command: <start> sudo sa --user-summary <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> edit the password file <end>
# Predicted Command: + by
# Actual Command: <start> vipw <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Input Text: <start> display the current version of `vipw` <end>
# Predicted Command: from height logs newer)
# Actual Command: <start> vipw --version <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: <start> retrieve current status of the jail service <end>
# Predicted Command: sudo {{rtmp://example.com/path/to/video}} initialization gh {{foo}}
# Actual Command: <start> fail2ban-client status {{jail}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Input Text: <start> remove the specified ip from the jail service's ban list <end>
# Predicted Command: from {{path/to/file_or_directory}} information devices homectl
# Actual Command: <start> fail2ban-client set {{jail}} unbanip {{ip}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Input Text: <start> verify fail2ban server is alive <end>
# Predicted Command: than --exclude
# Actual Command: <start> fail2ban-client ping <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: <start> synchronize and set date and time <end>
# Predicted Command: desktop default name days http//localhostport
# Actual Command: <start> sudo ntpdate {{host}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> query the host without setting the time <end>
# Predicted Command: from name logs
# Actual Command: <start> ntpdate -q {{host}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Input Text: <start> use an unprivileged port in case a firewall is blocking privileged ports <end>
# Predicted Command: fonts -u docker
# Actual Command: <start> sudo ntpdate -u {{host}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Input Text: <start> force time to be stepped using `settimeofday` instead of `slewed` <end>
# Predicted Command: inventory {{network_name}} test}} elvi's
# Actual Command: <start> sudo ntpdate -b {{host}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> show all running services <end>
# Predicted Command: {{hash_value}} default fcrackzip
# Actual Command: <start> systemctl status <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: <start> list failed units <end>
# Predicted Command: wc default
# Actual Command: <start> systemctl --failed <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: <start> start/stop/restart/reload a service <end>
# Predicted Command: {{7}} gh
# Actual Command: <start> systemctl {{start|stop|restart|reload}} {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Input Text: <start> show the status of a unit <end>
# Predicted Command: sudo default by
# Actual Command: <start> systemctl status {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Input Text: <start> enable/disable a unit to be started on bootup <end>
# Predicted Command: musescore
# Actual Command: <start> systemctl {{enable|disable}} {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: <start> mask/unmask a unit to prevent enablement and manual activation <end>
# Predicted Command: trans file, pdfgrep
# Actual Command: <start> systemctl {{mask|unmask}} {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Input Text: <start> reload systemd, scanning for new or changed units <end>
# Predicted Command: system -u index {{/dev/sdxn}}
# Actual Command: <start> systemctl daemon-reload <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> check if a unit is enabled <end>
# Predicted Command: than
# Actual Command: <start> systemctl is-enabled {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Input Text: <start> run `ipconfig.exe` program <end>
# Predicted Command: + -d
# Actual Command: <start> wine {{ipconfig}} {{/all}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Input Text: <start> run `cmd.exe` in background <end>
# Predicted Command: transmission-cli {{75}}% {{header-name:header-value}} tagged
# Actual Command: <start> wine start {{cmd}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: <start> run windowslike package manager <end>
# Predicted Command: sudo
# Actual Command: <start> wine uninstaller <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> install msi packages <end>
# Predicted Command: argument encryption {{path/to/cipher_dir}}
# Actual Command: <start> wine msiexec /i {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: <start> display a message in fullscreen <end>
# Predicted Command: computer information
# Actual Command: <start> sm "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Input Text: <start> display a message with inverted colors <end>
# Predicted Command: ngrok java information returning
# Actual Command: <start> sm -i "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Input Text: <start> display a message with a custom foreground color <end>
# Predicted Command: from "{{title}}" secret secret
# Actual Command: <start> sm -f {{blue}} "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Input Text: <start> display a message with a custom background color <end>
# Predicted Command: system background {{input_file}} its {{8.8.8.8}}
# Actual Command: <start> sm -b {{#008888}} "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Input Text: <start> display a message rotated 3 times (in steps of 90 degrees, counterclockwise) <end>
# Predicted Command: sudo start ag jstack state, --web
# Actual Command: <start> sm -r {{3}} "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> display a message using the output from another command <end>
# Predicted Command: from {{path/to/file_or_directory}} cmatrix prompted
# Actual Command: <start> {{echo "Hello World!"}} | sm - <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> create a btrfs filesystem on a single device <end>
# Predicted Command: connects name generate
# Actual Command: <start> sudo mkfs.btrfs --metadata single --data single {{/dev/sda}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: <start> create a btrfs filesystem on multiple devices with raid1 <end>
# Predicted Command: e default default {{path/to/file.tar}}
# Actual Command: <start> sudo mkfs.btrfs --metadata raid1 --data raid1 {{/dev/sda}} {{/dev/sdb}} {{/dev/sdN}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> set a label for the filesystem <end>
# Predicted Command: into user ghci omitted that
# Actual Command: <start> sudo mkfs.btrfs --label "{{label}}" {{/dev/sda}} [{{/dev/sdN}}] <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> mount a `.raw` image file into a dmg container file <end>
# Predicted Command: unused mode gh by
# Actual Command: <start> xmount --in {{raw}} {{path/to/image.dd}} --out {{dmg}} {{mountpoint}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Input Text: <start> mount an ewf image file with writecache support into a vhd file to boot from <end>
# Predicted Command: {{archive_file.dump}} unused then one one
# Actual Command: <start> xmount --cache {{path/to/cache.ovl}} --in {{ewf}} {{path/to/image.E??}} --out {{vhd}} {{mountpoint}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Input Text: <start> mount the first partition at sector 2048 into a new `.raw` image file <end>
# Predicted Command: {{file.ext}} first julia one
# Actual Command: <start> xmount --offset {{2048}} --in {{raw}} {{path/to/image.dd}} --out {{raw}} {{mountpoint}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Input Text: <start> show the current number lock status <end>
# Predicted Command: sudo default default
# Actual Command: <start> numlockx status <end>
#
# ---

# %%
# Load dataset
dataset_test = load_dataset("neulab/tldr", split='test')

# Append <start> and <end> tokens to cmd_texts
cmd_text_test = ["<start> " + item['cmd'] + " <end>" for item in dataset_val]

# Combine nl_texts and cmd_texts for tokenizer fitting
nl_texts_test = [item['nl'] for item in dataset_val]

# Get the first 10 rows of the training dataset
first_100_nl_texts_test = nl_texts[:100]
first_100_cmd_texts_test = cmd_texts[:100]

# Translate each text and print the input, prediction, and actual command
for i in range(100):
    input_text = first_100_nl_texts_test[i]
    actual_command = first_100_cmd_texts_test[i]
    predicted_command = translate(model, tokenizer, input_text, max_length)

    print(f"Input Text: {input_text}")
    print(f"Predicted Command: {predicted_command}")
    print(f"Actual Command: {actual_command}")
    print("\n---\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:1486: FutureWarning: The repository for neulab/tldr contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/neulab/tldr
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Input Text: <start> get the label of a fat32 partition <end>
# Predicted Command: decode members generate unused logs
# Actual Command: <start> fatlabel {{/dev/sda1}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Input Text: <start> set the label of a fat32 partition <end>
# Predicted Command: ascii framework generate {{file.pdf}} logs {{foo}}
# Actual Command: <start> fatlabel {{/dev/sdc3}} "{{new_label}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Input Text: <start> search for a package in your current sources <end>
# Predicted Command: "{{title}}" docker file,
# Actual Command: <start> apt-cache search {{query}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> show information about a package <end>
# Predicted Command: sudo default
# Actual Command: <start> apt-cache show {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: <start> show whether a package is installed and up to date <end>
# Predicted Command: sudo openconnect information pr entire
# Actual Command: <start> apt-cache policy {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Input Text: <start> show dependencies for a package <end>
# Predicted Command: assimp default default
# Actual Command: <start> apt-cache depends {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Input Text: <start> show packages that depend on a particular package <end>
# Predicted Command: -with default {{5}} allows
# Actual Command: <start> apt-cache rdepends {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Input Text: <start> refresh database content <end>
# Predicted Command: wc default additional email
# Actual Command: <start> sudo updatedb <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Input Text: <start> display file names as soon as they are found <end>
# Predicted Command: {{50}} {{user}} size video
# Actual Command: <start> sudo updatedb --verbose <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> install a new package <end>
# Predicted Command: {{app_name}} multiple
# Actual Command: <start> sudo pacman --sync {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: <start> synchronize and update all packages (add `downloadonly` to download the packages and not update them) <end>
# Predicted Command: decoding -u {{command}}
# Actual Command: <start> sudo pacman --sync --refresh --sysupgrade <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Input Text: <start> update all packages and install a new one without prompting <end>
# Predicted Command: newline btrfs index
# Actual Command: <start> sudo pacman --sync --refresh --sysupgrade --noconfirm {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Input Text: <start> search the package database for a regular expression or keyword <end>
# Predicted Command: sudo docker mode information
# Actual Command: <start> pacman --sync --search "{{search_pattern}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Input Text: <start> display information about a package <end>
# Predicted Command: sudo information
# Actual Command: <start> pacman --sync --info {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Input Text: <start> overwrite conflicting files during a package update <end>
# Predicted Command: sudo docker issue
# Actual Command: <start> sudo pacman --sync --refresh --sysupgrade --overwrite {{path/to/file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Input Text: <start> synchronize and update all packages, but ignore a specific package (can be used more than once) <end>
# Predicted Command: editor) --package launch launch
# Actual Command: <start> sudo pacman --sync --refresh --sysupgrade --ignore {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> remove not installed packages and unused repositories from the cache (use two `clean` flags to clean all packages) <end>
# Predicted Command: --quiet unload mpd guix annex
# Actual Command: <start> sudo pacman --sync --clean <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Input Text: <start> display help for this subcommand <end>
# Predicted Command: set {{command}}
# Actual Command: <start> pacman --remove --help <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> remove a package and its dependencies <end>
# Predicted Command: {{project}} that that information
# Actual Command: <start> sudo pacman --remove --recursive {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> remove a package and both its dependencies and configuration files <end>
# Predicted Command: asterisk docker docker pattern
# Actual Command: <start> sudo pacman --remove --recursive --nosave {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Input Text: <start> remove a package without prompting <end>
# Predicted Command: save secret tabletpcbutton
# Actual Command: <start> sudo pacman --remove --noconfirm {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Input Text: <start> remove orphan packages (installed as dependencies but not required by any package) <end>
# Predicted Command: system gh devices undo
# Actual Command: <start> sudo pacman --remove --recursive --nosave $(pacman --query --unrequired --deps --quiet) <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: <start> remove a package and all packages that depend on it <end>
# Predicted Command: duplicity -u commit
# Actual Command: <start> sudo pacman --remove --cascade {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> list packages that would be affected (does not remove any packages) <end>
# Predicted Command: number devices
# Actual Command: <start> pacman --remove --print {{package_name}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Input Text: <start> display bpftrace version <end>
# Predicted Command: bpftrace detailed nft
# Actual Command: <start> bpftrace -V <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: <start> list all available probes <end>
# Predicted Command: battery branch
# Actual Command: <start> sudo bpftrace -l <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Input Text: <start> run a oneliner program (e.g. syscall count by program) <end>
# Predicted Command: uncrustify
# Actual Command: <start> sudo bpftrace -e '{{tracepoint:raw_syscalls:sys_enter { @[comm] = count(); }}}' <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: <start> run a program from a file <end>
# Predicted Command: from additional
# Actual Command: <start> sudo bpftrace {{path/to/file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: <start> trace a program by pid <end>
# Predicted Command: that} devices
# Actual Command: <start> sudo bpftrace -e '{{tracepoint:raw_syscalls:sys_enter /pid == 123/ { @[comm] = count(); }}}' <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> do a dry run and display the output in ebpf format <end>
# Predicted Command: tput cpu cpu
# Actual Command: <start> sudo bpftrace -d -e '{{one_line_program}}' <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> open a file in the default editor <end>
# Predicted Command: battery by by
# Actual Command: <start> sensible-editor {{file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: <start> open a file in the default editor, with the cursor at the end of the file <end>
# Predicted Command: specified docker line by
# Actual Command: <start> sensible-editor + {{file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Input Text: <start> open a file in the default editor, with the cursor at the beginning of line 10 <end>
# Predicted Command: tr that https docker tsacert.pem 1
# Actual Command: <start> sensible-editor +10 {{file}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> open 3 files in vertically split editor windows at the same time <end>
# Predicted Command: hostnames password password password gpg2
# Actual Command: <start> sensible-editor -O3 {{file_1}} {{file_2}} {{file_3}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Input Text: <start> integrate firejail with your desktop environment <end>
# Predicted Command: {{filename.svg}} information information `perf.data` logs `/`)
# Actual Command: <start> sudo firecfg <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> open a restricted mozilla firefox <end>
# Predicted Command: into -type user
# Actual Command: <start> firejail {{firefox}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Input Text: <start> start a restricted apache server on a known interface and address <end>
# Predicted Command: save -u shell docker
# Actual Command: <start> firejail --net={{eth0}} --ip={{192.168.1.244}} {{/etc/init.d/apache2}} {{start}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Input Text: <start> list running sandboxes <end>
# Predicted Command: keys start {{file_opt.bc}}
# Actual Command: <start> firejail --list <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Input Text: <start> list network activity from running sandboxes <end>
# Predicted Command: keys agent {{file_opt.bc}}
# Actual Command: <start> firejail --netstats <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Input Text: <start> shutdown a running sandbox <end>
# Predicted Command: sudo help
# Actual Command: <start> firejail --shutdown={{7777}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Input Text: <start> build the package in the current directory <end>
# Predicted Command: wireless without logs
# Actual Command: <start> debuild <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> build a binary package only <end>
# Predicted Command: sudo gunicorn default 3
# Actual Command: <start> debuild -b <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> do not run lintian after building the package <end>
# Predicted Command: rather gunicorn '{{mariadb*}}' 3 3
# Actual Command: <start> debuild --no-lintian <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Input Text: <start> start nmon <end>
# Predicted Command: year
# Actual Command: <start> nmon <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> save records to file ("s 300 c 288" by default) <end>
# Predicted Command: xman mode julia user
# Actual Command: <start> nmon -f <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> save records to file with a total of 240 measurements, by taking 30 seconds between each measurement <end>
# Predicted Command: --database that xpdf
# Actual Command: <start> nmon -f -s {{30}} -c {{240}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: <start> view the queue <end>
# Predicted Command: diff [a]rchive logs
# Actual Command: <start> squeue <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> view jobs queued by a specific user <end>
# Predicted Command: jobs help showing
# Actual Command: <start> squeue -u {{username}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Input Text: <start> view the queue and refresh every 5 seconds <end>
# Predicted Command: entry 75% remove llvm-bcanalyzer
# Actual Command: <start> squeue -i {{5}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> view the queue with expected start times <end>
# Predicted Command: from start kate --column stty
# Actual Command: <start> squeue --start <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Input Text: <start> show the progress of running coreutils <end>
# Predicted Command: gzip enable vnc also
# Actual Command: <start> progress <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> show the progress of running coreutils in quiet mode <end>
# Predicted Command: gzip enable vnc also
# Actual Command: <start> progress -q <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Input Text: <start> launch and monitor a single longrunning command <end>
# Predicted Command: keys removed runlevels enscript 3
# Actual Command: <start> {{command}} & progress -mp $! <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Input Text: <start> start i7z (needs to be run in superuser mode) <end>
# Predicted Command: sudo "select until
# Actual Command: <start> sudo i7z <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> discover directories using a [w]ordlist on a target [u]rl with [c]olorized and [v]erbose output <end>
# Predicted Command: into file, mocp dumpe2fs information
# Actual Command: <start> ffuf -w {{path/to/wordlist}} -u {{https://target/FUZZ}} -c -v <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Input Text: <start> fuzz host[h]eaders with a host file on a traget website and [m]atch http 200 [c]ode responses <end>
# Predicted Command: dnsrecon gh remove would remove default
# Actual Command: <start> ffuf -w {{hosts.txt}} -u {{https://example.org}} -H "{{Host: FUZZ}}" -mc {{200}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> discover directories using a [w]ordlist on a target website with a max individual job time of 60 seconds and recursion discovery depth of 2 levels <end>
# Predicted Command: outlining custom platformio dumpe2fs pool-build {{path/to/output_file.pdf}} slackbuild
# Actual Command: <start> ffuf -w {{path/to/wordlist}} -u {{https://target/FUZZ}} -maxtime-job {{60}} -recursion -recursion-depth {{2}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> fuzz get parameter on a target website and [f]ilter out message [s]ize response of 4242 bytes <end>
# Predicted Command: from basic gw4 uploading {{num}} if=/dev/urandom shut
# Actual Command: <start> ffuf -w {{path/to/param_names.txt}} -u {{https://target/script.php?FUZZ=test_value}} -fs {{4242}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> fuzz post method with post [d]ata of password on a target website and [f]ilter out http response [c]ode 401 <end>
# Predicted Command: configure password information prompt --list-targets password password java
# Actual Command: <start> ffuf -w {{path/to/postdata.txt}} -X {{POST}} -d "{{username=admin\&password=FUZZ}}" -u {{https://target/login.php}} -fc {{401}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: <start> discover subdomains using a subdoomain list on a target website <end>
# Predicted Command: lpr generate generate generate
# Actual Command: <start> ffuf -w {{subdomains.txt}} -u {{https://website.com}} -H "{{Host: FUZZ.website.com}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Input Text: <start> add all package binaries in the current directory and remove the old database file <end>
# Predicted Command: running that
# Actual Command: <start> repo-add --remove {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> add all package binaries in the current directory in silent mode except for warning and error messages <end>
# Predicted Command: from basic force stash
# Actual Command: <start> repo-add --quiet {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# Input Text: <start> add all package binaries in the current directory without showing color <end>
# Predicted Command: babel multiple
# Actual Command: <start> repo-add --nocolor {{path/to/database.db.tar.gz}} {{*.pkg.tar.zst}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Input Text: <start> display executable invocations per user (username not displayed) <end>
# Predicted Command: phpdox only, runlevels one, 3
# Actual Command: <start> sudo sa <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Input Text: <start> display executable invocations per user, showing responsible usernames <end>
# Predicted Command: key {{path/to/directory}} logs
# Actual Command: <start> sudo sa --print-users <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Input Text: <start> list resources used recently per user <end>
# Predicted Command: == records) months|weeks|days|hours|seconds
# Actual Command: <start> sudo sa --user-summary <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Input Text: <start> edit the password file <end>
# Predicted Command: + by
# Actual Command: <start> vipw <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: <start> display the current version of `vipw` <end>
# Predicted Command: from height logs newer)
# Actual Command: <start> vipw --version <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: <start> retrieve current status of the jail service <end>
# Predicted Command: sudo {{rtmp://example.com/path/to/video}} initialization gh {{foo}}
# Actual Command: <start> fail2ban-client status {{jail}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Input Text: <start> remove the specified ip from the jail service's ban list <end>
# Predicted Command: from {{path/to/file_or_directory}} information devices homectl
# Actual Command: <start> fail2ban-client set {{jail}} unbanip {{ip}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Input Text: <start> verify fail2ban server is alive <end>
# Predicted Command: than --exclude
# Actual Command: <start> fail2ban-client ping <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> synchronize and set date and time <end>
# Predicted Command: desktop default name days http//localhostport
# Actual Command: <start> sudo ntpdate {{host}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> query the host without setting the time <end>
# Predicted Command: from name logs
# Actual Command: <start> ntpdate -q {{host}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: <start> use an unprivileged port in case a firewall is blocking privileged ports <end>
# Predicted Command: fonts -u docker
# Actual Command: <start> sudo ntpdate -u {{host}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Input Text: <start> force time to be stepped using `settimeofday` instead of `slewed` <end>
# Predicted Command: inventory {{network_name}} test}} elvi's
# Actual Command: <start> sudo ntpdate -b {{host}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Input Text: <start> show all running services <end>
# Predicted Command: {{hash_value}} default fcrackzip
# Actual Command: <start> systemctl status <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Input Text: <start> list failed units <end>
# Predicted Command: wc default
# Actual Command: <start> systemctl --failed <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Input Text: <start> start/stop/restart/reload a service <end>
# Predicted Command: {{7}} gh
# Actual Command: <start> systemctl {{start|stop|restart|reload}} {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Input Text: <start> show the status of a unit <end>
# Predicted Command: sudo default by
# Actual Command: <start> systemctl status {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Input Text: <start> enable/disable a unit to be started on bootup <end>
# Predicted Command: musescore
# Actual Command: <start> systemctl {{enable|disable}} {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: <start> mask/unmask a unit to prevent enablement and manual activation <end>
# Predicted Command: trans file, pdfgrep
# Actual Command: <start> systemctl {{mask|unmask}} {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Input Text: <start> reload systemd, scanning for new or changed units <end>
# Predicted Command: system -u index {{/dev/sdxn}}
# Actual Command: <start> systemctl daemon-reload <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> check if a unit is enabled <end>
# Predicted Command: than
# Actual Command: <start> systemctl is-enabled {{unit}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Input Text: <start> run `ipconfig.exe` program <end>
# Predicted Command: + -d
# Actual Command: <start> wine {{ipconfig}} {{/all}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Input Text: <start> run `cmd.exe` in background <end>
# Predicted Command: transmission-cli {{75}}% {{header-name:header-value}} tagged
# Actual Command: <start> wine start {{cmd}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> run windowslike package manager <end>
# Predicted Command: sudo
# Actual Command: <start> wine uninstaller <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input Text: <start> install msi packages <end>
# Predicted Command: argument encryption {{path/to/cipher_dir}}
# Actual Command: <start> wine msiexec /i {{package}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Input Text: <start> display a message in fullscreen <end>
# Predicted Command: computer information
# Actual Command: <start> sm "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Input Text: <start> display a message with inverted colors <end>
# Predicted Command: ngrok java information returning
# Actual Command: <start> sm -i "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Input Text: <start> display a message with a custom foreground color <end>
# Predicted Command: from "{{title}}" secret secret
# Actual Command: <start> sm -f {{blue}} "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> display a message with a custom background color <end>
# Predicted Command: system background {{input_file}} its {{8.8.8.8}}
# Actual Command: <start> sm -b {{#008888}} "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# Input Text: <start> display a message rotated 3 times (in steps of 90 degrees, counterclockwise) <end>
# Predicted Command: sudo start ag jstack state, --web
# Actual Command: <start> sm -r {{3}} "{{Hello World!}}" <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Input Text: <start> display a message using the output from another command <end>
# Predicted Command: from {{path/to/file_or_directory}} cmatrix prompted
# Actual Command: <start> {{echo "Hello World!"}} | sm - <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> create a btrfs filesystem on a single device <end>
# Predicted Command: connects name generate
# Actual Command: <start> sudo mkfs.btrfs --metadata single --data single {{/dev/sda}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Input Text: <start> create a btrfs filesystem on multiple devices with raid1 <end>
# Predicted Command: e default default {{path/to/file.tar}}
# Actual Command: <start> sudo mkfs.btrfs --metadata raid1 --data raid1 {{/dev/sda}} {{/dev/sdb}} {{/dev/sdN}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Input Text: <start> set a label for the filesystem <end>
# Predicted Command: into user ghci omitted that
# Actual Command: <start> sudo mkfs.btrfs --label "{{label}}" {{/dev/sda}} [{{/dev/sdN}}] <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Input Text: <start> mount a `.raw` image file into a dmg container file <end>
# Predicted Command: unused mode gh by
# Actual Command: <start> xmount --in {{raw}} {{path/to/image.dd}} --out {{dmg}} {{mountpoint}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Input Text: <start> mount an ewf image file with writecache support into a vhd file to boot from <end>
# Predicted Command: {{archive_file.dump}} unused then one one
# Actual Command: <start> xmount --cache {{path/to/cache.ovl}} --in {{ewf}} {{path/to/image.E??}} --out {{vhd}} {{mountpoint}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Input Text: <start> mount the first partition at sector 2048 into a new `.raw` image file <end>
# Predicted Command: {{file.ext}} first julia one
# Actual Command: <start> xmount --offset {{2048}} --in {{raw}} {{path/to/image.dd}} --out {{raw}} {{mountpoint}} <end>
#
# ---
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Input Text: <start> show the current number lock status <end>
# Predicted Command: sudo default default
# Actual Command: <start> numlockx status <end>
#
# ---
